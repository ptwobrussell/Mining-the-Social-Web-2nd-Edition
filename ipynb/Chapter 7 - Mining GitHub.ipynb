# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 7: Mining GitHub: Inspecting Software Collaboration Habits, Building Interest Graphs, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# ## Example 1. Programmatically obtaining a personal API access token for accessing GitHub's API

# %%
import requests
from getpass import getpass
import json

username = '' # Your GitHub username
password = '' # Your GitHub password

# Note that credentials will be transmitted over a secure SSL connection
url = 'https://github.com/login/oauth/authorize'
note = 'Mining the Social Web, 2nd Ed.'
post_data = {'scopes':['repo'],'note': note }

response = requests.post(
    url,
    auth = (username, password),
    data = json.dumps(post_data),
    )   

print("API response:", response.text)
print('\n')
print("Your OAuth token is", response.json()['token'])

# Go to https://github.com/settings/applications to revoke this token
# Out:
# API response: Cookies must be enabled to use GitHub.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-8-df9740550bb5> in <module>()
#      19 print("API response:", response.text)
#      20 print('\n')
# ---> 21 print("Your OAuth token is", response.json()['token'])
#      22
#      23 # Go to https://github.com/settings/applications to revoke this token
#
# /Users/temp/anaconda/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     883                     # used.
#     884                     pass
# --> 885         return complexjson.loads(self.text, **kwargs)
#     886
#     887     @property
#
# /Users/temp/anaconda/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /Users/temp/anaconda/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Users/temp/anaconda/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-9-670418389d1b> in <module>()
# ----> 1 response.json()
#
# /Users/temp/anaconda/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     883                     # used.
#     884                     pass
# --> 885         return complexjson.loads(self.text, **kwargs)
#     886
#     887     @property
#
# /Users/temp/anaconda/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /Users/temp/anaconda/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Users/temp/anaconda/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Example 2. Making direct HTTP requests to GitHub's API

# %%
import json
import requests

# An unauthenticated request that doesn't contain an ?access_token=xxx query string
url = "https://api.github.com/repos/ptwobrussell/Mining-the-Social-Web/stargazers"
response = requests.get(url)

# Display one stargazer

print(json.dumps(response.json()[0], indent=1)+ '\n')

# Display headers
for (k,v) in response.headers.items():
    print(k, "=>", v)
# Out:
# {
#  "login": "rdempsey",
#  "id": 224,
#  "avatar_url": "https://avatars2.githubusercontent.com/u/224?v=4",
#  "gravatar_id": "",
#  "url": "https://api.github.com/users/rdempsey",
#  "html_url": "https://github.com/rdempsey",
#  "followers_url": "https://api.github.com/users/rdempsey/followers",
#  "following_url": "https://api.github.com/users/rdempsey/following{/other_user}",
#  "gists_url": "https://api.github.com/users/rdempsey/gists{/gist_id}",
#  "starred_url": "https://api.github.com/users/rdempsey/starred{/owner}{/repo}",
#  "subscriptions_url": "https://api.github.com/users/rdempsey/subscriptions",
#  "organizations_url": "https://api.github.com/users/rdempsey/orgs",
#  "repos_url": "https://api.github.com/users/rdempsey/repos",
#  "events_url": "https://api.github.com/users/rdempsey/events{/privacy}",
#  "received_events_url": "https://api.github.com/users/rdempsey/received_events",
#  "type": "User",
#  "site_admin": false
# }
#
# Server => GitHub.com
# Date => Sun, 29 Apr 2018 21:38:18 GMT
# Content-Type => application/json; charset=utf-8
# Transfer-Encoding => chunked
# Status => 200 OK
# X-RateLimit-Limit => 60
# X-RateLimit-Remaining => 56
# X-RateLimit-Reset => 1525040104
# Cache-Control => public, max-age=60, s-maxage=60
# Vary => Accept
# ETag => W/"b43b2c639758a6849c9f3f5873209038"
# X-GitHub-Media-Type => github.v3; format=json
# Link => <https://api.github.com/repositories/1040700/stargazers?page=2>; rel="next", <https://api.github.com/repositories/1040700/stargazers?page=39>; rel="last"
# Access-Control-Expose-Headers => ETag, Link, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval
# Access-Control-Allow-Origin => *
# Strict-Transport-Security => max-age=31536000; includeSubdomains; preload
# X-Frame-Options => deny
# X-Content-Type-Options => nosniff
# X-XSS-Protection => 1; mode=block
# Referrer-Policy => origin-when-cross-origin, strict-origin-when-cross-origin
# Content-Security-Policy => default-src 'none'
# X-Runtime-rack => 0.039513
# Content-Encoding => gzip
# X-GitHub-Request-Id => F75B:1DE5:1C7DDDF:43426B1:5AE63B4A

# %% [markdown]
# ## Example 3. Using PyGithub to query for stargazers of a particular repository

# %%
from github import Github

# XXX: Specify your own access token here

ACCESS_TOKEN = ''

# Specify a username and repository of interest for that user.

USER = 'ptwobrussell'
REPO = 'Mining-the-Social-Web'

client = Github(ACCESS_TOKEN, per_page=100)
user = client.get_user(USER)
repo = user.get_repo(REPO)

# Get a list of people who have bookmarked the repo.
# Since you'll get a lazy iterator back, you have to traverse
# it if you want to get the total number of stargazers.

stargazers = [ s for s in repo.get_stargazers() ]
print("Number of stargazers", len(stargazers))
# Out:
# Number of stargazers 1151

# %% [markdown]
# ## Example 4. Constructing a trivial property graph

# %%
import networkx as nx

# Create a directed graph

g = nx.DiGraph()

# Add an edge to the directed graph from X to Y

g.add_edge('X', 'Y')

# Print some statistics about the graph

print(nx.info(g)+'\n')

# Get the nodes and edges from the graph

print("Nodes:", g.nodes())
print("Edges:", g.edges())
print('\n')


# Get node properties

print("X props:", g.node['X'])
print("Y props:", g.node['Y'])

# Get edge properties

print("X=>Y props:", g['X']['Y'])
print('\n')

# Update a node property

g.node['X'].update({'prop1' : 'value1'})
print("X props:", g.node['X'])
print('\n')

# Update an edge property

g['X']['Y'].update({'label' : 'label1'})
print("X=>Y props:", g['X']['Y'])
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 2
# Number of edges: 1
# Average in degree:   0.5000
# Average out degree:   0.5000
#
# Nodes: ['X', 'Y']
# Edges: [('X', 'Y')]
#
#
# X props: {}
# Y props: {}
# X=>Y props: {}
#
#
# X props: {'prop1': 'value1'}
#
#
# X=>Y props: {'label': 'label1'}

# %% [markdown]
# ## Example 5. Constructing an ego graph of a repository and its stargazers

# %%
# Expand the initial graph with (interest) edges pointing each direction for 
# additional people interested. Take care to ensure that user and repo nodes 
# do not collide by appending their type.

import networkx as nx

g = nx.DiGraph()
g.add_node(repo.name + '(repo)', type='repo', lang=repo.language, owner=user.login)

for sg in stargazers:
    g.add_node(sg.login + '(user)', type='user')
    g.add_edge(sg.login + '(user)', repo.name + '(repo)', type='gazes')

# %% [markdown]
# ## Example 6. Introducing some handy graph operations

# %%
# Poke around in the current graph to get a better feel for how NetworkX works

print(nx.info(g))
print('\n')
print(g.node['Mining-the-Social-Web(repo)'])
print(g.node['ptwobrussell(user)'])
print('\n')
print(g['ptwobrussell(user)']['Mining-the-Social-Web(repo)'])
# The next line would throw a KeyError since no such edge exists:
# print g['Mining-the-Social-Web(repo)']['ptwobrussell(user)']
print('\n')
print(g['ptwobrussell(user)'])
print(g['Mining-the-Social-Web(repo)'])
print('\n')
print(g.in_edges(['ptwobrussell(user)']))
print(g.out_edges(['ptwobrussell(user)']))
print('\n')
print(g.in_edges(['Mining-the-Social-Web(repo)']))
print(g.out_edges(['Mining-the-Social-Web(repo)']))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1152
# Number of edges: 1151
# Average in degree:   0.9991
# Average out degree:   0.9991
#
#
# {'type': 'repo', 'lang': 'JavaScript', 'owner': 'ptwobrussell'}
# {'type': 'user'}
#
#
# {'type': 'gazes'}
#
#
# {'Mining-the-Social-Web(repo)': {'type': 'gazes'}}
# {}
#
#
# []
# [('ptwobrussell(user)', 'Mining-the-Social-Web(repo)')]
#
#
# [('rdempsey(user)', 'Mining-the-Social-Web(repo)'), ('frac(user)', 'Mining-the-Social-Web(repo)'), ('prb(user)', 'Mining-the-Social-Web(repo)'), ('mcroydon(user)', 'Mining-the-Social-Web(repo)'), ('batasrki(user)', 'Mining-the-Social-Web(repo)'), ('twleung(user)', 'Mining-the-Social-Web(repo)'), ('kevinchiu(user)', 'Mining-the-Social-Web(repo)'), ('nikolay(user)', 'Mining-the-Social-Web(repo)'), ('tswicegood(user)', 'Mining-the-Social-Web(repo)'), ('ngpestelos(user)', 'Mining-the-Social-Web(repo)'), ('darron(user)', 'Mining-the-Social-Web(repo)'), ('brunojm(user)', 'Mining-the-Social-Web(repo)'), ('rgaidot(user)', 'Mining-the-Social-Web(repo)'), ('openweb(user)', 'Mining-the-Social-Web(repo)'), ('shanlalit(user)', 'Mining-the-Social-Web(repo)'), ('hoffmann(user)', 'Mining-the-Social-Web(repo)'), ('nacht(user)', 'Mining-the-Social-Web(repo)'), ('hectoregm(user)', 'Mining-the-Social-Web(repo)'), ('tzuryby(user)', 'Mining-the-Social-Web(repo)'), ('marksands(user)', 'Mining-the-Social-Web(repo)'), ('wbzyl(user)', 'Mining-the-Social-Web(repo)'), ('sou(user)', 'Mining-the-Social-Web(repo)'), ('magnum(user)', 'Mining-the-Social-Web(repo)'), ('suzuki(user)', 'Mining-the-Social-Web(repo)'), ('tertsch(user)', 'Mining-the-Social-Web(repo)'), ('ymirpl(user)', 'Mining-the-Social-Web(repo)'), ('sebasmagri(user)', 'Mining-the-Social-Web(repo)'), ('galvez(user)', 'Mining-the-Social-Web(repo)'), ('paulbersch(user)', 'Mining-the-Social-Web(repo)'), ('georgebellos(user)', 'Mining-the-Social-Web(repo)'), ('acadopia(user)', 'Mining-the-Social-Web(repo)'), ('ggtr1138(user)', 'Mining-the-Social-Web(repo)'), ('program247365(user)', 'Mining-the-Social-Web(repo)'), ('edwelker(user)', 'Mining-the-Social-Web(repo)'), ('hammer(user)', 'Mining-the-Social-Web(repo)'), ('jengdal(user)', 'Mining-the-Social-Web(repo)'), ('brimbrom(user)', 'Mining-the-Social-Web(repo)'), ('gar(user)', 'Mining-the-Social-Web(repo)'), ('willi(user)', 'Mining-the-Social-Web(repo)'), ('gregmoreno(user)', 'Mining-the-Social-Web(repo)'), ('rays(user)', 'Mining-the-Social-Web(repo)'), ('rayleyva(user)', 'Mining-the-Social-Web(repo)'), ('paxan(user)', 'Mining-the-Social-Web(repo)'), ('eughenes(user)', 'Mining-the-Social-Web(repo)'), ('barce(user)', 'Mining-the-Social-Web(repo)'), ('abuiles(user)', 'Mining-the-Social-Web(repo)'), ('carhartl(user)', 'Mining-the-Social-Web(repo)'), ('jexchan(user)', 'Mining-the-Social-Web(repo)'), ('yasu00000(user)', 'Mining-the-Social-Web(repo)'), ('lsinger(user)', 'Mining-the-Social-Web(repo)'), ('yy(user)', 'Mining-the-Social-Web(repo)'), ('daemianmack(user)', 'Mining-the-Social-Web(repo)'), ('ricardoalmeida(user)', 'Mining-the-Social-Web(repo)'), ('gerad(user)', 'Mining-the-Social-Web(repo)'), ('amitagrawal(user)', 'Mining-the-Social-Web(repo)'), ('swinton(user)', 'Mining-the-Social-Web(repo)'), ('polonia(user)', 'Mining-the-Social-Web(repo)'), ('fozbaca(user)', 'Mining-the-Social-Web(repo)'), ('nborwankar(user)', 'Mining-the-Social-Web(repo)'), ('aljosa(user)', 'Mining-the-Social-Web(repo)'), ('macdet(user)', 'Mining-the-Social-Web(repo)'), ('Smerity(user)', 'Mining-the-Social-Web(repo)'), ('joepestro(user)', 'Mining-the-Social-Web(repo)'), ('phauly(user)', 'Mining-the-Social-Web(repo)'), ('shamiksharma(user)', 'Mining-the-Social-Web(repo)'), ('lg2046(user)', 'Mining-the-Social-Web(repo)'), ('omg(user)', 'Mining-the-Social-Web(repo)'), ('lzell(user)', 'Mining-the-Social-Web(repo)'), ('eduardocereto(user)', 'Mining-the-Social-Web(repo)'), ('kshimo69(user)', 'Mining-the-Social-Web(repo)'), ('natorro(user)', 'Mining-the-Social-Web(repo)'), ('abecciu(user)', 'Mining-the-Social-Web(repo)'), ('CaptSolo(user)', 'Mining-the-Social-Web(repo)'), ('clyfe(user)', 'Mining-the-Social-Web(repo)'), ('mahmoudimus(user)', 'Mining-the-Social-Web(repo)'), ('mznmel(user)', 'Mining-the-Social-Web(repo)'), ('Kilian(user)', 'Mining-the-Social-Web(repo)'), ('stonegao(user)', 'Mining-the-Social-Web(repo)'), ('pcdinh(user)', 'Mining-the-Social-Web(repo)'), ('jacktang(user)', ' ...
# []

# %% [markdown]
# ## Example 7. Calculating degree, betweenness, and closeness centrality measures on the Krackhardt kite graph

# %%
from operator import itemgetter
from IPython.display import HTML
from IPython.core.display import display

display(HTML('<img src="files/resources/ch07-github/kite-graph.png" width="400px">'))

# The classic Krackhardt kite graph
kkg = nx.generators.small.krackhardt_kite_graph()

print("Degree Centrality")
print(sorted(nx.degree_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))
print('\n')

print("Betweenness Centrality")
print(sorted(nx.betweenness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))
print('\n')

print("Closeness Centrality")
print(sorted(nx.closeness_centrality(kkg).items(), 
             key=itemgetter(1), reverse=True))
# Out:
# <img src="files/resources/ch07-github/kite-graph.png" width="400px">
# Degree Centrality
# [(3, 0.6666666666666666), (5, 0.5555555555555556), (6, 0.5555555555555556), (0, 0.4444444444444444), (1, 0.4444444444444444), (2, 0.3333333333333333), (4, 0.3333333333333333), (7, 0.3333333333333333), (8, 0.2222222222222222), (9, 0.1111111111111111)]
#
#
# Betweenness Centrality
# [(7, 0.38888888888888884), (5, 0.23148148148148148), (6, 0.23148148148148148), (8, 0.2222222222222222), (3, 0.10185185185185183), (0, 0.023148148148148143), (1, 0.023148148148148143), (2, 0.0), (4, 0.0), (9, 0.0)]
#
#
# Closeness Centrality
# [(5, 0.6428571428571429), (6, 0.6428571428571429), (3, 0.6), (7, 0.6), (0, 0.5294117647058824), (1, 0.5294117647058824), (2, 0.5), (4, 0.5), (8, 0.42857142857142855), (9, 0.3103448275862069)]

# %% [markdown]
# ## Example 8. Adding additional interest edges to the graph through the inclusion of "follows" edges

# %%
# Add (social) edges from the stargazers' followers. This can take a while 
# because of all of the potential API calls to GitHub. The approximate number
# of requests for followers for each iteration of this loop can be calculated as
# math.ceil(sg.get_followers() / 100.0) per the API returning up to 100 items
# at a time.

import sys

for i, sg in enumerate(stargazers):
    
    # Add "follows" edges between stargazers in the graph if any relationships exist
    try:
        for follower in sg.get_followers():
            if follower.login + '(user)' in g:
                g.add_edge(follower.login + '(user)', sg.login + '(user)', 
                           type='follows')
    except Exception: #ssl.SSLError
        print >> sys.stderr, "Encountered an error fetching followers for", \
                             sg.login, "Skipping."
        print >> sys.stderr, e

    print("Processed", i+1, " stargazers. Num nodes/edges in graph", \
          g.number_of_nodes(), "/", g.number_of_edges())
    print("Rate limit remaining", client.rate_limiting)
# Out:
# Processed 1  stargazers. Num nodes/edges in graph 1152 / 1153
# Rate limit remaining (4981, 5000)
# Processed 2  stargazers. Num nodes/edges in graph 1152 / 1156
# Rate limit remaining (4980, 5000)
# Processed 3  stargazers. Num nodes/edges in graph 1152 / 1158
# Rate limit remaining (4979, 5000)
# Processed 4  stargazers. Num nodes/edges in graph 1152 / 1164
# Rate limit remaining (4977, 5000)
# Processed 5  stargazers. Num nodes/edges in graph 1152 / 1165
# Rate limit remaining (4976, 5000)
# Processed 6  stargazers. Num nodes/edges in graph 1152 / 1167
# Rate limit remaining (4975, 5000)
# Processed 7  stargazers. Num nodes/edges in graph 1152 / 1168
# Rate limit remaining (4974, 5000)
# Processed 8  stargazers. Num nodes/edges in graph 1152 / 1171
# Rate limit remaining (4971, 5000)
# Processed 9  stargazers. Num nodes/edges in graph 1152 / 1181
# Rate limit remaining (4966, 5000)
# Processed 10  stargazers. Num nodes/edges in graph 1152 / 1184
# Rate limit remaining (4965, 5000)
# Processed 11  stargazers. Num nodes/edges in graph 1152 / 1186
# Rate limit remaining (4964, 5000)
# Processed 12  stargazers. Num nodes/edges in graph 1152 / 1189
# Rate limit remaining (4963, 5000)
# Processed 13  stargazers. Num nodes/edges in graph 1152 / 1192
# Rate limit remaining (4962, 5000)
# Processed 14  stargazers. Num nodes/edges in graph 1152 / 1194
# Rate limit remaining (4961, 5000)
# Processed 15  stargazers. Num nodes/edges in graph 1152 / 1196
# Rate limit remaining (4960, 5000)
# Processed 16  stargazers. Num nodes/edges in graph 1152 / 1201
# Rate limit remaining (4959, 5000)
# Processed 17  stargazers. Num nodes/edges in graph 1152 / 1202
# Rate limit remaining (4958, 5000)
# Processed 18  stargazers. Num nodes/edges in graph 1152 / 1205
# Rate limit remaining (4957, 5000)
# Processed 19  stargazers. Num nodes/edges in graph 1152 / 1210
# Rate limit remaining (4956, 5000)
# Processed 20  stargazers. Num nodes/edges in graph 1152 / 1211
# Rate limit remaining (4955, 5000)
# Processed 21  stargazers. Num nodes/edges in graph 1152 / 1213
# Rate limit remaining (4952, 5000)
# Processed 22  stargazers. Num nodes/edges in graph 1152 / 1214
# Rate limit remaining (4951, 5000)
# Processed 23  stargazers. Num nodes/edges in graph 1152 / 1215
# Rate limit remaining (4950, 5000)
# Processed 24  stargazers. Num nodes/edges in graph 1152 / 1217
# Rate limit remaining (4949, 5000)
# Processed 25  stargazers. Num nodes/edges in graph 1152 / 1218
# Rate limit remaining (4948, 5000)
# Processed 26  stargazers. Num nodes/edges in graph 1152 / 1219
# Rate limit remaining (4947, 5000)
# Processed 27  stargazers. Num nodes/edges in graph 1152 / 1223
# Rate limit remaining (4945, 5000)
# Processed 28  stargazers. Num nodes/edges in graph 1152 / 1225
# Rate limit remaining (4944, 5000)
# Processed 29  stargazers. Num nodes/edges in graph 1152 / 1226
# Rate limit remaining (4943, 5000)
# Processed 30  stargazers. Num nodes/edges in graph 1152 / 1228
# Rate limit remaining (4942, 5000)
# Processed 31  stargazers. Num nodes/edges in graph 1152 / 1230
# Rate limit remaining (4941, 5000)
# Processed 32  stargazers. Num nodes/edges in graph 1152 / 1231
# Rate limit remaining (4940, 5000)
# Processed 33  stargazers. Num nodes/edges in graph 1152 / 1233
# Rate limit remaining (4939, 5000)
# Processed 34  stargazers. Num nodes/edges in graph 1152 / 1234
# Rate limit remaining (4938, 5000)
# Processed 35  stargazers. Num nodes/edges in graph 1152 / 1254
# Rate limit remaining (4931, 5000)
# Processed 36  stargazers. Num nodes/edges in graph 1152 / 1255
# Rate limit remaining (4930, 5000)
# Processed 37  stargazers. Num nodes/edges in graph 1152 / 1257
# Rate limit remaining (4929, 5000)
# Processed 38  stargazers. Num nodes/edges in graph 1152 / 1258
# Rate limit remaining (4928, 5000)
# Processed 39  stargazers. Num nodes/edges in graph 1152 / 1261
# Rate limit remaining (4926, 5000)
# Processed 40  stargazers. Num nodes/edges in graph 1152 / 1264
# Rate limit remaining (4925, 5000)
# Processed 41  stargazers. Num nodes/edges in graph 1152 / 1265
# Rate limit remaining (4924, 5000)
# Processed 42  stargazers. Num nodes/edges in graph 1152 / 1267
# Rate limit remaining (4923, 5000)
# Processed 43  stargazers. Num nodes/edges in graph 1152 / 1269
# Rate limit remaining (4922, 5000)
# Processed 44  stargazers. Num nodes/edges in graph 1152 / 1270
# Rate limit remaining (4921, 5000)
# Processed 45  stargazers. Num nodes/edges in graph 1152 / 1273
# Rate limit remaining (4920, 5000)
# Processed 46  stargazers. Num nodes/edges in graph 1152 / 1276
# Rate limit remaining (4917, 5000)
# Processed 47  stargazers. Num nodes/edges in graph 1152 / 1280
# Rate limit remaining (4914, 5000)
# Processed 48  stargazers. Num nodes/edges in graph 1152 / 1282
# Rate limit remaining (4913, 5000)
# Processed 49  stargazers. Num nodes/edges in graph 1152 / 1283
# Rate limit remaining (4912, 5000)
# Processed 50  stargazers. Num nodes/edges in graph 1152 / 1284
# Rate limit remaining (4911, 5000)
# Processed 51  stargazers. Num nodes/edges in graph 1152 / 1285
# Rate limit remaining (4910, 5000)
# Processed 52  stargazers. Num nodes/edges in graph 1152 / 1287
# Rate limit remaining (4909, 5000)
# Processed 53  stargazers. Num nodes/edges in graph 1152 / 1288
# Rate limit remaining (4908, 5000)
# Processed 54  stargazers. Num nodes/edges in graph 1152 / 1291
# Rate limit remaining (4907, 5000)
# Processed 55  stargazers. Num nodes/edges in graph 1152 / 1292
# Rate limit remaining (4906, 5000)
# Processed 56  stargazers. Num nodes/edges in graph 1152 / 1294
# Rate limit remaining (4905, 5000)
# Processed 57  stargazers. Num nodes/edges in graph 1152 / 1295
# Rate limit remaining (4904, 5000)
# Processed 58  stargazers. Num nodes/edges in graph 1152 / 1296
# Rate limit remaining (4903, 5000)
# Processed 59  stargazers. Num nodes/edges in graph 1152 / 1302
# Rate limit remaining (4900, 5000)
# Processed 60  stargazers. Num nodes/edges in graph 1152 / 1303
# Rate limit remaining (4899, 5000)
# Processed 61  stargazers. Num nodes/edges in graph 1152 / 1304
# Rate limit remaining (4898, 5000)
# Processed 62  stargazers. Num nodes/edges in graph 1152 / 1313
# Rate limit remaining (4893, 5000)
# Processed 63  stargazers. Num nodes/edges in graph 1152 / 1314
# Rate limit remaining (4892, 5000)
# Processed 64  stargazers. Num nodes/edges in graph 1152 / 1317
# Rate limit remaining (4891, 5000)
# Processed 65  stargazers. Num nodes/edges in graph 1152 / 1318
# Rate limit remaining (4890, 5000)
# Processed 66  stargazers. Num nodes/edges in graph 1152 / 1319
# Rate limit remaining (4889, 5000)
# Processed 67  stargazers. Num nodes/edges in graph 1152 / 1320
# Rate limit remaining (4888, 5000)
# Processed 68  stargazers. Num nodes/edges in graph 1152 / 1321
# Rate limit remaining (4887, 5000)
# Processed 69  stargazers. Num nodes/edges in graph 1152 / 1323
# Rate limit remaining (4885, 5000)
# Processed 70  stargazers. Num nodes/edges in graph 1152 / 1324
# Rate limit remaining (4884, 5000)
# Processed 71  stargazers. Num nodes/edges in graph 1152 / 1326
# Rate limit remaining (4883, 5000)
# Processed 72  stargazers. Num nodes/edges in graph 1152 / 1331
# Rate limit remaining (4881, 5000)
# Processed 73  stargazers. Num nodes/edges in graph 1152 / 1333
# Rate limit remaining (4880, 5000)
# Processed 74  stargazers. Num nodes/edges in graph 1152 / 1335
# Rate limit remaining (4879, 5000)
# Processed 75  stargazers. Num nodes/edges in graph 1152 / 1338
# Rate limit remaining (4877, 5000)
# Processed 76  stargazers. Num nodes/edges in graph 1152 / 1340
# Rate limit remaining (4875, 5000)
# Processed 77  stargazers. Num nodes/edges in graph 1152 / 1346
# Rate limit remaining (4873, 5000)
# Processed 78  stargazers. Num nodes/edges in graph 1152 / 1350
# Rate limit remaining (4871, 5000)
# Processed 79  stargazers. Num nodes/edges in graph 1152 / 1351
# Rate limit remaining (4870, 5000)
# Processed 80  stargazers. Num nodes/edges in graph 1152 / 1352
# Rate limit remaining (4869, 5000)
# Processed 81  stargazers. Num nodes/edges in graph 1152 / 1353
# Rate limit remaining (4868, 5000)
# Processed 82  stargazers. Num nodes/edges in graph 1152 / 1355
# Rate limit remaining (4867, 5000)
# Processed 83  stargazers. Num nodes/edges in graph 1152 / 1357
# Rate limit remaining (4866, 5000)
# Processed 84  stargazers. Num nodes/edges in graph 1152 / 1365
# Rate limit remaining (4863, 5000)
# Processed 85  stargazers. Num nodes/edges in graph 1152 / 1367
# Rate limit remaining (4862, 5000)
# Processed 86  stargazers. Num nodes/edges in graph 1152 / 1368
# Rate limit remaining (4861, 5000)
# Processed 87  stargazers. Num nodes/edges in graph 1152 / 1373
# Rate limit remaining (4858, 5000)
# Processed 88  stargazers. Num nodes/edges in graph 1152 / 1376
# Rate limit remaining (4857, 5000)
# Processed 89  stargazers. Num nodes/edges in graph 1152 / 1378
# Rate limit remaining (4856, 5000)
# Processed 90  stargazers. Num nodes/edges in graph 1152 / 1379
# Rate limit remaining (4855, 5000)
# Processed 91  stargazers. Num nodes/edges in graph 1152 / 1384
# Rate limit remaining (4853, 5000)
# Processed 92  stargazers. Num nodes/edges in graph 1152 / 1385
# Rate limit remaining (4852, 5000)
# Processed 93  stargazers. Num nodes/edges in graph 1152 / 1389
# Rate limit remaining (4851, 5000)
# Processed 94  stargazers. Num nodes/edges in graph 1152 / 1390
# Rate limit remaining (4850, 5000)
# Processed 95  stargazers. Num nodes/edges in graph 1152 / 1391
# Rate limit remaining (4849, 5000)
# Processed 96  stargazers. Num nodes/edges in graph 1152 / 1394
# Rate limit remaining (4848, 5000)
# Processed 97  stargazers. Num nodes/edges in graph 1152 / 1395
# Rate limit remaining (4847, 5000)
# Processed 98  stargazers. Num nodes/edges in graph 1152 / 1396
# Rate limit remaining (4846, 5000)
# Processed 99  stargazers. Num nodes/edges in graph 1152 / 1401
# Rate limit remaining (4842, 5000)
# Processed 100  stargazers. Num nodes/edges in graph 1152 / 1404
# Rate limit remaining (4841, 5000)
# Processed 101  stargazers. Num nodes/edges in graph 1152 / 1405
# Rate limit remaining (4840, 5000)
# Processed 102  stargazers. Num nodes/edges in graph 1152 / 1409
# Rate limit remaining (4837, 5000)
# Processed 103  stargazers. Num nodes/edges in graph 1152 / 1410
# Rate limit remaining (4836, 5000)
# Processed 104  stargazers. Num nodes/edges in graph 1152 / 1411
# Rate limit remaining (4835, 5000)
# Processed 105  stargazers. Num nodes/edges in graph 1152 / 1414
# Rate limit remaining (4834, 5000)
# Processed 106  stargazers. Num nodes/edges in graph 1152 / 1415
# Rate limit remaining (4833, 5000)
# Processed 107  stargazers. Num nodes/edges in graph 1152 / 1416
# Rate limit remaining (4832, 5000)
# Processed 108  stargazers. Num nodes/edges in graph 1152 / 1417
# Rate limit remaining (4831, 5000)
# Processed 109  stargazers. Num nodes/edges in graph 1152 / 1418
# Rate limit remaining (4830, 5000)
# Processed 110  stargazers. Num nodes/edges in graph 1152 / 1419
# Rate limit remaining (4829, 5000)
# Processed 111  stargazers. Num nodes/edges in graph 1152 / 1420
# Rate limit remaining (4828, 5000)
# Processed 112  stargazers. Num nodes/edges in graph 1152 / 1423
# Rate limit remaining (4827, 5000)
# Processed 113  stargazers. Num nodes/edges in graph 1152 / 1424
# Rate limit remaining (4826, 5000)
# Processed 114  stargazers. Num nodes/edges in graph 1152 / 1428
# Rate limit remaining (4824, 5000)
# Processed 115  stargazers. Num nodes/edges in graph 1152 / 1429
# Rate limit remaining (4823, 5000)
# Processed 116  stargazers. Num nodes/edges in graph 1152 / 1437
# Rate limit remaining (4822, 5000)
# Processed 117  stargazers. Num nodes/edges in graph 1152 / 1438
# Rate limit remaining (4821, 5000)
# Processed 118  stargazers. Num nodes/edges in graph 1152 / 1439
# Rate limit remaining (4820, 5000)
# Processed 119  stargazers. Num nodes/edges in graph 1152 / 1440
# Rate limit remaining (4819, 5000)
# Processed 120  stargazers. Num nodes/edges in graph 1152 / 1446
# Rate limit remaining (4817, 5000)
# Processed 121  stargazers. Num nodes/edges in graph 1152 / 1450
# Rate limit remaining (4813, 5000)
# Processed 122  stargazers. Num nodes/edges in graph 1152 / 1453
# Rate limit remaining (4812, 5000)
# Processed 123  stargazers. Num nodes/edges in graph 1152 / 1454
# Rate limit remaining (4811, 5000)
# Processed 124  stargazers. Num nodes/edges in graph 1152 / 1455
# Rate limit remaining (4810, 5000)
# Processed 125  stargazers. Num nodes/edges in graph 1152 / 1456
# Rate limit remaining (4809, 5000)
# Processed 126  stargazers. Num nodes/edges in graph 1152 / 1457
# Rate limit remaining (4808, 5000)
# Processed 127  stargazers. Num nodes/edges in graph 1152 / 1458
# Rate limit remaining (4807, 5000)
# Processed 128  stargazers. Num nodes/edges in graph 1152 / 1459
# Rate limit remaining (4806, 5000)
# Processed 129  stargazers. Num nodes/edges in graph 1152 / 1459
# Rate limit remaining (4805, 5000)
# Processed 130  stargazers. Num nodes/edges in graph 1152 / 1461
# Rate limit remaining (4804, 5000)
# Processed 131  stargazers. Num nodes/edges in graph 1152 / 1461
# Rate limit remaining (4803, 5000)
# Processed 132  stargazers. Num nodes/edges in graph 1152 / 1463
# Rate limit remaining (4802, 5000)
# Processed 133  stargazers. Num nodes/edges in graph 1152 / 1463
# Rate limit remaining (4801, 5000)
# Processed 134  stargazers. Num nodes/edges in graph 1152 / 1464
# Rate limit remaining (4800, 5000)
# Processed 135  stargazers. Num nodes/edges in graph 1152 / 1465
# Rate limit remaining (4799, 5000)
# Processed 136  stargazers. Num nodes/edges in graph 1152 / 1466
# Rate limit remaining (4798, 5000)
# Processed 137  stargazers. Num nodes/edges in graph 1152 / 1470
# Rate limit remaining (4789, 5000)
# Processed 138  stargazers. Num nodes/edges in graph 1152 / 1471
# Rate limit remaining (4788, 5000)
# Processed 139  stargazers. Num nodes/edges in graph 1152 / 1471
# Rate limit remaining (4787, 5000)
# Processed 140  stargazers. Num nodes/edges in graph 1152 / 1472
# Rate limit remaining (4786, 5000)
# Processed 141  stargazers. Num nodes/edges in graph 1152 / 1476
# Rate limit remaining (4784, 5000)
# Processed 142  stargazers. Num nodes/edges in graph 1152 / 1476
# Rate limit remaining (4783, 5000)
# Processed 143  stargazers. Num nodes/edges in graph 1152 / 1478
# Rate limit remaining (4782, 5000)
# Processed 144  stargazers. Num nodes/edges in graph 1152 / 1478
# Rate limit remaining (4781, 5000)
# Processed 145  stargazers. Num nodes/edges in graph 1152 / 1478
# Rate limit remaining (4780, 5000)
# Processed 146  stargazers. Num nodes/edges in graph 1152 / 1478
# Rate limit remaining (4779, 5000)
# Processed 147  stargazers. Num nodes/edges in graph 1152 / 1479
# Rate limit remaining (4778, 5000)
# Processed 148  stargazers. Num nodes/edges in graph 1152 / 1484
# Rate limit remaining (4774, 5000)
# Processed 149  stargazers. Num nodes/edges in graph 1152 / 1486
# Rate limit remaining (4773, 5000)
# Processed 150  stargazers. Num nodes/edges in graph 1152 / 1488
# Rate limit remaining (4772, 5000)
# Processed 151  stargazers. Num nodes/edges in graph 1152 / 1615
# Rate limit remaining (4764, 5000)
# Processed 152  stargazers. Num nodes/edges in graph 1152 / 1617
# Rate limit remaining (4762, 5000)
# Processed 153  stargazers. Num nodes/edges in graph 1152 / 1618
# Rate limit remaining (4761, 5000)
# Processed 154  stargazers. Num nodes/edges in graph 1152 / 1619
# Rate limit remaining (4760, 5000)
# Processed 155  stargazers. Num nodes/edges in graph 1152 / 1622
# Rate limit remaining (4757, 5000)
# Processed 156  stargazers. Num nodes/edges in graph 1152 / 1622
# Rate limit remaining (4756, 5000)
# Processed 157  stargazers. Num nodes/edges in graph 1152 / 1622
# Rate limit remaining (4755, 5000)
# Processed 158  stargazers. Num nodes/edges in graph 1152 / 1622
# Rate limit remaining (4754, 5000)
# Processed 159  stargazers. Num nodes/edges in graph 1152 / 1624
# Rate limit remaining (4752, 5000)
# Processed 160  stargazers. Num nodes/edges in graph 1152 / 1626
# Rate limit remaining (4750, 5000)
# Processed 161  stargazers. Num nodes/edges in graph 1152 / 1627
# Rate limit remaining (4749, 5000)
# Processed 162  stargazers. Num nodes/edges in graph 1152 / 1627
# Rate limit remaining (4748, 5000)
# Processed 163  stargazers. Num nodes/edges in graph 1152 / 1627
# Rate limit remaining (4747, 5000)
# Processed 164  stargazers. Num nodes/edges in graph 1152 / 1630
# Rate limit remaining (4746, 5000)
# Processed 165  stargazers. Num nodes/edges in graph 1152 / 1633
# Rate limit remaining (4745, 5000)
# Processed 166  stargazers. Num nodes/edges in graph 1152 / 1634
# Rate limit remaining (4744, 5000)
# Processed 167  stargazers. Num nodes/edges in graph 1152 / 1634
# Rate limit remaining (4742, 5000)
# Processed 168  stargazers. Num nodes/edges in graph 1152 / 1634
# Rate limit remaining (4741, 5000)
# Processed 169  stargazers. Num nodes/edges in graph 1152 / 1637
# Rate limit remaining (4740, 5000)
# Processed 170  stargazers. Num nodes/edges in graph 1152 / 1803
# Rate limit remaining (4521, 5000)
# Processed 171  stargazers. Num nodes/edges in graph 1152 / 1803
# Rate limit remaining (4520, 5000)
# Processed 172  stargazers. Num nodes/edges in graph 1152 / 1804
# Rate limit remaining (4519, 5000)
# Processed 173  stargazers. Num nodes/edges in graph 1152 / 1806
# Rate limit remaining (4517, 5000)
# Processed 174  stargazers. Num nodes/edges in graph 1152 / 1807
# Rate limit remaining (4516, 5000)
# Processed 175  stargazers. Num nodes/edges in graph 1152 / 1810
# Rate limit remaining (4515, 5000)
# Processed 176  stargazers. Num nodes/edges in graph 1152 / 1810
# Rate limit remaining (4514, 5000)
# Processed 177  stargazers. Num nodes/edges in graph 1152 / 1810
# Rate limit remaining (4513, 5000)
# Processed 178  stargazers. Num nodes/edges in graph 1152 / 1812
# Rate limit remaining (4512, 5000)
# Processed 179  stargazers. Num nodes/edges in graph 1152 / 1814
# Rate limit remaining (4511, 5000)
# Processed 180  stargazers. Num nodes/edges in graph 1152 / 1817
# Rate limit remaining (4509, 5000)
# Processed 181  stargazers. Num nodes/edges in graph 1152 / 1817
# Rate limit remaining (4508, 5000)
# Processed 182  stargazers. Num nodes/edges in graph 1152 / 1825
# Rate limit remaining (4506, 5000)
# Processed 183  stargazers. Num nodes/edges in graph 1152 / 1832
# Rate limit remaining (4504, 5000)
# Processed 184  stargazers. Num nodes/edges in graph 1152 / 1832
# Rate limit remaining (4503, 5000)
# Processed 185  stargazers. Num nodes/edges in graph 1152 / 1833
# Rate limit remaining (4502, 5000)
# Processed 186  stargazers. Num nodes/edges in graph 1152 / 1838
# Rate limit remaining (4499, 5000)
# Processed 187  stargazers. Num nodes/edges in graph 1152 / 1838
# Rate limit remaining (4498, 5000)
# Processed 188  stargazers. Num nodes/edges in graph 1152 / 1838
# Rate limit remaining (4497, 5000)
# Processed 189  stargazers. Num nodes/edges in graph 1152 / 1838
# Rate limit remaining (4496, 5000)
# Processed 190  stargazers. Num nodes/edges in graph 1152 / 1839
# Rate limit remaining (4495, 5000)
# Processed 191  stargazers. Num nodes/edges in graph 1152 / 1846
# Rate limit remaining (4493, 5000)
# Processed 192  stargazers. Num nodes/edges in graph 1152 / 1847
# Rate limit remaining (4492, 5000)
# Processed 193  stargazers. Num nodes/edges in graph 1152 / 1847
# Rate limit remaining (4491, 5000)
# Processed 194  stargazers. Num nodes/edges in graph 1152 / 1848
# Rate limit remaining (4490, 5000)
# Processed 195  stargazers. Num nodes/edges in graph 1152 / 1848
# Rate limit remaining (4489, 5000)
# Processed 196  stargazers. Num nodes/edges in graph 1152 / 1848
# Rate limit remaining (4488, 5000)
# Processed 197  stargazers. Num nodes/edges in graph 1152 / 1849
# Rate limit remaining (4487, 5000)
# Processed 198  stargazers. Num nodes/edges in graph 1152 / 1850
# Rate limit remaining (4486, 5000)
# Processed 199  stargazers. Num nodes/edges in graph 1152 / 1850
# Rate limit remaining (4485, 5000)
# Processed 200  stargazers. Num nodes/edges in graph 1152 / 1851
# Rate limit remaining (4484, 5000)
# Processed 201  stargazers. Num nodes/edges in graph 1152 / 1852
# Rate limit remaining (4483, 5000)
# Processed 202  stargazers. Num nodes/edges in graph 1152 / 1856
# Rate limit remaining (4482, 5000)
# Processed 203  stargazers. Num nodes/edges in graph 1152 / 1856
# Rate limit remaining (4481, 5000)
# Processed 204  stargazers. Num nodes/edges in graph 1152 / 1857
# Rate limit remaining (4480, 5000)
# Processed 205  stargazers. Num nodes/edges in graph 1152 / 1858
# Rate limit remaining (4479, 5000)
# Processed 206  stargazers. Num nodes/edges in graph 1152 / 1859
# Rate limit remaining (4478, 5000)
# Processed 207  stargazers. Num nodes/edges in graph 1152 / 1860
# Rate limit remaining (4477, 5000)
# Processed 208  stargazers. Num nodes/edges in graph 1152 / 1861
# Rate limit remaining (4476, 5000)
# Processed 209  stargazers. Num nodes/edges in graph 1152 / 1861
# Rate limit remaining (4475, 5000)
# Processed 210  stargazers. Num nodes/edges in graph 1152 / 1861
# Rate limit remaining (4474, 5000)
# Processed 211  stargazers. Num nodes/edges in graph 1152 / 1862
# Rate limit remaining (4473, 5000)
# Processed 212  stargazers. Num nodes/edges in graph 1152 / 1863
# Rate limit remaining (4472, 5000)
# Processed 213  stargazers. Num nodes/edges in graph 1152 / 1870
# Rate limit remaining (4470, 5000)
# Processed 214  stargazers. Num nodes/edges in graph 1152 / 1872
# Rate limit remaining (4469, 5000)
# Processed 215  stargazers. Num nodes/edges in graph 1152 / 1873
# Rate limit remaining (4468, 5000)
# Processed 216  stargazers. Num nodes/edges in graph 1152 / 1875
# Rate limit remaining (4467, 5000)
# Processed 217  stargazers. Num nodes/edges in graph 1152 / 1877
# Rate limit remaining (4466, 5000)
# Processed 218  stargazers. Num nodes/edges in graph 1152 / 1877
# Rate limit remaining (4465, 5000)
# Processed 219  stargazers. Num nodes/edges in graph 1152 / 1877
# Rate limit remaining (4464, 5000)
# Processed 220  stargazers. Num nodes/edges in graph 1152 / 1878
# Rate limit remaining (4463, 5000)
# Processed 221  stargazers. Num nodes/edges in graph 1152 / 1879
# Rate limit remaining (4462, 5000)
# Processed 222  stargazers. Num nodes/edges in graph 1152 / 1880
# Rate limit remaining (4461, 5000)
# Processed 223  stargazers. Num nodes/edges in graph 1152 / 1880
# Rate limit remaining (4460, 5000)
# Processed 224  stargazers. Num nodes/edges in graph 1152 / 1882
# Rate limit remaining (4459, 5000)
# Processed 225  stargazers. Num nodes/edges in graph 1152 / 1885
# Rate limit remaining (4458, 5000)
# Processed 226  stargazers. Num nodes/edges in graph 1152 / 1885
# Rate limit remaining (4457, 5000)
# Processed 227  stargazers. Num nodes/edges in graph 1152 / 1885
# Rate limit remaining (4456, 5000)
# Processed 228  stargazers. Num nodes/edges in graph 1152 / 1889
# Rate limit remaining (4453, 5000)
# Processed 229  stargazers. Num nodes/edges in graph 1152 / 1889
# Rate limit remaining (4452, 5000)
# Processed 230  stargazers. Num nodes/edges in graph 1152 / 1891
# Rate limit remaining (4451, 5000)
# Processed 231  stargazers. Num nodes/edges in graph 1152 / 1893
# Rate limit remaining (4450, 5000)
# Processed 232  stargazers. Num nodes/edges in graph 1152 / 1893
# Rate limit remaining (4449, 5000)
# Processed 233  stargazers. Num nodes/edges in graph 1152 / 1893
# Rate limit remaining (4448, 5000)
# Processed 234  stargazers. Num nodes/edges in graph 1152 / 1894
# Rate limit remaining (4447, 5000)
# Processed 235  stargazers. Num nodes/edges in graph 1152 / 1899
# Rate limit remaining (4446, 5000)
# Processed 236  stargazers. Num nodes/edges in graph 1152 / 1901
# Rate limit remaining (4445, 5000)
# Processed 237  stargazers. Num nodes/edges in graph 1152 / 1903
# Rate limit remaining (4444, 5000)
# Processed 238  stargazers. Num nodes/edges in graph 1152 / 1904
# Rate limit remaining (4443, 5000)
# Processed 239  stargazers. Num nodes/edges in graph 1152 / 1905
# Rate limit remaining (4442, 5000)
# Processed 240  stargazers. Num nodes/edges in graph 1152 / 1905
# Rate limit remaining (4441, 5000)
# Processed 241  stargazers. Num nodes/edges in graph 1152 / 1906
# Rate limit remaining (4440, 5000)
# Processed 242  stargazers. Num nodes/edges in graph 1152 / 1907
# Rate limit remaining (4439, 5000)
# Processed 243  stargazers. Num nodes/edges in graph 1152 / 1907
# Rate limit remaining (4438, 5000)
# Processed 244  stargazers. Num nodes/edges in graph 1152 / 1908
# Rate limit remaining (4437, 5000)
# Processed 245  stargazers. Num nodes/edges in graph 1152 / 1908
# Rate limit remaining (4436, 5000)
# Processed 246  stargazers. Num nodes/edges in graph 1152 / 1909
# Rate limit remaining (4435, 5000)
# Processed 247  stargazers. Num nodes/edges in graph 1152 / 1913
# Rate limit remaining (4434, 5000)
# Processed 248  stargazers. Num nodes/edges in graph 1152 / 1914
# Rate limit remaining (4433, 5000)
# Processed 249  stargazers. Num nodes/edges in graph 1152 / 1915
# Rate limit remaining (4432, 5000)
# Processed 250  stargazers. Num nodes/edges in graph 1152 / 1917
# Rate limit remaining (4431, 5000)
# Processed 251  stargazers. Num nodes/edges in graph 1152 / 1917
# Rate limit remaining (4430, 5000)
# Processed 252  stargazers. Num nodes/edges in graph 1152 / 1920
# Rate limit remaining (4428, 5000)
# Processed 253  stargazers. Num nodes/edges in graph 1152 / 1921
# Rate limit remaining (4427, 5000)
# Processed 254  stargazers. Num nodes/edges in graph 1152 / 1939
# Rate limit remaining (4425, 5000)
# Processed 255  stargazers. Num nodes/edges in graph 1152 / 1941
# Rate limit remaining (4424, 5000)
# Processed 256  stargazers. Num nodes/edges in graph 1152 / 1942
# Rate limit remaining (4423, 5000)
# Processed 257  stargazers. Num nodes/edges in graph 1152 / 1942
# Rate limit remaining (4422, 5000)
# Processed 258  stargazers. Num nodes/edges in graph 1152 / 1943
# Rate limit remaining (4421, 5000)
# Processed 259  stargazers. Num nodes/edges in graph 1152 / 1943
# Rate limit remaining (4420, 5000)
# Processed 260  stargazers. Num nodes/edges in graph 1152 / 1944
# Rate limit remaining (4419, 5000)
# Processed 261  stargazers. Num nodes/edges in graph 1152 / 1945
# Rate limit remaining (4418, 5000)
# Processed 262  stargazers. Num nodes/edges in graph 1152 / 1946
# Rate limit remaining (4417, 5000)
# Processed 263  stargazers. Num nodes/edges in graph 1152 / 1946
# Rate limit remaining (4416, 5000)
# Processed 264  stargazers. Num nodes/edges in graph 1152 / 1946
# Rate limit remaining (4415, 5000)
# Processed 265  stargazers. Num nodes/edges in graph 1152 / 1948
# Rate limit remaining (4414, 5000)
# Processed 266  stargazers. Num nodes/edges in graph 1152 / 1948
# Rate limit remaining (4413, 5000)
# Processed 267  stargazers. Num nodes/edges in graph 1152 / 1949
# Rate limit remaining (4412, 5000)
# Processed 268  stargazers. Num nodes/edges in graph 1152 / 1949
# Rate limit remaining (4411, 5000)
# Processed 269  stargazers. Num nodes/edges in graph 1152 / 1949
# Rate limit remaining (4410, 5000)
# Processed 270  stargazers. Num nodes/edges in graph 1152 / 1950
# Rate limit remaining (4409, 5000)
# Processed 271  stargazers. Num nodes/edges in graph 1152 / 1950
# Rate limit remaining (4408, 5000)
# Processed 272  stargazers. Num nodes/edges in graph 1152 / 1950
# Rate limit remaining (4407, 5000)
# Processed 273  stargazers. Num nodes/edges in graph 1152 / 1951
# Rate limit remaining (4406, 5000)
# Processed 274  stargazers. Num nodes/edges in graph 1152 / 1952
# Rate limit remaining (4405, 5000)
# Processed 275  stargazers. Num nodes/edges in graph 1152 / 1953
# Rate limit remaining (4404, 5000)
# Processed 276  stargazers. Num nodes/edges in graph 1152 / 1953
# Rate limit remaining (4403, 5000)
# Processed 277  stargazers. Num nodes/edges in graph 1152 / 1953
# Rate limit remaining (4402, 5000)
# Processed 278  stargazers. Num nodes/edges in graph 1152 / 1954
# Rate limit remaining (4401, 5000)
# Processed 279  stargazers. Num nodes/edges in graph 1152 / 1955
# Rate limit remaining (4400, 5000)
# Processed 280  stargazers. Num nodes/edges in graph 1152 / 1958
# Rate limit remaining (4399, 5000)
# Processed 281  stargazers. Num nodes/edges in graph 1152 / 1958
# Rate limit remaining (4398, 5000)
# Processed 282  stargazers. Num nodes/edges in graph 1152 / 1959
# Rate limit remaining (4397, 5000)
# Processed 283  stargazers. Num nodes/edges in graph 1152 / 1960
# Rate limit remaining (4396, 5000)
# Processed 284  stargazers. Num nodes/edges in graph 1152 / 1960
# Rate limit remaining (4395, 5000)
# Processed 285  stargazers. Num nodes/edges in graph 1152 / 1960
# Rate limit remaining (4394, 5000)
# Processed 286  stargazers. Num nodes/edges in graph 1152 / 1966
# Rate limit remaining (4392, 5000)
# Processed 287  stargazers. Num nodes/edges in graph 1152 / 1970
# Rate limit remaining (4391, 5000)
# Processed 288  stargazers. Num nodes/edges in graph 1152 / 1970
# Rate limit remaining (4390, 5000)
# Processed 289  stargazers. Num nodes/edges in graph 1152 / 1971
# Rate limit remaining (4389, 5000)
# Processed 290  stargazers. Num nodes/edges in graph 1152 / 1971
# Rate limit remaining (4388, 5000)
# Processed 291  stargazers. Num nodes/edges in graph 1152 / 1971
# Rate limit remaining (4387, 5000)
# Processed 292  stargazers. Num nodes/edges in graph 1152 / 1971
# Rate limit remaining (4386, 5000)
# Processed 293  stargazers. Num nodes/edges in graph 1152 / 1971
# Rate limit remaining (4385, 5000)
# Processed 294  stargazers. Num nodes/edges in graph 1152 / 1973
# Rate limit remaining (4384, 5000)
# Processed 295  stargazers. Num nodes/edges in graph 1152 / 1973
# Rate limit remaining (4383, 5000)
# Processed 296  stargazers. Num nodes/edges in graph 1152 / 1974
# Rate limit remaining (4382, 5000)
# Processed 297  stargazers. Num nodes/edges in graph 1152 / 1974
# Rate limit remaining (4381, 5000)
# Processed 298  stargazers. Num nodes/edges in graph 1152 / 1975
# Rate limit remaining (4380, 5000)
# Processed 299  stargazers. Num nodes/edges in graph 1152 / 1975
# Rate limit remaining (4379, 5000)
# Processed 300  stargazers. Num nodes/edges in graph 1152 / 1976
# Rate limit remaining (4378, 5000)
# Processed 301  stargazers. Num nodes/edges in graph 1152 / 1977
# Rate limit remaining (4377, 5000)
# Processed 302  stargazers. Num nodes/edges in graph 1152 / 1978
# Rate limit remaining (4376, 5000)
# Processed 303  stargazers. Num nodes/edges in graph 1152 / 1978
# Rate limit remaining (4375, 5000)
# Processed 304  stargazers. Num nodes/edges in graph 1152 / 1978
# Rate limit remaining (4374, 5000)
# Processed 305  stargazers. Num nodes/edges in graph 1152 / 1982
# Rate limit remaining (4372, 5000)
# Processed 306  stargazers. Num nodes/edges in graph 1152 / 1982
# Rate limit remaining (4371, 5000)
# Processed 307  stargazers. Num nodes/edges in graph 1152 / 1982
# Rate limit remaining (4370, 5000)
# Processed 308  stargazers. Num nodes/edges in graph 1152 / 1982
# Rate limit remaining (4369, 5000)
# Processed 309  stargazers. Num nodes/edges in graph 1152 / 1984
# Rate limit remaining (4368, 5000)
# Processed 310  stargazers. Num nodes/edges in graph 1152 / 1984
# Rate limit remaining (4367, 5000)
# Processed 311  stargazers. Num nodes/edges in graph 1152 / 1984
# Rate limit remaining (4366, 5000)
# Processed 312  stargazers. Num nodes/edges in graph 1152 / 1987
# Rate limit remaining (4365, 5000)
# Processed 313  stargazers. Num nodes/edges in graph 1152 / 1987
# Rate limit remaining (4364, 5000)
# Processed 314  stargazers. Num nodes/edges in graph 1152 / 1990
# Rate limit remaining (4363, 5000)
# Processed 315  stargazers. Num nodes/edges in graph 1152 / 1990
# Rate limit remaining (4362, 5000)
# Processed 316  stargazers. Num nodes/edges in graph 1152 / 1991
# Rate limit remaining (4361, 5000)
# Processed 317  stargazers. Num nodes/edges in graph 1152 / 1996
# Rate limit remaining (4359, 5000)
# Processed 318  stargazers. Num nodes/edges in graph 1152 / 2000
# Rate limit remaining (4356, 5000)
# Processed 319  stargazers. Num nodes/edges in graph 1152 / 2001
# Rate limit remaining (4355, 5000)
# Processed 320  stargazers. Num nodes/edges in graph 1152 / 2021
# Rate limit remaining (4344, 5000)
# Processed 321  stargazers. Num nodes/edges in graph 1152 / 2023
# Rate limit remaining (4343, 5000)
# Processed 322  stargazers. Num nodes/edges in graph 1152 / 2023
# Rate limit remaining (4342, 5000)
# Processed 323  stargazers. Num nodes/edges in graph 1152 / 2023
# Rate limit remaining (4341, 5000)
# Processed 324  stargazers. Num nodes/edges in graph 1152 / 2023
# Rate limit remaining (4340, 5000)
# Processed 325  stargazers. Num nodes/edges in graph 1152 / 2026
# Rate limit remaining (4338, 5000)
# Processed 326  stargazers. Num nodes/edges in graph 1152 / 2026
# Rate limit remaining (4337, 5000)
# Processed 327  stargazers. Num nodes/edges in graph 1152 / 2026
# Rate limit remaining (4336, 5000)
# Processed 328  stargazers. Num nodes/edges in graph 1152 / 2026
# Rate limit remaining (4335, 5000)
# Processed 329  stargazers. Num nodes/edges in graph 1152 / 2026
# Rate limit remaining (4334, 5000)
# Processed 330  stargazers. Num nodes/edges in graph 1152 / 2026
# Rate limit remaining (4333, 5000)
# Processed 331  stargazers. Num nodes/edges in graph 1152 / 2026
# Rate limit remaining (4332, 5000)
# Processed 332  stargazers. Num nodes/edges in graph 1152 / 2027
# Rate limit remaining (4331, 5000)
# Processed 333  stargazers. Num nodes/edges in graph 1152 / 2027
# Rate limit remaining (4330, 5000)
# Processed 334  stargazers. Num nodes/edges in graph 1152 / 2028
# Rate limit remaining (4329, 5000)
# Processed 335  stargazers. Num nodes/edges in graph 1152 / 2028
# Rate limit remaining (4328, 5000)
# Processed 336  stargazers. Num nodes/edges in graph 1152 / 2028
# Rate limit remaining (4327, 5000)
# Processed 337  stargazers. Num nodes/edges in graph 1152 / 2028
# Rate limit remaining (4326, 5000)
# Processed 338  stargazers. Num nodes/edges in graph 1152 / 2028
# Rate limit remaining (4325, 5000)
# Processed 339  stargazers. Num nodes/edges in graph 1152 / 2028
# Rate limit remaining (4324, 5000)
# Processed 340  stargazers. Num nodes/edges in graph 1152 / 2028
# Rate limit remaining (4323, 5000)
# Processed 341  stargazers. Num nodes/edges in graph 1152 / 2037
# Rate limit remaining (4321, 5000)
# Processed 342  stargazers. Num nodes/edges in graph 1152 / 2042
# Rate limit remaining (4318, 5000)
# Processed 343  stargazers. Num nodes/edges in graph 1152 / 2042
# Rate limit remaining (4317, 5000)
# Processed 344  stargazers. Num nodes/edges in graph 1152 / 2043
# Rate limit remaining (4316, 5000)
# Processed 345  stargazers. Num nodes/edges in graph 1152 / 2044
# Rate limit remaining (4315, 5000)
# Processed 346  stargazers. Num nodes/edges in graph 1152 / 2046
# Rate limit remaining (4314, 5000)
# Processed 347  stargazers. Num nodes/edges in graph 1152 / 2046
# Rate limit remaining (4313, 5000)
# Processed 348  stargazers. Num nodes/edges in graph 1152 / 2046
# Rate limit remaining (4312, 5000)
# Processed 349  stargazers. Num nodes/edges in graph 1152 / 2046
# Rate limit remaining (4311, 5000)
# Processed 350  stargazers. Num nodes/edges in graph 1152 / 2046
# Rate limit remaining (4310, 5000)
# Processed 351  stargazers. Num nodes/edges in graph 1152 / 2050
# Rate limit remaining (4308, 5000)
# Processed 352  stargazers. Num nodes/edges in graph 1152 / 2051
# Rate limit remaining (4307, 5000)
# Processed 353  stargazers. Num nodes/edges in graph 1152 / 2051
# Rate limit remaining (4306, 5000)
# Processed 354  stargazers. Num nodes/edges in graph 1152 / 2052
# Rate limit remaining (4303, 5000)
# Processed 355  stargazers. Num nodes/edges in graph 1152 / 2052
# Rate limit remaining (4302, 5000)
# Processed 356  stargazers. Num nodes/edges in graph 1152 / 2053
# Rate limit remaining (4301, 5000)
# Processed 357  stargazers. Num nodes/edges in graph 1152 / 2056
# Rate limit remaining (4300, 5000)
# Processed 358  stargazers. Num nodes/edges in graph 1152 / 2056
# Rate limit remaining (4299, 5000)
# Processed 359  stargazers. Num nodes/edges in graph 1152 / 2056
# Rate limit remaining (4298, 5000)
# Processed 360  stargazers. Num nodes/edges in graph 1152 / 2057
# Rate limit remaining (4297, 5000)
# Processed 361  stargazers. Num nodes/edges in graph 1152 / 2059
# Rate limit remaining (4296, 5000)
# Processed 362  stargazers. Num nodes/edges in graph 1152 / 2059
# Rate limit remaining (4295, 5000)
# Processed 363  stargazers. Num nodes/edges in graph 1152 / 2060
# Rate limit remaining (4294, 5000)
# Processed 364  stargazers. Num nodes/edges in graph 1152 / 2061
# Rate limit remaining (4293, 5000)
# Processed 365  stargazers. Num nodes/edges in graph 1152 / 2064
# Rate limit remaining (4292, 5000)
# Processed 366  stargazers. Num nodes/edges in graph 1152 / 2065
# Rate limit remaining (4291, 5000)
# Processed 367  stargazers. Num nodes/edges in graph 1152 / 2065
# Rate limit remaining (4290, 5000)
# Processed 368  stargazers. Num nodes/edges in graph 1152 / 2068
# Rate limit remaining (4287, 5000)
# Processed 369  stargazers. Num nodes/edges in graph 1152 / 2068
# Rate limit remaining (4286, 5000)
# Processed 370  stargazers. Num nodes/edges in graph 1152 / 2069
# Rate limit remaining (4285, 5000)
# Processed 371  stargazers. Num nodes/edges in graph 1152 / 2070
# Rate limit remaining (4284, 5000)
# Processed 372  stargazers. Num nodes/edges in graph 1152 / 2072
# Rate limit remaining (4283, 5000)
# Processed 373  stargazers. Num nodes/edges in graph 1152 / 2073
# Rate limit remaining (4282, 5000)
# Processed 374  stargazers. Num nodes/edges in graph 1152 / 2073
# Rate limit remaining (4281, 5000)
# Processed 375  stargazers. Num nodes/edges in graph 1152 / 2074
# Rate limit remaining (4280, 5000)
# Processed 376  stargazers. Num nodes/edges in graph 1152 / 2074
# Rate limit remaining (4279, 5000)
# Processed 377  stargazers. Num nodes/edges in graph 1152 / 2075
# Rate limit remaining (4278, 5000)
# Processed 378  stargazers. Num nodes/edges in graph 1152 / 2075
# Rate limit remaining (4277, 5000)
# Processed 379  stargazers. Num nodes/edges in graph 1152 / 2075
# Rate limit remaining (4276, 5000)
# Processed 380  stargazers. Num nodes/edges in graph 1152 / 2076
# Rate limit remaining (4275, 5000)
# Processed 381  stargazers. Num nodes/edges in graph 1152 / 2076
# Rate limit remaining (4274, 5000)
# Processed 382  stargazers. Num nodes/edges in graph 1152 / 2082
# Rate limit remaining (4271, 5000)
# Processed 383  stargazers. Num nodes/edges in graph 1152 / 2082
# Rate limit remaining (4270, 5000)
# Processed 384  stargazers. Num nodes/edges in graph 1152 / 2082
# Rate limit remaining (4269, 5000)
# Processed 385  stargazers. Num nodes/edges in graph 1152 / 2082
# Rate limit remaining (4268, 5000)
# Processed 386  stargazers. Num nodes/edges in graph 1152 / 2083
# Rate limit remaining (4267, 5000)
# Processed 387  stargazers. Num nodes/edges in graph 1152 / 2083
# Rate limit remaining (4266, 5000)
# Processed 388  stargazers. Num nodes/edges in graph 1152 / 2084
# Rate limit remaining (4265, 5000)
# Processed 389  stargazers. Num nodes/edges in graph 1152 / 2087
# Rate limit remaining (4264, 5000)
# Processed 390  stargazers. Num nodes/edges in graph 1152 / 2090
# Rate limit remaining (4263, 5000)
# Processed 391  stargazers. Num nodes/edges in graph 1152 / 2090
# Rate limit remaining (4262, 5000)
# Processed 392  stargazers. Num nodes/edges in graph 1152 / 2090
# Rate limit remaining (4261, 5000)
# Processed 393  stargazers. Num nodes/edges in graph 1152 / 2092
# Rate limit remaining (4260, 5000)
# Processed 394  stargazers. Num nodes/edges in graph 1152 / 2092
# Rate limit remaining (4259, 5000)
# Processed 395  stargazers. Num nodes/edges in graph 1152 / 2092
# Rate limit remaining (4258, 5000)
# Processed 396  stargazers. Num nodes/edges in graph 1152 / 2092
# Rate limit remaining (4257, 5000)
# Processed 397  stargazers. Num nodes/edges in graph 1152 / 2096
# Rate limit remaining (4253, 5000)
# Processed 398  stargazers. Num nodes/edges in graph 1152 / 2096
# Rate limit remaining (4252, 5000)
# Processed 399  stargazers. Num nodes/edges in graph 1152 / 2097
# Rate limit remaining (4251, 5000)
# Processed 400  stargazers. Num nodes/edges in graph 1152 / 2098
# Rate limit remaining (4250, 5000)
# Processed 401  stargazers. Num nodes/edges in graph 1152 / 2098
# Rate limit remaining (4249, 5000)
# Processed 402  stargazers. Num nodes/edges in graph 1152 / 2098
# Rate limit remaining (4248, 5000)
# Processed 403  stargazers. Num nodes/edges in graph 1152 / 2098
# Rate limit remaining (4247, 5000)
# Processed 404  stargazers. Num nodes/edges in graph 1152 / 2098
# Rate limit remaining (4246, 5000)
# Processed 405  stargazers. Num nodes/edges in graph 1152 / 2099
# Rate limit remaining (4245, 5000)
# Processed 406  stargazers. Num nodes/edges in graph 1152 / 2100
# Rate limit remaining (4244, 5000)
# Processed 407  stargazers. Num nodes/edges in graph 1152 / 2100
# Rate limit remaining (4243, 5000)
# Processed 408  stargazers. Num nodes/edges in graph 1152 / 2101
# Rate limit remaining (4242, 5000)
# Processed 409  stargazers. Num nodes/edges in graph 1152 / 2101
# Rate limit remaining (4241, 5000)
# Processed 410  stargazers. Num nodes/edges in graph 1152 / 2101
# Rate limit remaining (4240, 5000)
# Processed 411  stargazers. Num nodes/edges in graph 1152 / 2102
# Rate limit remaining (4239, 5000)
# Processed 412  stargazers. Num nodes/edges in graph 1152 / 2102
# Rate limit remaining (4238, 5000)
# Processed 413  stargazers. Num nodes/edges in graph 1152 / 2102
# Rate limit remaining (4237, 5000)
# Processed 414  stargazers. Num nodes/edges in graph 1152 / 2102
# Rate limit remaining (4236, 5000)
# Processed 415  stargazers. Num nodes/edges in graph 1152 / 2103
# Rate limit remaining (4235, 5000)
# Processed 416  stargazers. Num nodes/edges in graph 1152 / 2103
# Rate limit remaining (4234, 5000)
# Processed 417  stargazers. Num nodes/edges in graph 1152 / 2103
# Rate limit remaining (4233, 5000)
# Processed 418  stargazers. Num nodes/edges in graph 1152 / 2103
# Rate limit remaining (4232, 5000)
# Processed 419  stargazers. Num nodes/edges in graph 1152 / 2103
# Rate limit remaining (4231, 5000)
# Processed 420  stargazers. Num nodes/edges in graph 1152 / 2104
# Rate limit remaining (4230, 5000)
# Processed 421  stargazers. Num nodes/edges in graph 1152 / 2107
# Rate limit remaining (4228, 5000)
# Processed 422  stargazers. Num nodes/edges in graph 1152 / 2109
# Rate limit remaining (4227, 5000)
# Processed 423  stargazers. Num nodes/edges in graph 1152 / 2109
# Rate limit remaining (4226, 5000)
# Processed 424  stargazers. Num nodes/edges in graph 1152 / 2109
# Rate limit remaining (4225, 5000)
# Processed 425  stargazers. Num nodes/edges in graph 1152 / 2109
# Rate limit remaining (4224, 5000)
# Processed 426  stargazers. Num nodes/edges in graph 1152 / 2109
# Rate limit remaining (4223, 5000)
# Processed 427  stargazers. Num nodes/edges in graph 1152 / 2111
# Rate limit remaining (4222, 5000)
# Processed 428  stargazers. Num nodes/edges in graph 1152 / 2113
# Rate limit remaining (4220, 5000)
# Processed 429  stargazers. Num nodes/edges in graph 1152 / 2113
# Rate limit remaining (4219, 5000)
# Processed 430  stargazers. Num nodes/edges in graph 1152 / 2114
# Rate limit remaining (4218, 5000)
# Processed 431  stargazers. Num nodes/edges in graph 1152 / 2115
# Rate limit remaining (4217, 5000)
# Processed 432  stargazers. Num nodes/edges in graph 1152 / 2117
# Rate limit remaining (4216, 5000)
# Processed 433  stargazers. Num nodes/edges in graph 1152 / 2117
# Rate limit remaining (4215, 5000)
# Processed 434  stargazers. Num nodes/edges in graph 1152 / 2123
# Rate limit remaining (4212, 5000)
# Processed 435  stargazers. Num nodes/edges in graph 1152 / 2123
# Rate limit remaining (4211, 5000)
# Processed 436  stargazers. Num nodes/edges in graph 1152 / 2124
# Rate limit remaining (4210, 5000)
# Processed 437  stargazers. Num nodes/edges in graph 1152 / 2125
# Rate limit remaining (4209, 5000)
# Processed 438  stargazers. Num nodes/edges in graph 1152 / 2127
# Rate limit remaining (4208, 5000)
# Processed 439  stargazers. Num nodes/edges in graph 1152 / 2129
# Rate limit remaining (4207, 5000)
# Processed 440  stargazers. Num nodes/edges in graph 1152 / 2130
# Rate limit remaining (4206, 5000)
# Processed 441  stargazers. Num nodes/edges in graph 1152 / 2130
# Rate limit remaining (4205, 5000)
# Processed 442  stargazers. Num nodes/edges in graph 1152 / 2134
# Rate limit remaining (4201, 5000)
# Processed 443  stargazers. Num nodes/edges in graph 1152 / 2134
# Rate limit remaining (4200, 5000)
# Processed 444  stargazers. Num nodes/edges in graph 1152 / 2134
# Rate limit remaining (4199, 5000)
# Processed 445  stargazers. Num nodes/edges in graph 1152 / 2138
# Rate limit remaining (4196, 5000)
# Processed 446  stargazers. Num nodes/edges in graph 1152 / 2138
# Rate limit remaining (4195, 5000)
# Processed 447  stargazers. Num nodes/edges in graph 1152 / 2138
# Rate limit remaining (4194, 5000)
# Processed 448  stargazers. Num nodes/edges in graph 1152 / 2138
# Rate limit remaining (4193, 5000)
# Processed 449  stargazers. Num nodes/edges in graph 1152 / 2139
# Rate limit remaining (4192, 5000)
# Processed 450  stargazers. Num nodes/edges in graph 1152 / 2139
# Rate limit remaining (4191, 5000)
# Processed 451  stargazers. Num nodes/edges in graph 1152 / 2140
# Rate limit remaining (4190, 5000)
# Processed 452  stargazers. Num nodes/edges in graph 1152 / 2140
# Rate limit remaining (4189, 5000)
# Processed 453  stargazers. Num nodes/edges in graph 1152 / 2141
# Rate limit remaining (4188, 5000)
# Processed 454  stargazers. Num nodes/edges in graph 1152 / 2141
# Rate limit remaining (4187, 5000)
# Processed 455  stargazers. Num nodes/edges in graph 1152 / 2142
# Rate limit remaining (4186, 5000)
# Processed 456  stargazers. Num nodes/edges in graph 1152 / 2142
# Rate limit remaining (4185, 5000)
# Processed 457  stargazers. Num nodes/edges in graph 1152 / 2143
# Rate limit remaining (4184, 5000)
# Processed 458  stargazers. Num nodes/edges in graph 1152 / 2144
# Rate limit remaining (4183, 5000)
# Processed 459  stargazers. Num nodes/edges in graph 1152 / 2144
# Rate limit remaining (4182, 5000)
# Processed 460  stargazers. Num nodes/edges in graph 1152 / 2146
# Rate limit remaining (4181, 5000)
# Processed 461  stargazers. Num nodes/edges in graph 1152 / 2146
# Rate limit remaining (4180, 5000)
# Processed 462  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4179, 5000)
# Processed 463  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4178, 5000)
# Processed 464  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4177, 5000)
# Processed 465  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4176, 5000)
# Processed 466  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4175, 5000)
# Processed 467  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4174, 5000)
# Processed 468  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4173, 5000)
# Processed 469  stargazers. Num nodes/edges in graph 1152 / 2148
# Rate limit remaining (4172, 5000)
# Processed 470  stargazers. Num nodes/edges in graph 1152 / 2150
# Rate limit remaining (4171, 5000)
# Processed 471  stargazers. Num nodes/edges in graph 1152 / 2151
# Rate limit remaining (4170, 5000)
# Processed 472  stargazers. Num nodes/edges in graph 1152 / 2151
# Rate limit remaining (4169, 5000)
# Processed 473  stargazers. Num nodes/edges in graph 1152 / 2152
# Rate limit remaining (4168, 5000)
# Processed 474  stargazers. Num nodes/edges in graph 1152 / 2153
# Rate limit remaining (4167, 5000)
# Processed 475  stargazers. Num nodes/edges in graph 1152 / 2153
# Rate limit remaining (4166, 5000)
# Processed 476  stargazers. Num nodes/edges in graph 1152 / 2154
# Rate limit remaining (4165, 5000)
# Processed 477  stargazers. Num nodes/edges in graph 1152 / 2156
# Rate limit remaining (4164, 5000)
# Processed 478  stargazers. Num nodes/edges in graph 1152 / 2157
# Rate limit remaining (4163, 5000)
# Processed 479  stargazers. Num nodes/edges in graph 1152 / 2157
# Rate limit remaining (4162, 5000)
# Processed 480  stargazers. Num nodes/edges in graph 1152 / 2160
# Rate limit remaining (4160, 5000)
# Processed 481  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4159, 5000)
# Processed 482  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4158, 5000)
# Processed 483  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4157, 5000)
# Processed 484  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4156, 5000)
# Processed 485  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4155, 5000)
# Processed 486  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4154, 5000)
# Processed 487  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4153, 5000)
# Processed 488  stargazers. Num nodes/edges in graph 1152 / 2161
# Rate limit remaining (4152, 5000)
# Processed 489  stargazers. Num nodes/edges in graph 1152 / 2162
# Rate limit remaining (4151, 5000)
# Processed 490  stargazers. Num nodes/edges in graph 1152 / 2162
# Rate limit remaining (4150, 5000)
# Processed 491  stargazers. Num nodes/edges in graph 1152 / 2162
# ...
# Processed 634  stargazers. Num nodes/edges in graph 1152 / 2254
# Rate limit remaining (3991, 5000)
# Processed 635  stargazers. Num nodes/edges in graph 1152 / 2254
# Rate limit remaining (3990, 5000)
# Processed 636  stargazers. Num nodes/edges in graph 1152 / 2256
# Rate limit remaining (3989, 5000)
# Processed 637  stargazers. Num nodes/edges in graph 1152 / 2257
# Rate limit remaining (3988, 5000)
# Processed 638  stargazers. Num nodes/edges in graph 1152 / 2259
# Rate limit remaining (3987, 5000)
# Processed 639  stargazers. Num nodes/edges in graph 1152 / 2260
# Rate limit remaining (3986, 5000)
# Processed 640  stargazers. Num nodes/edges in graph 1152 / 2260
# Rate limit remaining (3985, 5000)
# Processed 641  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3984, 5000)
# Processed 642  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3983, 5000)
# Processed 643  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3982, 5000)
# Processed 644  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3981, 5000)
# Processed 645  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3980, 5000)
# Processed 646  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3979, 5000)
# Processed 647  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3978, 5000)
# Processed 648  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3977, 5000)
# Processed 649  stargazers. Num nodes/edges in graph 1152 / 2261
# Rate limit remaining (3976, 5000)
# Processed 650  stargazers. Num nodes/edges in graph 1152 / 2262
# Rate limit remaining (3975, 5000)
# Processed 651  stargazers. Num nodes/edges in graph 1152 / 2262
# Rate limit remaining (3974, 5000)
# Processed 652  stargazers. Num nodes/edges in graph 1152 / 2263
# Rate limit remaining (3973, 5000)
# Processed 653  stargazers. Num nodes/edges in graph 1152 / 2263
# Rate limit remaining (3972, 5000)
# Processed 654  stargazers. Num nodes/edges in graph 1152 / 2263
# Rate limit remaining (3971, 5000)
# Processed 655  stargazers. Num nodes/edges in graph 1152 / 2263
# Rate limit remaining (3970, 5000)
# Processed 656  stargazers. Num nodes/edges in graph 1152 / 2263
# Rate limit remaining (3969, 5000)
# Processed 657  stargazers. Num nodes/edges in graph 1152 / 2265
# Rate limit remaining (3967, 5000)
# Processed 658  stargazers. Num nodes/edges in graph 1152 / 2265
# Rate limit remaining (3966, 5000)
# Processed 659  stargazers. Num nodes/edges in graph 1152 / 2267
# Rate limit remaining (3964, 5000)
# Processed 660  stargazers. Num nodes/edges in graph 1152 / 2267
# Rate limit remaining (3963, 5000)
# Processed 661  stargazers. Num nodes/edges in graph 1152 / 2267
# Rate limit remaining (3962, 5000)
# Processed 662  stargazers. Num nodes/edges in graph 1152 / 2268
# Rate limit remaining (3961, 5000)
# Processed 663  stargazers. Num nodes/edges in graph 1152 / 2268
# Rate limit remaining (3960, 5000)
# Processed 664  stargazers. Num nodes/edges in graph 1152 / 2268
# Rate limit remaining (3959, 5000)
# Processed 665  stargazers. Num nodes/edges in graph 1152 / 2269
# Rate limit remaining (3958, 5000)
# Processed 666  stargazers. Num nodes/edges in graph 1152 / 2270
# Rate limit remaining (3957, 5000)
# Processed 667  stargazers. Num nodes/edges in graph 1152 / 2271
# Rate limit remaining (3956, 5000)
# Processed 668  stargazers. Num nodes/edges in graph 1152 / 2271
# Rate limit remaining (3955, 5000)
# Processed 669  stargazers. Num nodes/edges in graph 1152 / 2272
# Rate limit remaining (3954, 5000)
# Processed 670  stargazers. Num nodes/edges in graph 1152 / 2272
# Rate limit remaining (3953, 5000)
# Processed 671  stargazers. Num nodes/edges in graph 1152 / 2272
# Rate limit remaining (3952, 5000)
# Processed 672  stargazers. Num nodes/edges in graph 1152 / 2272
# Rate limit remaining (3951, 5000)
# Processed 673  stargazers. Num nodes/edges in graph 1152 / 2273
# Rate limit remaining (3950, 5000)
# Processed 674  stargazers. Num nodes/edges in graph 1152 / 2273
# Rate limit remaining (3949, 5000)
# Processed 675  stargazers. Num nodes/edges in graph 1152 / 2273
# Rate limit remaining (3948, 5000)
# Processed 676  stargazers. Num nodes/edges in graph 1152 / 2273
# Rate limit remaining (3947, 5000)
# Processed 677  stargazers. Num nodes/edges in graph 1152 / 2274
# Rate limit remaining (3946, 5000)
# Processed 678  stargazers. Num nodes/edges in graph 1152 / 2274
# Rate limit remaining (3945, 5000)
# Processed 679  stargazers. Num nodes/edges in graph 1152 / 2275
# Rate limit remaining (3944, 5000)
# Processed 680  stargazers. Num nodes/edges in graph 1152 / 2276
# Rate limit remaining (3943, 5000)
# Processed 681  stargazers. Num nodes/edges in graph 1152 / 2277
# Rate limit remaining (3942, 5000)
# Processed 682  stargazers. Num nodes/edges in graph 1152 / 2278
# Rate limit remaining (3941, 5000)
# Processed 683  stargazers. Num nodes/edges in graph 1152 / 2279
# Rate limit remaining (3940, 5000)
# Processed 684  stargazers. Num nodes/edges in graph 1152 / 2280
# Rate limit remaining (3939, 5000)
# Processed 685  stargazers. Num nodes/edges in graph 1152 / 2283
# Rate limit remaining (3938, 5000)
# Processed 686  stargazers. Num nodes/edges in graph 1152 / 2283
# Rate limit remaining (3937, 5000)
# Processed 687  stargazers. Num nodes/edges in graph 1152 / 2284
# Rate limit remaining (3936, 5000)
# Processed 688  stargazers. Num nodes/edges in graph 1152 / 2284
# Rate limit remaining (3935, 5000)
# Processed 689  stargazers. Num nodes/edges in graph 1152 / 2286
# Rate limit remaining (3934, 5000)
# Processed 690  stargazers. Num nodes/edges in graph 1152 / 2305
# Rate limit remaining (3926, 5000)
# Processed 691  stargazers. Num nodes/edges in graph 1152 / 2305
# Rate limit remaining (3925, 5000)
# Processed 692  stargazers. Num nodes/edges in graph 1152 / 2307
# Rate limit remaining (3924, 5000)
# Processed 693  stargazers. Num nodes/edges in graph 1152 / 2307
# Rate limit remaining (3923, 5000)
# Processed 694  stargazers. Num nodes/edges in graph 1152 / 2307
# Rate limit remaining (3922, 5000)
# Processed 695  stargazers. Num nodes/edges in graph 1152 / 2309
# Rate limit remaining (3921, 5000)
# Processed 696  stargazers. Num nodes/edges in graph 1152 / 2319
# Rate limit remaining (3911, 5000)
# Processed 697  stargazers. Num nodes/edges in graph 1152 / 2319
# Rate limit remaining (3910, 5000)
# Processed 698  stargazers. Num nodes/edges in graph 1152 / 2324
# Rate limit remaining (3909, 5000)
# Processed 699  stargazers. Num nodes/edges in graph 1152 / 2325
# Rate limit remaining (3907, 5000)
# Processed 700  stargazers. Num nodes/edges in graph 1152 / 2325
# Rate limit remaining (3906, 5000)
# Processed 701  stargazers. Num nodes/edges in graph 1152 / 2326
# Rate limit remaining (3904, 5000)
# Processed 702  stargazers. Num nodes/edges in graph 1152 / 2334
# Rate limit remaining (3901, 5000)
# Processed 703  stargazers. Num nodes/edges in graph 1152 / 2335
# Rate limit remaining (3900, 5000)
# Processed 704  stargazers. Num nodes/edges in graph 1152 / 2335
# Rate limit remaining (3899, 5000)
# Processed 705  stargazers. Num nodes/edges in graph 1152 / 2335
# Rate limit remaining (3898, 5000)
# Processed 706  stargazers. Num nodes/edges in graph 1152 / 2335
# Rate limit remaining (3897, 5000)
# Processed 707  stargazers. Num nodes/edges in graph 1152 / 2335
# Rate limit remaining (3896, 5000)
# Processed 708  stargazers. Num nodes/edges in graph 1152 / 2336
# Rate limit remaining (3895, 5000)
# Processed 709  stargazers. Num nodes/edges in graph 1152 / 2337
# Rate limit remaining (3894, 5000)
# Processed 710  stargazers. Num nodes/edges in graph 1152 / 2338
# Rate limit remaining (3893, 5000)
# Processed 711  stargazers. Num nodes/edges in graph 1152 / 2339
# Rate limit remaining (3892, 5000)
# Processed 712  stargazers. Num nodes/edges in graph 1152 / 2339
# Rate limit remaining (3891, 5000)
# Processed 713  stargazers. Num nodes/edges in graph 1152 / 2340
# Rate limit remaining (3890, 5000)
# Processed 714  stargazers. Num nodes/edges in graph 1152 / 2343
# Rate limit remaining (3889, 5000)
# Processed 715  stargazers. Num nodes/edges in graph 1152 / 2344
# Rate limit remaining (3887, 5000)
# Processed 716  stargazers. Num nodes/edges in graph 1152 / 2345
# Rate limit remaining (3886, 5000)
# Processed 717  stargazers. Num nodes/edges in graph 1152 / 2345
# Rate limit remaining (3885, 5000)
# Processed 718  stargazers. Num nodes/edges in graph 1152 / 2345
# Rate limit remaining (3884, 5000)
# Processed 719  stargazers. Num nodes/edges in graph 1152 / 2347
# Rate limit remaining (3883, 5000)
# Processed 720  stargazers. Num nodes/edges in graph 1152 / 2351
# Rate limit remaining (3881, 5000)
# Processed 721  stargazers. Num nodes/edges in graph 1152 / 2353
# Rate limit remaining (3880, 5000)
# Processed 722  stargazers. Num nodes/edges in graph 1152 / 2354
# Rate limit remaining (3879, 5000)
# Processed 723  stargazers. Num nodes/edges in graph 1152 / 2359
# Rate limit remaining (3877, 5000)
# Processed 724  stargazers. Num nodes/edges in graph 1152 / 2359
# Rate limit remaining (3876, 5000)
# Processed 725  stargazers. Num nodes/edges in graph 1152 / 2361
# Rate limit remaining (3875, 5000)
# Processed 726  stargazers. Num nodes/edges in graph 1152 / 2361
# Rate limit remaining (3874, 5000)
# Processed 727  stargazers. Num nodes/edges in graph 1152 / 2362
# Rate limit remaining (3872, 5000)
# Processed 728  stargazers. Num nodes/edges in graph 1152 / 2369
# Rate limit remaining (3865, 5000)
# Processed 729  stargazers. Num nodes/edges in graph 1152 / 2369
# Rate limit remaining (3864, 5000)
# Processed 730  stargazers. Num nodes/edges in graph 1152 / 2369
# Rate limit remaining (3863, 5000)
# Processed 731  stargazers. Num nodes/edges in graph 1152 / 2369
# Rate limit remaining (3862, 5000)
# Processed 732  stargazers. Num nodes/edges in graph 1152 / 2371
# Rate limit remaining (3861, 5000)
# Processed 733  stargazers. Num nodes/edges in graph 1152 / 2371
# Rate limit remaining (3860, 5000)
# Processed 734  stargazers. Num nodes/edges in graph 1152 / 2373
# Rate limit remaining (3859, 5000)
# Processed 735  stargazers. Num nodes/edges in graph 1152 / 2374
# Rate limit remaining (3858, 5000)
# Processed 736  stargazers. Num nodes/edges in graph 1152 / 2374
# Rate limit remaining (3857, 5000)
# Processed 737  stargazers. Num nodes/edges in graph 1152 / 2374
# Rate limit remaining (3856, 5000)
# Processed 738  stargazers. Num nodes/edges in graph 1152 / 2374
# Rate limit remaining (3855, 5000)
# Processed 739  stargazers. Num nodes/edges in graph 1152 / 2374
# Rate limit remaining (3854, 5000)
# Processed 740  stargazers. Num nodes/edges in graph 1152 / 2377
# Rate limit remaining (3853, 5000)
# Processed 741  stargazers. Num nodes/edges in graph 1152 / 2377
# Rate limit remaining (3852, 5000)
# Processed 742  stargazers. Num nodes/edges in graph 1152 / 2379
# Rate limit remaining (3851, 5000)
# Processed 743  stargazers. Num nodes/edges in graph 1152 / 2380
# Rate limit remaining (3850, 5000)
# Processed 744  stargazers. Num nodes/edges in graph 1152 / 2381
# Rate limit remaining (3849, 5000)
# Processed 745  stargazers. Num nodes/edges in graph 1152 / 2382
# Rate limit remaining (3848, 5000)
# Processed 746  stargazers. Num nodes/edges in graph 1152 / 2382
# Rate limit remaining (3847, 5000)
# Processed 747  stargazers. Num nodes/edges in graph 1152 / 2383
# Rate limit remaining (3846, 5000)
# Processed 748  stargazers. Num nodes/edges in graph 1152 / 2385
# Rate limit remaining (3845, 5000)
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# <ipython-input-19-223ee7a15636> in <module>()
#      12     try:
# ---> 13         for follower in sg.get_followers():
#      14             if follower.login + '(user)' in g:
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in __iter__(self)
#      57         while self._couldGrow():
# ---> 58             newElements = self._grow()
#      59             for element in newElements:
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in _grow(self)
#      69     def _grow(self):
# ---> 70         newElements = self._fetchNextPage()
#      71         self.__elements += newElements
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in _fetchNextPage(self)
#     171             parameters=self.__nextParams,
# --> 172             headers=self.__headers
#     173         )
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input, cnx)
#     184     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
# --> 185         return self.__check(*self.requestJson(verb, url, parameters, headers, input, cnx))
#     186
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in requestJson(self, verb, url, parameters, headers, input, cnx)
#     230
# --> 231         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     232
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     283
# --> 284         status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     285
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     308             input,
# --> 309             requestHeaders
#     310         )
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /Users/temp/anaconda/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# /Users/temp/anaconda/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     742     addrlist = []
# --> 743     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     744         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-223ee7a15636> in <module>()
#      16                            type='follows')
#      17     except Exception: #ssl.SSLError
# ---> 18         print >> sys.stderr, "Encountered an error fetching followers for",                              sg.login, "Skipping."
#      19         print >> sys.stderr, e
#      20
#
# TypeError: unsupported operand type(s) for >>: 'builtin_function_or_method' and 'OutStream'

# %% [markdown]
# ## Example 9. Exploring the updated graph's "follows" edges

# %%
from operator import itemgetter
from collections import Counter

# Let's see how many social edges we added since last time.
print(nx.info(g))
print('\n')

# The number of "follows" edges is the difference
print(len([e for e in g.edges_iter(data=True) if e[2]['type'] == 'follows']))
print('\n')

# The repository owner is possibly one of the more popular users in this graph.
print(len([e 
           for e in g.edges_iter(data=True) 
               if e[2]['type'] == 'follows' and e[1] == 'ptwobrussell(user)']))
print('\n')

# Let's examine the number of adjacent edges to each node
print(sorted([n for n in g.degree_iter()], key=itemgetter(1), reverse=True)[:10])
print('\n')

# Consider the ratio of incoming and outgoing edges for a couple of users with 
# high node degrees...

# A user who follows many but is not followed back by many.

print(len(g.out_edges('hcilab(user)')))
print(len(g.in_edges('hcilab(user)')))
print('\n')

# A user who is followed by many but does not follow back.

print(len(g.out_edges('ptwobrussell(user)')))
print(len(g.in_edges('ptwobrussell(user)')))
print('\n')

c = Counter([e[1] for e in g.edges_iter(data=True) if e[2]['type'] == 'follows'])
popular_users = [ (u, f) for (u, f) in c.most_common() if f > 1 ]
print("Number of popular users", len(popular_users))
print("Top 10 popular users:", popular_users[:10])
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1152
# Number of edges: 2421
# Average in degree:   2.1016
# Average out degree:   2.1016
#
#
# 1270
#
#
# 127
#
#
# [('Mining-the-Social-Web(repo)', 1151), ('angusshire(user)', 347), ('kennethreitz(user)', 169), ('ptwobrussell(user)', 128), ('VagrantStory(user)', 77), ('trietptm(user)', 50), ('daimajia(user)', 39), ('rohithadassanayake(user)', 39), ('JT5D(user)', 28), ('hammer(user)', 26)]
#
#
# 0
# 0
#
#
# 1
# 127
#
#
# Number of popular users 202
# Top 10 popular users: [('kennethreitz(user)', 166), ('ptwobrussell(user)', 127), ('daimajia(user)', 36), ('hammer(user)', 20), ('jakubroztocil(user)', 20), ('isnowfy(user)', 19), ('japerk(user)', 18), ('dgryski(user)', 13), ('tswicegood(user)', 10), ('ZoomQuiet(user)', 10)]

# %% [markdown]
# ## Example 10. Snapshotting (pickling) the graph's state to disk

# %%
# Save your work by serializing out (pickling) the graph
nx.write_gpickle(g, "resources/ch07-github/data/github.gpickle.1")

# How to restore the graph...
# import networkx as nx
# g = nx.read_gpickle("resources/ch07-github/data/github.gpickle.1")

# %% [markdown]
# ## Example 11. Applying centrality measures to the interest graph

# %%
from operator import itemgetter

# Create a copy of the graph so that we can iteratively mutate the copy
# as needed for experimentation

h = g.copy()

# Remove the seed of the interest graph, which is a supernode, in order
# to get a better idea of the network dynamics

h.remove_node('Mining-the-Social-Web(repo)')

# XXX: Remove any other nodes that appear to be supernodes.
# Filter any other nodes that you can by threshold
# criteria or heuristics from inspection.

# Display the centrality measures for the top 10 nodes


dc = sorted(nx.degree_centrality(h).items(), 
            key=itemgetter(1), reverse=True)

print "Degree Centrality"
print dc[:10]
print

bc = sorted(nx.betweenness_centrality(h).items(), 
            key=itemgetter(1), reverse=True)

print "Betweenness Centrality"
print bc[:10]
print

print "Closeness Centrality"
cc = sorted(nx.closeness_centrality(h).items(), 
            key=itemgetter(1), reverse=True)
print cc[:10]

# %% [markdown]
# ## Example 12. Adding starred repositories to the graph

# %%
# Let's add each stargazer's additional starred repos and add edges 
# to find additional interests.

MAX_REPOS = 500

for i, sg in enumerate(stargazers):
    print(sg.login)
    try:
        for starred in sg.get_starred()[:MAX_REPOS]: # Slice to avoid supernodes
            g.add_node(starred.name + '(repo)', type='repo', lang=starred.language, \
                       owner=starred.owner.login)
            g.add_edge(sg.login + '(user)', starred.name + '(repo)', type='gazes')
    except Exception: #ssl.SSLError:
        print("Encountered an error fetching starred repos for", sg.login, "Skipping.")

    print("Processed", i+1, "stargazers' starred repos")
    print("Num nodes/edges in graph", g.number_of_nodes(), "/", g.number_of_edges())
    print("Rate limit", client.rate_limiting)
# Out:
# rdempsey
# Encountered an error fetching starred repos for rdempsey Skipping.
# Processed 1 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (59, 60)
# frac
# Encountered an error fetching starred repos for frac Skipping.
# Processed 2 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (58, 60)
# prb
# Encountered an error fetching starred repos for prb Skipping.
# Processed 3 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (57, 60)
# mcroydon
# Encountered an error fetching starred repos for mcroydon Skipping.
# Processed 4 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (56, 60)
# batasrki
# Encountered an error fetching starred repos for batasrki Skipping.
# Processed 5 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (55, 60)
# twleung
# Encountered an error fetching starred repos for twleung Skipping.
# Processed 6 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (54, 60)
# kevinchiu
# Encountered an error fetching starred repos for kevinchiu Skipping.
# Processed 7 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (53, 60)
# nikolay
# Encountered an error fetching starred repos for nikolay Skipping.
# Processed 8 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (52, 60)
# tswicegood
# Encountered an error fetching starred repos for tswicegood Skipping.
# Processed 9 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (51, 60)
# ngpestelos
# Encountered an error fetching starred repos for ngpestelos Skipping.
# Processed 10 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (50, 60)
# darron
# Encountered an error fetching starred repos for darron Skipping.
# Processed 11 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (49, 60)
# brunojm
# Encountered an error fetching starred repos for brunojm Skipping.
# Processed 12 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (48, 60)
# rgaidot
# Encountered an error fetching starred repos for rgaidot Skipping.
# Processed 13 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (47, 60)
# openweb
# Encountered an error fetching starred repos for openweb Skipping.
# Processed 14 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (46, 60)
# shanlalit
# Encountered an error fetching starred repos for shanlalit Skipping.
# Processed 15 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (45, 60)
# hoffmann
# Encountered an error fetching starred repos for hoffmann Skipping.
# Processed 16 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (44, 60)
# nacht
# Encountered an error fetching starred repos for nacht Skipping.
# Processed 17 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (43, 60)
# hectoregm
# Encountered an error fetching starred repos for hectoregm Skipping.
# Processed 18 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (42, 60)
# tzuryby
# Encountered an error fetching starred repos for tzuryby Skipping.
# Processed 19 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (41, 60)
# marksands
# Encountered an error fetching starred repos for marksands Skipping.
# Processed 20 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (40, 60)
# wbzyl
# Encountered an error fetching starred repos for wbzyl Skipping.
# Processed 21 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (39, 60)
# sou
# Encountered an error fetching starred repos for sou Skipping.
# Processed 22 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (38, 60)
# magnum
# Encountered an error fetching starred repos for magnum Skipping.
# Processed 23 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (37, 60)
# suzuki
# Encountered an error fetching starred repos for suzuki Skipping.
# Processed 24 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (36, 60)
# tertsch
# Encountered an error fetching starred repos for tertsch Skipping.
# Processed 25 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (35, 60)
# ymirpl
# Encountered an error fetching starred repos for ymirpl Skipping.
# Processed 26 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (34, 60)
# sebasmagri
# Encountered an error fetching starred repos for sebasmagri Skipping.
# Processed 27 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (33, 60)
# galvez
# Encountered an error fetching starred repos for galvez Skipping.
# Processed 28 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (32, 60)
# paulbersch
# Encountered an error fetching starred repos for paulbersch Skipping.
# Processed 29 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (31, 60)
# georgebellos
# Encountered an error fetching starred repos for georgebellos Skipping.
# Processed 30 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (30, 60)
# acadopia
# Encountered an error fetching starred repos for acadopia Skipping.
# Processed 31 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (29, 60)
# ggtr1138
# Encountered an error fetching starred repos for ggtr1138 Skipping.
# Processed 32 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (28, 60)
# program247365
# Encountered an error fetching starred repos for program247365 Skipping.
# Processed 33 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (27, 60)
# edwelker
# Encountered an error fetching starred repos for edwelker Skipping.
# Processed 34 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (26, 60)
# hammer
# Encountered an error fetching starred repos for hammer Skipping.
# Processed 35 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (25, 60)
# jengdal
# Encountered an error fetching starred repos for jengdal Skipping.
# Processed 36 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (24, 60)
# brimbrom
# Encountered an error fetching starred repos for brimbrom Skipping.
# Processed 37 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (23, 60)
# gar
# Encountered an error fetching starred repos for gar Skipping.
# Processed 38 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (22, 60)
# willi
# Encountered an error fetching starred repos for willi Skipping.
# Processed 39 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (21, 60)
# gregmoreno
# Encountered an error fetching starred repos for gregmoreno Skipping.
# Processed 40 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (20, 60)
# rays
# Encountered an error fetching starred repos for rays Skipping.
# Processed 41 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (19, 60)
# rayleyva
# Encountered an error fetching starred repos for rayleyva Skipping.
# Processed 42 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (18, 60)
# paxan
# Encountered an error fetching starred repos for paxan Skipping.
# Processed 43 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (17, 60)
# eughenes
# Encountered an error fetching starred repos for eughenes Skipping.
# Processed 44 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (16, 60)
# barce
# Encountered an error fetching starred repos for barce Skipping.
# Processed 45 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (15, 60)
# abuiles
# Encountered an error fetching starred repos for abuiles Skipping.
# Processed 46 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (14, 60)
# carhartl
# Encountered an error fetching starred repos for carhartl Skipping.
# Processed 47 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (13, 60)
# jexchan
# Encountered an error fetching starred repos for jexchan Skipping.
# Processed 48 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (12, 60)
# yasu00000
# Encountered an error fetching starred repos for yasu00000 Skipping.
# Processed 49 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (11, 60)
# lsinger
# Encountered an error fetching starred repos for lsinger Skipping.
# Processed 50 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (10, 60)
# yy
# Encountered an error fetching starred repos for yy Skipping.
# Processed 51 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (9, 60)
# daemianmack
# Encountered an error fetching starred repos for daemianmack Skipping.
# Processed 52 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (8, 60)
# ricardoalmeida
# Encountered an error fetching starred repos for ricardoalmeida Skipping.
# Processed 53 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (7, 60)
# gerad
# Encountered an error fetching starred repos for gerad Skipping.
# Processed 54 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (6, 60)
# amitagrawal
# Encountered an error fetching starred repos for amitagrawal Skipping.
# Processed 55 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (5, 60)
# swinton
# Encountered an error fetching starred repos for swinton Skipping.
# Processed 56 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (4, 60)
# polonia
# Encountered an error fetching starred repos for polonia Skipping.
# Processed 57 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (3, 60)
# fozbaca
# Encountered an error fetching starred repos for fozbaca Skipping.
# Processed 58 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (2, 60)
# nborwankar
# Encountered an error fetching starred repos for nborwankar Skipping.
# Processed 59 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (1, 60)
# aljosa
# Encountered an error fetching starred repos for aljosa Skipping.
# Processed 60 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# macdet
# Encountered an error fetching starred repos for macdet Skipping.
# Processed 61 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# Smerity
# Encountered an error fetching starred repos for Smerity Skipping.
# Processed 62 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# joepestro
# Encountered an error fetching starred repos for joepestro Skipping.
# Processed 63 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# phauly
# Encountered an error fetching starred repos for phauly Skipping.
# Processed 64 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# shamiksharma
# Encountered an error fetching starred repos for shamiksharma Skipping.
# Processed 65 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# lg2046
# Encountered an error fetching starred repos for lg2046 Skipping.
# Processed 66 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# omg
# Encountered an error fetching starred repos for omg Skipping.
# Processed 67 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# lzell
# Encountered an error fetching starred repos for lzell Skipping.
# Processed 68 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# eduardocereto
# Encountered an error fetching starred repos for eduardocereto Skipping.
# Processed 69 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# kshimo69
# Encountered an error fetching starred repos for kshimo69 Skipping.
# Processed 70 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# natorro
# Encountered an error fetching starred repos for natorro Skipping.
# Processed 71 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# abecciu
# Encountered an error fetching starred repos for abecciu Skipping.
# Processed 72 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# CaptSolo
# Encountered an error fetching starred repos for CaptSolo Skipping.
# Processed 73 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# clyfe
# Encountered an error fetching starred repos for clyfe Skipping.
# Processed 74 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# mahmoudimus
# Encountered an error fetching starred repos for mahmoudimus Skipping.
# Processed 75 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# mznmel
# Encountered an error fetching starred repos for mznmel Skipping.
# Processed 76 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# Kilian
# Encountered an error fetching starred repos for Kilian Skipping.
# Processed 77 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# stonegao
# Encountered an error fetching starred repos for stonegao Skipping.
# Processed 78 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# pcdinh
# Encountered an error fetching starred repos for pcdinh Skipping.
# Processed 79 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# jacktang
# Encountered an error fetching starred repos for jacktang Skipping.
# Processed 80 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# Almad
# Encountered an error fetching starred repos for Almad Skipping.
# Processed 81 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# sleeptillseven
# Encountered an error fetching starred repos for sleeptillseven Skipping.
# Processed 82 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# Kudo
# Encountered an error fetching starred repos for Kudo Skipping.
# Processed 83 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# acdha
# Encountered an error fetching starred repos for acdha Skipping.
# Processed 84 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# ticean
# Encountered an error fetching starred repos for ticean Skipping.
# Processed 85 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# buffpojken
# Encountered an error fetching starred repos for buffpojken Skipping.
# Processed 86 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# bnvk
# Encountered an error fetching starred repos for bnvk Skipping.
# Processed 87 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# zen4ever
# Encountered an error fetching starred repos for zen4ever Skipping.
# Processed 88 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# bpeirce
# Encountered an error fetching starred repos for bpeirce Skipping.
# Processed 89 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# metllord
# Encountered an error fetching starred repos for metllord Skipping.
# Processed 90 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# macdiva
# Encountered an error fetching starred repos for macdiva Skipping.
# Processed 91 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# miukal
# Encountered an error fetching starred repos for miukal Skipping.
# Processed 92 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# miyucy
# Encountered an error fetching starred repos for miyucy Skipping.
# Processed 93 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# valentinzberea
# Encountered an error fetching starred repos for valentinzberea Skipping.
# Processed 94 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# Tuxified
# Encountered an error fetching starred repos for Tuxified Skipping.
# Processed 95 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# miku
# Encountered an error fetching starred repos for miku Skipping.
# Processed 96 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# daevid
# Encountered an error fetching starred repos for daevid Skipping.
# Processed 97 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# lemonad
# Encountered an error fetching starred repos for lemonad Skipping.
# Processed 98 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# Xeoncross
# Encountered an error fetching starred repos for Xeoncross Skipping.
# Processed 99 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# shurik
# Encountered an error fetching starred repos for shurik Skipping.
# Processed 100 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# zonovo
# Encountered an error fetching starred repos for zonovo Skipping.
# Processed 101 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# matagus
# Encountered an error fetching starred repos for matagus Skipping.
# Processed 102 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# phernandez
# Encountered an error fetching starred repos for phernandez Skipping.
# Processed 103 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# vshulyak
# Encountered an error fetching starred repos for vshulyak Skipping.
# Processed 104 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# elg0nz
# Encountered an error fetching starred repos for elg0nz Skipping.
# Processed 105 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# jonathanjo
# Encountered an error fetching starred repos for jonathanjo Skipping.
# Processed 106 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# rduong
# Encountered an error fetching starred repos for rduong Skipping.
# Processed 107 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# sfrench
# Encountered an error fetching starred repos for sfrench Skipping.
# Processed 108 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# edtechdev
# Encountered an error fetching starred repos for edtechdev Skipping.
# Processed 109 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# vvoody
# Encountered an error fetching starred repos for vvoody Skipping.
# Processed 110 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# riivo
# Encountered an error fetching starred repos for riivo Skipping.
# Processed 111 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# doolin
# Encountered an error fetching starred repos for doolin Skipping.
# Processed 112 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# chlalanne
# Encountered an error fetching starred repos for chlalanne Skipping.
# Processed 113 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# lrvick
# Encountered an error fetching starred repos for lrvick Skipping.
# Processed 114 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# cameronpriest
# Encountered an error fetching starred repos for cameronpriest Skipping.
# Processed 115 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# napo
# Encountered an error fetching starred repos for napo Skipping.
# Processed 116 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# ukituki
# Encountered an error fetching starred repos for ukituki Skipping.
# Processed 117 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# blynch
# Encountered an error fetching starred repos for blynch Skipping.
# Processed 118 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# adriaant
# Encountered an error fetching starred repos for adriaant Skipping.
# Processed 119 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# mgrouchy
# Encountered an error fetching starred repos for mgrouchy Skipping.
# Processed 120 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# InFog
# Encountered an error fetching starred repos for InFog Skipping.
# Processed 121 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# rnagle
# Encountered an error fetching starred repos for rnagle Skipping.
# Processed 122 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# macorama
# Encountered an error fetching starred repos for macorama Skipping.
# Processed 123 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# mki
# Encountered an error fetching starred repos for mki Skipping.
# Processed 124 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# dasfaha
# Encountered an error fetching starred repos for dasfaha Skipping.
# Processed 125 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# jagguli
# Encountered an error fetching starred repos for jagguli Skipping.
# Processed 126 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# davidrd123
# Encountered an error fetching starred repos for davidrd123 Skipping.
# Processed 127 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# darkseed
# Encountered an error fetching starred repos for darkseed Skipping.
# Processed 128 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# bjpcjp
# Encountered an error fetching starred repos for bjpcjp Skipping.
# Processed 129 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# jonathanyee
# Encountered an error fetching starred repos for jonathanyee Skipping.
# Processed 130 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# jensenrf
# Encountered an error fetching starred repos for jensenrf Skipping.
# Processed 131 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# levigross
# Encountered an error fetching starred repos for levigross Skipping.
# Processed 132 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# BrianPin
# Encountered an error fetching starred repos for BrianPin Skipping.
# Processed 133 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# nycterent
# Encountered an error fetching starred repos for nycterent Skipping.
# Processed 134 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# lyddonb
# Encountered an error fetching starred repos for lyddonb Skipping.
# Processed 135 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# putorti
# Encountered an error fetching starred repos for putorti Skipping.
# Processed 136 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# vigo
# Encountered an error fetching starred repos for vigo Skipping.
# Processed 137 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# MaggiePlusPlus
# Encountered an error fetching starred repos for MaggiePlusPlus Skipping.
# Processed 138 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# Stecki
# Encountered an error fetching starred repos for Stecki Skipping.
# Processed 139 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# jean
# Encountered an error fetching starred repos for jean Skipping.
# Processed 140 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# ido
# Encountered an error fetching starred repos for ido Skipping.
# Processed 141 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# brianly
# Encountered an error fetching starred repos for brianly Skipping.
# Processed 142 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# kcnickerson
# Encountered an error fetching starred repos for kcnickerson Skipping.
# Processed 143 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# seralf
# Encountered an error fetching starred repos for seralf Skipping.
# Processed 144 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# kemaltaskin
# Encountered an error fetching starred repos for kemaltaskin Skipping.
# Processed 145 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# trevorhales
# Encountered an error fetching starred repos for trevorhales Skipping.
# Processed 146 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# jonhurlock
# Encountered an error fetching starred repos for jonhurlock Skipping.
# Processed 147 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# zmughal
# Encountered an error fetching starred repos for zmughal Skipping.
# Processed 148 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# ykhroki
# Encountered an error fetching starred repos for ykhroki Skipping.
# Processed 149 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# johnthedebs
# Encountered an error fetching starred repos for johnthedebs Skipping.
# Processed 150 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# ptwobrussell
# Encountered an error fetching starred repos for ptwobrussell Skipping.
# Processed 151 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# bububa
# Encountered an error fetching starred repos for bububa Skipping.
# Processed 152 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# barbietunnie
# Encountered an error fetching starred repos for barbietunnie Skipping.
# Processed 153 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# hezila
# Encountered an error fetching starred repos for hezila Skipping.
# Processed 154 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# sudar
# Encountered an error fetching starred repos for sudar Skipping.
# Processed 155 stargazers' starred repos
# Num nodes/edges in graph 1152 / 2421
# Rate limit (0, 60)
# klaut
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-faa2223926c3> in <module>()
#       7     print(sg.login)
#       8     try:
# ----> 9         for starred in sg.get_starred()[:MAX_REPOS]: # Slice to avoid supernodes
#      10             g.add_node(starred.name + '(repo)', type='repo', lang=starred.language,                        owner=starred.owner.login)
#      11             g.add_edge(sg.login + '(user)', starred.name + '(repo)', type='gazes')
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in __iter__(self)
#      83             while not self.__finished(index):
#      84                 if self.__list._isBiggerThan(index):
# ---> 85                     yield self.__list[index]
#      86                     index += self.__step
#      87                 else:
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in __getitem__(self, index)
#      47         assert isinstance(index, (int, slice))
#      48         if isinstance(index, int):
# ---> 49             self.__fetchToIndex(index)
#      50             return self.__elements[index]
#      51         else:
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in __fetchToIndex(self, index)
#      65     def __fetchToIndex(self, index):
#      66         while len(self.__elements) <= index and self._couldGrow():
# ---> 67             self._grow()
#      68
#      69     def _grow(self):
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in _grow(self)
#      68
#      69     def _grow(self):
# ---> 70         newElements = self._fetchNextPage()
#      71         self.__elements += newElements
#      72         return newElements
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/PaginatedList.py in _fetchNextPage(self)
#     170             self.__nextUrl,
#     171             parameters=self.__nextParams,
# --> 172             headers=self.__headers
#     173         )
#     174         data = data if data else []
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input, cnx)
#     183
#     184     def requestJsonAndCheck(self, verb, url, parameters=None, headers=None, input=None, cnx=None):
# --> 185         return self.__check(*self.requestJson(verb, url, parameters, headers, input, cnx))
#     186
#     187     def requestMultipartAndCheck(self, verb, url, parameters=None, headers=None, input=None):
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in requestJson(self, verb, url, parameters, headers, input, cnx)
#     229             return "application/json", json.dumps(input)
#     230
# --> 231         return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#     232
#     233     def requestMultipart(self, verb, url, parameters=None, headers=None, input=None):
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in __requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     282         self.NEW_DEBUG_FRAME(requestHeaders)
#     283
# --> 284         status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     285
#     286         if "x-ratelimit-remaining" in responseHeaders and "x-ratelimit-limit" in responseHeaders:
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in __requestRaw(self, cnx, verb, url, requestHeaders, input)
#     299         original_cnx = cnx
#     300         if cnx is None:
# --> 301             cnx = self.__createConnection()
#     302         else:
#     303             assert cnx == "status"
#
# /Users/temp/anaconda/lib/python3.6/site-packages/github/Requester.py in __createConnection(self)
#     379             conn.set_tunnel(self.__hostname, self.__port, headers)
#     380         else:
# --> 381             conn = self.__connectionClass(self.__hostname, self.__port, **kwds)
#     382
#     383         return conn
#
# /Users/temp/anaconda/lib/python3.6/http/client.py in __init__(self, host, port, key_file, cert_file, timeout, source_address, context, check_hostname)
#    1375             self.cert_file = cert_file
#    1376             if context is None:
# -> 1377                 context = ssl._create_default_https_context()
#    1378             will_verify = context.verify_mode != ssl.CERT_NONE
#    1379             if check_hostname is None:
#
# /Users/temp/anaconda/lib/python3.6/ssl.py in create_default_context(purpose, cafile, capath, cadata)
#     509         # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     510         # root CA certificates for the given purpose. This may fail silently.
# --> 511         context.load_default_certs(purpose)
#     512     return context
#     513
#
# /Users/temp/anaconda/lib/python3.6/ssl.py in load_default_certs(self, purpose)
#     449             for storename in self._windows_cert_stores:
#     450                 self._load_windows_store_certs(storename, purpose)
# --> 451         self.set_default_verify_paths()
#     452
#     453     @property
#
# KeyboardInterrupt:

# %% [markdown]
# **NOTE: Given that Example 12 is potentially a very time-consuming example to run, be sure to snapshot your work**

# %%
# Save your work by serializing out another snapshot of the graph
nx.write_gpickle(g, "resources/ch07-github/data/github.gpickle.2")

#import networkx as nx
#g = nx.read_gpickle("resources/ch07-github/data/github.gpickle.2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-7e08a9e1b428> in <module>()
#       1 # Save your work by serializing out another snapshot of the graph
# ----> 2 nx.write_gpickle(g, "resources/ch07-github/data/github.gpickle.2")
#       3
#       4 #import networkx as nx
#       5 #g = nx.read_gpickle("resources/ch07-github/data/github.gpickle.2")
#
# <decorator-gen-293> in write_gpickle(G, path, protocol)
#
# /Users/temp/anaconda/lib/python3.6/site-packages/networkx/utils/decorators.py in _open_file(func, *args, **kwargs)
#     196         if is_string_like(path):
#     197             ext = splitext(path)[1]
# --> 198             fobj = _dispatch_dict[ext](path, mode=mode)
#     199             close_fobj = True
#     200         elif hasattr(path, 'read'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/ch07-github/data/github.gpickle.2'

# %% [markdown]
# Consider analysis similar to _Example 12_ here. Create a copy of the graph and be selective in pruning it or extracting subgraphs of interst.

# %% [markdown]
# ## Example 13. Exploring the graph after updates with additional starred repositories

# %%
# Poke around: how to get users/repos
from operator import itemgetter

print(nx.info(g))
print('\n')

# Get a list of repositories from the graph.

repos = [n for n in g.nodes_iter() if g.node[n]['type'] == 'repo']

# Most popular repos

print("Popular repositories")
print(sorted([(n,d) 
              for (n,d) in g.in_degree_iter() 
                  if g.node[n]['type'] == 'repo'], \
             key=itemgetter(1), reverse=True)[:10])
print('\n')

# Projects gazed at by a user

print("Respositories that ptwobrussell has bookmarked")
print([(n,g.node[n]['lang']) 
       for n in g['ptwobrussell(user)'] 
           if g['ptwobrussell(user)'][n]['type'] == 'gazes'])
print('\n')

# Programming languages for each user

print("Programming languages ptwobrussell is interested in")
print(list(set([g.node[n]['lang'] 
                for n in g['ptwobrussell(user)'] 
                    if g['ptwobrussell(user)'][n]['type'] == 'gazes'])))
print('\n')

# Find supernodes in the graph by approximating with a high number of 
# outgoing edges

print("Supernode candidates")
print(sorted([(n, len(g.out_edges(n))) 
              for n in g.nodes_iter() 
                  if g.node[n]['type'] == 'user' and len(g.out_edges(n)) > 500], \
             key=itemgetter(1), reverse=True))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1152
# Number of edges: 2421
# Average in degree:   2.1016
# Average out degree:   2.1016
#
#
# Popular repositories
# [('Mining-the-Social-Web(repo)', 1151)]
#
#
# Respositories that ptwobrussell has bookmarked
# [('Mining-the-Social-Web(repo)', 'JavaScript')]
#
#
# Programming languages ptwobrussell is interested in
# ['JavaScript']
#
#
# Supernode candidates
# []

# %% [markdown]
# ## Example 14. Updating the graph to include nodes for programming languages

# %%
# Iterate over all of the repos, and add edges for programming languages 
# for each person in the graph. We'll also add edges back to repos so that 
# we have a good point to "pivot" upon.

repos = [n 
         for n in g.nodes_iter() 
             if g.node[n]['type'] == 'repo']

for repo in repos:
    lang = (g.node[repo]['lang'] or "") + "(lang)"
    
    stargazers = [u 
                  for (u, r, d) in g.in_edges_iter(repo, data=True) 
                     if d['type'] == 'gazes'
                 ]
    
    for sg in stargazers:
        g.add_node(lang, type='lang')
        g.add_edge(sg, lang, type='programs')
        g.add_edge(lang, repo, type='implements')

# %% [markdown]
# ## Example 15. Sample queries for the final graph

# %%
# Some stats

print(nx.info(g))
print('\n')

# What languages exist in the graph?

print([n 
       for n in g.nodes_iter() 
           if g.node[n]['type'] == 'lang'])
print('\n')

# What languages do users program with?
print([n 
       for n in g['ptwobrussell(user)'] 
           if g['ptwobrussell(user)'][n]['type'] == 'programs'])

# What is the most popular programming language?
print("Most popular languages")
print(sorted([(n, g.in_degree(n))
 for n in g.nodes_iter() 
     if g.node[n]['type'] == 'lang'], key=itemgetter(1), reverse=True)[:10])
print('\n')

# How many users program in a particular language?
python_programmers = [u 
                      for (u, l) in g.in_edges_iter('Python(lang)') 
                          if g.node[u]['type'] == 'user']
print("Number of Python programmers:", len(python_programmers))
print('\n')

javascript_programmers = [u for 
                          (u, l) in g.in_edges_iter('JavaScript(lang)') 
                              if g.node[u]['type'] == 'user']
print("Number of JavaScript programmers:", len(javascript_programmers))
print('\n')

# What users program in both Python and JavaScript?
print("Number of programmers who use JavaScript and Python")
print(len(set(python_programmers).intersection(set(javascript_programmers))))

# Programmers who use JavaScript but not Python
print("Number of programmers who use JavaScript but not Python")
print(len(set(javascript_programmers).difference(set(python_programmers))))

# XXX: Can you determine who is the most polyglot programmer?
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 1153
# Number of edges: 3573
# Average in degree:   3.0989
# Average out degree:   3.0989
#
#
# ['JavaScript(lang)']
#
#
# ['JavaScript(lang)']
# Most popular languages
# [('JavaScript(lang)', 1151)]
#
#
# Number of Python programmers: 0
#
#
# Number of JavaScript programmers: 1151
#
#
# Number of programmers who use JavaScript and Python
# 0
# Number of programmers who use JavaScript but not Python
# 1151

# %% [markdown]
# **NOTE: Optionally, snapshot the final graph**

# %%
# Save your work by serializing out another snapshot of the graph
nx.write_gpickle(g, "resources/ch07-github/data/github.gpickle.3")

#import networkx as nx
#g = nx.read_gpickle("resources/ch07-github/data/github.gpickle.3")

# %% [markdown]
# ## Example 16. Graph visualization of the social network for the original interest graph

# %%
import os
import json
from IPython.display import IFrame
from IPython.core.display import display
from networkx.readwrite import json_graph

print("Stats on the full graph")
print(nx.info(g))
print('\n')

# Create a subgraph from a collection of nodes. In this case, the
# collection is all of the users in the original interest graph

mtsw_users = [n for n in g if g.node[n]['type'] == 'user']
h = g.subgraph(mtsw_users)

print("Stats on the extracted subgraph")
print(nx.info(h))

# Visualize the social network of all people from the original interest graph.

d = json_graph.node_link_data(h)
json.dump(d, open('resources/ch07-github/force.json', 'w'))


# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

# A D3 template for displaying the graph data.
viz_file = 'files/resources/ch07-github/force.html'

# Display the D3 visualization.

display(IFrame(viz_file, '100%', '600px'))
# Out:
# Stats on the full graph
# Name:
# Type: DiGraph
# Number of nodes: 1153
# Number of edges: 3573
# Average in degree:   3.0989
# Average out degree:   3.0989
#
#
# Stats on the extracted subgraph
# Name:
# Type: DiGraph
# Number of nodes: 1151
# Number of edges: 1270
# Average in degree:   1.1034
# Average out degree:   1.1034
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch07-github/force.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
