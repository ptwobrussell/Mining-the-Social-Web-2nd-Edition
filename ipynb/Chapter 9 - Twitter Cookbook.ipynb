# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 9: Twitter Cookbook
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.
#
# ## Notes
#
# This notebook is still a work in progress and currently features 25 recipes. The example titles should be fairly self-explanatory, and the code is designed to be reused as you progress further in the notebook --- meaning that you should follow along and execute each cell along the way since later cells may depend on functions being defined from earlier cells. Consider this notebook draft material at this point.

# %% [markdown]
# ## Example 1. Accessing Twitter's API for development purposes

# %%
import twitter

def oauth_login():
    # XXX: Go to http://twitter.com/apps/new to create an app and get values
    # for these credentials that you'll need to provide in place of these
    # empty string values that are defined as placeholders.
    # See https://dev.twitter.com/docs/auth/oauth for more information 
    # on Twitter's OAuth implementation.
    
    CONSUMER_KEY = ''
    CONSUMER_SECRET = ''
    OAUTH_TOKEN = ''
    OAUTH_TOKEN_SECRET = ''
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

# Sample usage
twitter_api = oauth_login()    

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x1075b57f0>

# %% [markdown]
# ## Example 2. Doing the OAuth dance to access Twitter's API for production purposes

# %%
import json
from flask import Flask, request
import multiprocessing
from threading import Timer
from IPython.display import IFrame
from IPython.display import display
from IPython.display import Javascript as JS

import twitter
from twitter.oauth_dance import parse_oauth_tokens
from twitter.oauth import read_token_file, write_token_file

# Note: This code is exactly the flow presented in the _AppendixB notebook

OAUTH_FILE = "resources/ch09-twittercookbook/twitter_oauth"

# XXX: Go to http://twitter.com/apps/new to create an app and get values
# for these credentials that you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation, and ensure that *oauth_callback*
# is defined in your application settings as shown next if you are 
# using Flask in this IPython Notebook.

# Define a few variables that will bleed into the lexical scope of a couple of 
# functions that follow
CONSUMER_KEY = ''
CONSUMER_SECRET = ''
oauth_callback = 'http://127.0.0.1:5000/oauth_helper'
    
# Set up a callback handler for when Twitter redirects back to us after the user 
# authorizes the app

webserver = Flask("TwitterOAuth")
@webserver.route("/oauth_helper")
def oauth_helper():
    
    oauth_verifier = request.args.get('oauth_verifier')

    # Pick back up credentials from ipynb_oauth_dance
    oauth_token, oauth_token_secret = read_token_file(OAUTH_FILE)
    
    _twitter = twitter.Twitter(
        auth=twitter.OAuth(
            oauth_token, oauth_token_secret, CONSUMER_KEY, CONSUMER_SECRET),
        format='', api_version=None)

    oauth_token, oauth_token_secret = parse_oauth_tokens(
        _twitter.oauth.access_token(oauth_verifier=oauth_verifier))

    # This web server only needs to service one request, so shut it down
    shutdown_after_request = request.environ.get('werkzeug.server.shutdown')
    shutdown_after_request()

    # Write out the final credentials that can be picked up after the following
    # blocking call to webserver.run().
    write_token_file(OAUTH_FILE, oauth_token, oauth_token_secret)
    return "%s %s written to %s" % (oauth_token, oauth_token_secret, OAUTH_FILE)

# To handle Twitter's OAuth 1.0a implementation, we'll just need to implement a 
# custom "oauth dance" and will closely follow the pattern defined in 
# twitter.oauth_dance.

def ipynb_oauth_dance():
    
    _twitter = twitter.Twitter(
        auth=twitter.OAuth('', '', CONSUMER_KEY, CONSUMER_SECRET),
        format='', api_version=None)

    oauth_token, oauth_token_secret = parse_oauth_tokens(
            _twitter.oauth.request_token(oauth_callback=oauth_callback))

    # Need to write these interim values out to a file to pick up on the callback 
    # from Twitter that is handled by the web server in /oauth_helper
    write_token_file(OAUTH_FILE, oauth_token, oauth_token_secret)
    
    oauth_url = ('http://api.twitter.com/oauth/authorize?oauth_token=' + oauth_token)
    
    # Tap the browser's native capabilities to access the web server through a new 
    # window to get user authorization
    display(JS("window.open('%s')" % oauth_url))

# After the webserver.run() blocking call, start the OAuth Dance that will
# ultimately cause Twitter to redirect a request back to it. Once that request
# is serviced, the web server will shut down and program flow will resume
# with the OAUTH_FILE containing the necessary credentials.
Timer(1, lambda: ipynb_oauth_dance()).start()

webserver.run(host='0.0.0.0')

# The values that are read from this file are written out at
# the end of /oauth_helper
oauth_token, oauth_token_secret = read_token_file(OAUTH_FILE)

# These four credentials are what is needed to authorize the application
auth = twitter.oauth.OAuth(oauth_token, oauth_token_secret,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
twitter_api = twitter.Twitter(auth=auth)

print(twitter_api)
# Out:
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/temp/anaconda/lib/python3.6/site-packages/twitter/api.py", line 341, in _handle_response
#     handle = urllib_request.urlopen(req, **kwargs)
#   File "/Users/temp/anaconda/lib/python3.6/urllib/request.py", line 223, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/temp/anaconda/lib/python3.6/urllib/request.py", line 532, in open
#     response = meth(req, response)
#   File "/Users/temp/anaconda/lib/python3.6/urllib/request.py", line 642, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/Users/temp/anaconda/lib/python3.6/urllib/request.py", line 570, in error
#     return self._call_chain(*args)
#   File "/Users/temp/anaconda/lib/python3.6/urllib/request.py", line 504, in _call_chain
#     result = func(*args)
#   File "/Users/temp/anaconda/lib/python3.6/urllib/request.py", line 650, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 401: Authorization Required
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/temp/anaconda/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/temp/anaconda/lib/python3.6/threading.py", line 1182, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-5-f0df48462198>", line 87, in <lambda>
#     Timer(1, lambda: ipynb_oauth_dance()).start()
#   File "<ipython-input-5-f0df48462198>", line 71, in ipynb_oauth_dance
#     _twitter.oauth.request_token(oauth_callback=oauth_callback))
#   File "/Users/temp/anaconda/lib/python3.6/site-packages/twitter/api.py", line 334, in __call__
#     return self._handle_response(req, uri, arg_data, _timeout)
#   File "/Users/temp/anaconda/lib/python3.6/site-packages/twitter/api.py", line 367, in _handle_response
#     raise TwitterHTTPError(e, uri, self.format, arg_data)
# twitter.api.TwitterHTTPError: Twitter sent status 401 for URL: oauth/request_token using parameters: (oauth_callback=http%3A%2F%2F127.0.0.1%3A5000%2Foauth_helper&oauth_consumer_key=k7TcWQNvLAFw6UHp8b6tjSfys&oauth_nonce=6301310725082399465&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1525124008&oauth_version=1.0&oauth_signature=Bv2axyh3yF5BV%2B%2FYyXooiKNeGIo%3D)
# details: <?xml version="1.0" encoding="UTF-8"?>
# <hash>
#   <error>Desktop applications only support the oauth_callback value 'oob'</error>
#   <request>/oauth/request_token</request>
# </hash>
#
#
# 127.0.0.1 - - [30/Apr/2018 17:33:32] "GET / HTTP/1.1" 404 -
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f0df48462198> in <module>()
#      91 # The values that are read from this file are written out at
#      92 # the end of /oauth_helper
# ---> 93 oauth_token, oauth_token_secret = read_token_file(OAUTH_FILE)
#      94
#      95 # These four credentials are what is needed to authorize the application
#
# /Users/temp/anaconda/lib/python3.6/site-packages/twitter/oauth.py in read_token_file(filename)
#      74     Read a token file and return the oauth token and oauth token secret.
#      75     """
# ---> 76     f = open(filename)
#      77     return f.readline().strip(), f.readline().strip()
#      78
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/ch09-twittercookbook/twitter_oauth'

# %% [markdown]
# ## Example 3. Discovering the trending topics

# %%
import json
import twitter

def twitter_trends(twitter_api, woe_id):
    # Prefix ID with the underscore for query string parameterization.
    # Without the underscore, the twitter package appends the ID value
    # to the URL itself as a special-case keyword argument.
    return twitter_api.trends.place(_id=woe_id)

# Sample usage

twitter_api = oauth_login()

# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/ for details on
# Yahoo! Where On Earth ID

WORLD_WOE_ID = 1
world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
print(json.dumps(world_trends, indent=1))

US_WOE_ID = 23424977
us_trends = twitter_trends(twitter_api, US_WOE_ID)
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#GF15",
#     "url": "http://twitter.com/search?q=%23GF15",
#     "promoted_content": null,
#     "query": "%23GF15",
#     "tweet_volume": 199997
#    },
#    {
#     "name": "#VisAVisEnFOX",
#     "url": "http://twitter.com/search?q=%23VisAVisEnFOX",
#     "promoted_content": null,
#     "query": "%23VisAVisEnFOX",
#     "tweet_volume": 13530
#    },
#    {
#     "name": "#BackToYou",
#     "url": "http://twitter.com/search?q=%23BackToYou",
#     "promoted_content": null,
#     "query": "%23BackToYou",
#     "tweet_volume": 38167
#    },
#    {
#     "name": "#NationalAdoptAShelterPetDay",
#     "url": "http://twitter.com/search?q=%23NationalAdoptAShelterPetDay",
#     "promoted_content": null,
#     "query": "%23NationalAdoptAShelterPetDay",
#     "tweet_volume": 30915
#    },
#    {
#     "name": "#\u0645\u0627\u0630\u0627_\u0642\u062f\u0645_\u0627\u0644\u0639\u064a\u0633\u064a_\u0644\u0644\u062a\u0639\u0644\u064a\u0645",
#     "url": "http://twitter.com/search?q=%23%D9%85%D8%A7%D8%B0%D8%A7_%D9%82%D8%AF%D9%85_%D8%A7%D9%84%D8%B9%D9%8A%D8%B3%D9%8A_%D9%84%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85",
#     "promoted_content": null,
#     "query": "%23%D9%85%D8%A7%D8%B0%D8%A7_%D9%82%D8%AF%D9%85_%D8%A7%D9%84%D8%B9%D9%8A%D8%B3%D9%8A_%D9%84%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85",
#     "tweet_volume": 76806
#    },
#    {
#     "name": "Betis",
#     "url": "http://twitter.com/search?q=Betis",
#     "promoted_content": null,
#     "query": "Betis",
#     "tweet_volume": 22405
#    },
#    {
#     "name": "John Kelly",
#     "url": "http://twitter.com/search?q=%22John+Kelly%22",
#     "promoted_content": null,
#     "query": "%22John+Kelly%22",
#     "tweet_volume": 20665
#    },
#    {
#     "name": "Iran",
#     "url": "http://twitter.com/search?q=Iran",
#     "promoted_content": null,
#     "query": "Iran",
#     "tweet_volume": 367052
#    },
#    {
#     "name": "Almagro",
#     "url": "http://twitter.com/search?q=Almagro",
#     "promoted_content": null,
#     "query": "Almagro",
#     "tweet_volume": 13987
#    },
#    {
#     "name": "B Nacional",
#     "url": "http://twitter.com/search?q=%22B+Nacional%22",
#     "promoted_content": null,
#     "query": "%22B+Nacional%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "All Boys",
#     "url": "http://twitter.com/search?q=%22All+Boys%22",
#     "promoted_content": null,
#     "query": "%22All+Boys%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sabrina Sato",
#     "url": "http://twitter.com/search?q=%22Sabrina+Sato%22",
#     "promoted_content": null,
#     "query": "%22Sabrina+Sato%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Netanyahu",
#     "url": "http://twitter.com/search?q=Netanyahu",
#     "promoted_content": null,
#     "query": "Netanyahu",
#     "tweet_volume": 208549
#    },
#    {
#     "name": "#Birlikte1May\u0131sa",
#     "url": "http://twitter.com/search?q=%23Birlikte1May%C4%B1sa",
#     "promoted_content": null,
#     "query": "%23Birlikte1May%C4%B1sa",
#     "tweet_volume": 13862
#    },
#    {
#     "name": "#\u0648\u0634_\u0646\u0627\u0648\u064a_\u062a\u062a\u0633\u062d\u0631_\u0628\u0631\u0645\u0636\u0627\u0646",
#     "url": "http://twitter.com/search?q=%23%D9%88%D8%B4_%D9%86%D8%A7%D9%88%D9%8A_%D8%AA%D8%AA%D8%B3%D8%AD%D8%B1_%D8%A8%D8%B1%D9%85%D8%B6%D8%A7%D9%86",
#     "promoted_content": null,
#     "query": "%23%D9%88%D8%B4_%D9%86%D8%A7%D9%88%D9%8A_%D8%AA%D8%AA%D8%B3%D8%AD%D8%B1_%D8%A8%D8%B1%D9%85%D8%B6%D8%A7%D9%86",
#     "tweet_volume": 17030
#    },
#    {
#     "name": "#FelizD\u00edaDelNi\u00f1o",
#     "url": "http://twitter.com/search?q=%23FelizD%C3%ADaDelNi%C3%B1o",
#     "promoted_content": null,
#     "query": "%23FelizD%C3%ADaDelNi%C3%B1o",
#     "tweet_volume": 63927
#    },
#    {
#     "name": "#\u062a\u0631\u0643\u064a_\u0627\u0644_\u0627\u0644\u0634\u064a\u062e_\u064a\u0642\u0641_\u0636\u062f_\u0627\u0644\u0646\u0635\u06312",
#     "url": "http://twitter.com/search?q=%23%D8%AA%D8%B1%D9%83%D9%8A_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE_%D9%8A%D9%82%D9%81_%D8%B6%D8%AF_%D8%A7%D9%84%D9%86%D8%B5%D8%B12",
#     "promoted_content": null,
#     "query": "%23%D8%AA%D8%B1%D9%83%D9%8A_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE_%D9%8A%D9%82%D9%81_%D8%B6%D8%AF_%D8%A7%D9%84%D9%86%D8%B5%D8%B12",
#     "tweet_volume": 30689
#    },
#    {
#     "name": "#TOTWAT",
#     "url": "http://twitter.com/search?q=%23TOTWAT",
#     "promoted_content": null,
#     "query": "%23TOTWAT",
#     "tweet_volume": 10313
#    },
#    {
#     "name": "#OnlarKonu\u015furAkPartiYapar",
#     "url": "http://twitter.com/search?q=%23OnlarKonu%C5%9FurAkPartiYapar",
#     "promoted_content": null,
#     "query": "%23OnlarKonu%C5%9FurAkPartiYapar",
#     "tweet_volume": 33468
#    },
#    {
#     "name": "#\u0627\u0644\u0631\u062c\u0644_\u0627\u0644\u0634\u0631\u0642\u064a_\u0628\u0643\u0644\u0645\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B1%D8%AC%D9%84_%D8%A7%D9%84%D8%B4%D8%B1%D9%82%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%B1%D8%AC%D9%84_%D8%A7%D9%84%D8%B4%D8%B1%D9%82%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ContigoAitana",
#     "url": "http://twitter.com/search?q=%23ContigoAitana",
#     "promoted_content": null,
#     "query": "%23ContigoAitana",
#     "tweet_volume": 13338
#    },
#    {
#     "name": "#FirstDates627",
#     "url": "http://twitter.com/search?q=%23FirstDates627",
#     "promoted_content": null,
#     "query": "%23FirstDates627",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NSYNC",
#     "url": "http://twitter.com/search?q=%23NSYNC",
#     "promoted_content": null,
#     "query": "%23NSYNC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ARMYSelcaDay",
#     "url": "http://twitter.com/search?q=%23ARMYSelcaDay",
#     "promoted_content": null,
#     "query": "%23ARMYSelcaDay",
#     "tweet_volume": 384793
#    },
#    {
#     "name": "#PuntoDedazoSanidad",
#     "url": "http://twitter.com/search?q=%23PuntoDedazoSanidad",
#     "promoted_content": null,
#     "query": "%23PuntoDedazoSanidad",
#     "tweet_volume": null
#    },
#    {
#     "name": "#30Abr",
#     "url": "http://twitter.com/search?q=%2330Abr",
#     "promoted_content": null,
#     "query": "%2330Abr",
#     "tweet_volume": 66980
#    },
#    {
#     "name": "#\u0627\u0646\u0641\u0635\u0627\u0644_\u0633\u0627\u0631\u0647_\u0627\u0644\u0648\u062f\u0639\u0627\u0646\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%86%D9%81%D8%B5%D8%A7%D9%84_%D8%B3%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D9%88%D8%AF%D8%B9%D8%A7%D9%86%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%86%D9%81%D8%B5%D8%A7%D9%84_%D8%B3%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D9%88%D8%AF%D8%B9%D8%A7%D9%86%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#conquis16",
#     "url": "http://twitter.com/search?q=%23conquis16",
#     "promoted_content": null,
#     "query": "%23conquis16",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0644\u0627\u0633\u064a\u0648\u0637\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7%D8%B3%D9%8A%D9%88%D8%B7%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%A7%D8%B3%D9%8A%D9%88%D8%B7%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CSKvDD",
#     "url": "http://twitter.com/search?q=%23CSKvDD",
#     "promoted_content": null,
#     "query": "%23CSKvDD",
#     "tweet_volume": 64519
#    },
#    {
#     "name": "#Sky90",
#     "url": "http://twitter.com/search?q=%23Sky90",
#     "promoted_content": null,
#     "query": "%23Sky90",
#     "tweet_volume": null
#    },
#    {
#     "name": "#holocaustoamarillo",
#     "url": "http://twitter.com/search?q=%23holocaustoamarillo",
#     "promoted_content": null,
#     "query": "%23holocaustoamarillo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SmallBusinessWeek",
#     "url": "http://twitter.com/search?q=%23SmallBusinessWeek",
#     "promoted_content": null,
#     "query": "%23SmallBusinessWeek",
#     "tweet_volume": 12332
#    },
#    {
#     "name": "#ArianaIsTop3Party",
#     "url": "http://twitter.com/search?q=%23ArianaIsTop3Party",
#     "promoted_content": null,
#     "query": "%23ArianaIsTop3Party",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OjosQueNoVen",
#     "url": "http://twitter.com/search?q=%23OjosQueNoVen",
#     "promoted_content": null,
#     "query": "%23OjosQueNoVen",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0643\u0644\u0645\u0647_\u062c\u0645\u064a\u0644\u0647_\u062a\u0637\u064a\u0628_\u0627\u0644\u062e\u0627\u0637\u0631",
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84%D9%85%D9%87_%D8%AC%D9%85%D9%8A%D9%84%D9%87_%D8%AA%D8%B7%D9%8A%D8%A8_%D8%A7%D9%84%D8%AE%D8%A7%D8%B7%D8%B1",
#     "promoted_content": null,
#     "query": "%23%D9%83%D9%84%D9%85%D9%87_%D8%AC%D9%85%D9%8A%D9%84%D9%87_%D8%AA%D8%B7%D9%8A%D8%A8_%D8%A7%D9%84%D8%AE%D8%A7%D8%B7%D8%B1",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AntmanAndTheWasp",
#     "url": "http://twitter.com/search?q=%23AntmanAndTheWasp",
#     "promoted_content": null,
#     "query": "%23AntmanAndTheWasp",
#     "tweet_volume": 23286
#    },
#    {
#     "name": "#Malha\u00e7\u00e3o",
#     "url": "http://twitter.com/search?q=%23Malha%C3%A7%C3%A3o",
#     "promoted_content": null,
#     "query": "%23Malha%C3%A7%C3%A3o",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u00e7ukurdahesapzaman\u0131",
#     "url": "http://twitter.com/search?q=%23%C3%A7ukurdahesapzaman%C4%B1",
#     "promoted_content": null,
#     "query": "%23%C3%A7ukurdahesapzaman%C4%B1",
#     "tweet_volume": 17051
#    },
#    {
#     "name": "#Ratatouille",
#     "url": "http://twitter.com/search?q=%23Ratatouille",
#     "promoted_content": null,
#     "query": "%23Ratatouille",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KYKdaKandilBa\u015fkad\u0131r",
#     "url": "http://twitter.com/search?q=%23KYKdaKandilBa%C5%9Fkad%C4%B1r",
#     "promoted_content": null,
#     "query": "%23KYKdaKandilBa%C5%9Fkad%C4%B1r",
#     "tweet_volume": null
#    },
#    {
#     "name": "#2018GEO",
#     "url": "http://twitter.com/search?q=%232018GEO",
#     "promoted_content": null,
#     "query": "%232018GEO",
#     "tweet_volume": null
#    },
#    {
#     "name": "#InArtePattyPravo",
#     "url": "http://twitter.com/search?q=%23InArtePattyPravo",
#     "promoted_content": null,
#     "query": "%23InArtePattyPravo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HBDThalaAJITH",
#     "url": "http://twitter.com/search?q=%23HBDThalaAJITH",
#     "promoted_content": null,
#     "query": "%23HBDThalaAJITH",
#     "tweet_volume": 737816
#    },
#    {
#     "name": "#\u0648\u0641\u0627\u0647_\u062d\u0644\u0627_\u0627\u0644\u062a\u0631\u0643",
#     "url": "http://twitter.com/search?q=%23%D9%88%D9%81%D8%A7%D9%87_%D8%AD%D9%84%D8%A7_%D8%A7%D9%84%D8%AA%D8%B1%D9%83",
#     "promoted_content": null,
#     "query": "%23%D9%88%D9%81%D8%A7%D9%87_%D8%AD%D9%84%D8%A7_%D8%A7%D9%84%D8%AA%D8%B1%D9%83",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RCLPFC",
#     "url": "http://twitter.com/search?q=%23RCLPFC",
#     "promoted_content": null,
#     "query": "%23RCLPFC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ConPjanicEspulso",
#     "url": "http://twitter.com/search?q=%23ConPjanicEspulso",
#     "promoted_content": null,
#     "query": "%23ConPjanicEspulso",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheIsland",
#     "url": "http://twitter.com/search?q=%23TheIsland",
#     "promoted_content": null,
#     "query": "%23TheIsland",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FCNEBS",
#     "url": "http://twitter.com/search?q=%23FCNEBS",
#     "promoted_content": null,
#     "query": "%23FCNEBS",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-04-30T21:34:30Z",
#   "created_at": "2018-04-30T21:31:06Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "trends": [
#    {
#     "name": "#NationalAdoptAShelterPetDay",
#     "url": "http://twitter.com/search?q=%23NationalAdoptAShelterPetDay",
#     "promoted_content": null,
#     "query": "%23NationalAdoptAShelterPetDay",
#     "tweet_volume": 30915
#    },
#    {
#     "name": "John Kelly",
#     "url": "http://twitter.com/search?q=%22John+Kelly%22",
#     "promoted_content": null,
#     "query": "%22John+Kelly%22",
#     "tweet_volume": 20665
#    },
#    {
#     "name": "Iran",
#     "url": "http://twitter.com/search?q=Iran",
#     "promoted_content": null,
#     "query": "Iran",
#     "tweet_volume": 367052
#    },
#    {
#     "name": "#NSYNC",
#     "url": "http://twitter.com/search?q=%23NSYNC",
#     "promoted_content": null,
#     "query": "%23NSYNC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SmallBusinessWeek",
#     "url": "http://twitter.com/search?q=%23SmallBusinessWeek",
#     "promoted_content": null,
#     "query": "%23SmallBusinessWeek",
#     "tweet_volume": 12332
#    },
#    {
#     "name": "Blac Chyna",
#     "url": "http://twitter.com/search?q=%22Blac+Chyna%22",
#     "promoted_content": null,
#     "query": "%22Blac+Chyna%22",
#     "tweet_volume": 24375
#    },
#    {
#     "name": "#2018GEO",
#     "url": "http://twitter.com/search?q=%232018GEO",
#     "promoted_content": null,
#     "query": "%232018GEO",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ActivitiesToAvoidOnProbation",
#     "url": "http://twitter.com/search?q=%23ActivitiesToAvoidOnProbation",
#     "promoted_content": null,
#     "query": "%23ActivitiesToAvoidOnProbation",
#     "tweet_volume": null
#    },
#    {
#     "name": "Netanyahu",
#     "url": "http://twitter.com/search?q=Netanyahu",
#     "promoted_content": null,
#     "query": "Netanyahu",
#     "tweet_volume": 208549
#    },
#    {
#     "name": "Jan Koum",
#     "url": "http://twitter.com/search?q=%22Jan+Koum%22",
#     "promoted_content": null,
#     "query": "%22Jan+Koum%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Marco Rubio",
#     "url": "http://twitter.com/search?q=%22Marco+Rubio%22",
#     "promoted_content": null,
#     "query": "%22Marco+Rubio%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Roy Moore",
#     "url": "http://twitter.com/search?q=%22Roy+Moore%22",
#     "promoted_content": null,
#     "query": "%22Roy+Moore%22",
#     "tweet_volume": 11136
#    },
#    {
#     "name": "The Killer",
#     "url": "http://twitter.com/search?q=%22The+Killer%22",
#     "promoted_content": null,
#     "query": "%22The+Killer%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Northgate High School",
#     "url": "http://twitter.com/search?q=%22Northgate+High+School%22",
#     "promoted_content": null,
#     "query": "%22Northgate+High+School%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ron Francis",
#     "url": "http://twitter.com/search?q=%22Ron+Francis%22",
#     "promoted_content": null,
#     "query": "%22Ron+Francis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Silent Sam",
#     "url": "http://twitter.com/search?q=%22Silent+Sam%22",
#     "promoted_content": null,
#     "query": "%22Silent+Sam%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Player of the Week",
#     "url": "http://twitter.com/search?q=%22Player+of+the+Week%22",
#     "promoted_content": null,
#     "query": "%22Player+of+the+Week%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mookie Betts",
#     "url": "http://twitter.com/search?q=%22Mookie+Betts%22",
#     "promoted_content": null,
#     "query": "%22Mookie+Betts%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "CB Elie Bouka",
#     "url": "http://twitter.com/search?q=%22CB+Elie+Bouka%22",
#     "promoted_content": null,
#     "query": "%22CB+Elie+Bouka%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Thomas Homan",
#     "url": "http://twitter.com/search?q=%22Thomas+Homan%22",
#     "promoted_content": null,
#     "query": "%22Thomas+Homan%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Porsches",
#     "url": "http://twitter.com/search?q=Porsches",
#     "promoted_content": null,
#     "query": "Porsches",
#     "tweet_volume": null
#    },
#    {
#     "name": "Terence Newman",
#     "url": "http://twitter.com/search?q=%22Terence+Newman%22",
#     "promoted_content": null,
#     "query": "%22Terence+Newman%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "JCPS",
#     "url": "http://twitter.com/search?q=JCPS",
#     "promoted_content": null,
#     "query": "JCPS",
#     "tweet_volume": null
#    },
#    {
#     "name": "David McCollum",
#     "url": "http://twitter.com/search?q=%22David+McCollum%22",
#     "promoted_content": null,
#     "query": "%22David+McCollum%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Justice Sotomayor",
#     "url": "http://twitter.com/search?q=%22Justice+Sotomayor%22",
#     "promoted_content": null,
#     "query": "%22Justice+Sotomayor%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "QB Joe Callahan",
#     "url": "http://twitter.com/search?q=%22QB+Joe+Callahan%22",
#     "promoted_content": null,
#     "query": "%22QB+Joe+Callahan%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "George Mason University",
#     "url": "http://twitter.com/search?q=%22George+Mason+University%22",
#     "promoted_content": null,
#     "query": "%22George+Mason+University%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Amber Alert",
#     "url": "http://twitter.com/search?q=%22Amber+Alert%22",
#     "promoted_content": null,
#     "query": "%22Amber+Alert%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThankYouCecile",
#     "url": "http://twitter.com/search?q=%23ThankYouCecile",
#     "promoted_content": null,
#     "query": "%23ThankYouCecile",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DellTechWorld",
#     "url": "http://twitter.com/search?q=%23DellTechWorld",
#     "promoted_content": null,
#     "query": "%23DellTechWorld",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BackToYou",
#     "url": "http://twitter.com/search?q=%23BackToYou",
#     "promoted_content": null,
#     "query": "%23BackToYou",
#     "tweet_volume": 38167
#    },
#    {
#     "name": "#MIGlobal",
#     "url": "http://twitter.com/search?q=%23MIGlobal",
#     "promoted_content": null,
#     "query": "%23MIGlobal",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MKTGnation",
#     "url": "http://twitter.com/search?q=%23MKTGnation",
#     "promoted_content": null,
#     "query": "%23MKTGnation",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AntManandtheWasp",
#     "url": "http://twitter.com/search?q=%23AntManandtheWasp",
#     "promoted_content": null,
#     "query": "%23AntManandtheWasp",
#     "tweet_volume": 23287
#    },
#    {
#     "name": "#SummitOfPower",
#     "url": "http://twitter.com/search?q=%23SummitOfPower",
#     "promoted_content": null,
#     "query": "%23SummitOfPower",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MusicMonday",
#     "url": "http://twitter.com/search?q=%23MusicMonday",
#     "promoted_content": null,
#     "query": "%23MusicMonday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DWTS",
#     "url": "http://twitter.com/search?q=%23DWTS",
#     "promoted_content": null,
#     "query": "%23DWTS",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IfPacManCouldTalk",
#     "url": "http://twitter.com/search?q=%23IfPacManCouldTalk",
#     "promoted_content": null,
#     "query": "%23IfPacManCouldTalk",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ArianaIsTop3Party",
#     "url": "http://twitter.com/search?q=%23ArianaIsTop3Party",
#     "promoted_content": null,
#     "query": "%23ArianaIsTop3Party",
#     "tweet_volume": null
#    },
#    {
#     "name": "#COYS",
#     "url": "http://twitter.com/search?q=%23COYS",
#     "promoted_content": null,
#     "query": "%23COYS",
#     "tweet_volume": 10175
#    },
#    {
#     "name": "#MotivationMonday",
#     "url": "http://twitter.com/search?q=%23MotivationMonday",
#     "promoted_content": null,
#     "query": "%23MotivationMonday",
#     "tweet_volume": 11881
#    },
#    {
#     "name": "#FixFAFSA",
#     "url": "http://twitter.com/search?q=%23FixFAFSA",
#     "promoted_content": null,
#     "query": "%23FixFAFSA",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KKWBODY",
#     "url": "http://twitter.com/search?q=%23KKWBODY",
#     "promoted_content": null,
#     "query": "%23KKWBODY",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ContentChat",
#     "url": "http://twitter.com/search?q=%23ContentChat",
#     "promoted_content": null,
#     "query": "%23ContentChat",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TravelAlaskaChat",
#     "url": "http://twitter.com/search?q=%23TravelAlaskaChat",
#     "promoted_content": null,
#     "query": "%23TravelAlaskaChat",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HolderForum",
#     "url": "http://twitter.com/search?q=%23HolderForum",
#     "promoted_content": null,
#     "query": "%23HolderForum",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HMPS18",
#     "url": "http://twitter.com/search?q=%23HMPS18",
#     "promoted_content": null,
#     "query": "%23HMPS18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SmartPhoneMusic",
#     "url": "http://twitter.com/search?q=%23SmartPhoneMusic",
#     "promoted_content": null,
#     "query": "%23SmartPhoneMusic",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CCAC2018",
#     "url": "http://twitter.com/search?q=%23CCAC2018",
#     "promoted_content": null,
#     "query": "%23CCAC2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheFive",
#     "url": "http://twitter.com/search?q=%23TheFive",
#     "promoted_content": null,
#     "query": "%23TheFive",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-04-30T21:34:30Z",
#   "created_at": "2018-04-30T21:31:06Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Searching for tweets

# %%
def twitter_search(twitter_api, q, max_results=200, **kw):

    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets and 
    # https://dev.twitter.com/docs/using-search for details on advanced 
    # search criteria that may be useful for keyword arguments
    
    # See https://dev.twitter.com/docs/api/1.1/get/search/tweets    
    search_results = twitter_api.search.tweets(q=q, count=100, **kw)
    
    statuses = search_results['statuses']
    
    # Iterate through batches of results by following the cursor until we
    # reach the desired number of results, keeping in mind that OAuth users
    # can "only" make 180 search queries per 15-minute interval. See
    # https://dev.twitter.com/docs/rate-limiting/1.1/limits
    # for details. A reasonable number of results is ~1000, although
    # that number of results may not exist for all queries.
    
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError: # No more results when next_results doesn't exist
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        
        if len(statuses) > max_results: 
            break
            
    return statuses

# Sample usage

twitter_api = oauth_login()

q = "CrossFit"
results = twitter_search(twitter_api, q, max_results=10)
        
# Show one sample search result by slicing the list...
print(json.dumps(results[0], indent=1))
# Out:
# {
#  "created_at": "Mon Apr 30 21:34:12 +0000 2018",
#  "id": 991068223281029121,
#  "id_str": "991068223281029121",
#  "text": "#mondaymotivation #strength #training #crossfit https://t.co/uMqCXSfV1h",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "mondaymotivation",
#     "indices": [
#      0,
#      17
#     ]
#    },
#    {
#     "text": "strength",
#     "indices": [
#      18,
#      27
#     ]
#    },
#    {
#     "text": "training",
#     "indices": [
#      28,
#      37
#     ]
#    },
#    {
#     "text": "crossfit",
#     "indices": [
#      38,
#      47
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/uMqCXSfV1h",
#     "expanded_url": "https://www.instagram.com/p/BiNbgMCntCk/?utm_source=twitter",
#     "display_url": "instagram.com/p/BiNbgMCntCk/\u2026",
#     "indices": [
#      48,
#      71
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "und",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 814105939989164033,
#   "id_str": "814105939989164033",
#   "name": "CrossFit Ridgeway",
#   "screen_name": "CFRidgeway",
#   "location": "Rochester, NY",
#   "description": "Improve Health. Lose Weight. Look Better. CrossFit Ridgeway wants to provide every person that walks through the door the best one hour of their day.",
#   "url": "https://t.co/cwLHjPQUbk",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/cwLHjPQUbk",
#       "expanded_url": "https://crossfitridgeway.com",
#       "display_url": "crossfitridgeway.com",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 44,
#   "friends_count": 109,
#   "listed_count": 2,
#   "created_at": "Wed Dec 28 13:49:16 +0000 2016",
#   "favourites_count": 260,
#   "utc_offset": -25200,
#   "time_zone": "Pacific Time (US & Canada)",
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 371,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/892499333836226560/fb0-5z2H_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/892499333836226560/fb0-5z2H_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/814105939989164033/1501623408",
#   "profile_link_color": "B62127",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "und"
# }

# %% [markdown]
# ## Example 5. Constructing convenient function calls

# %%
from functools import partial

pp = partial(json.dumps, indent=1)

twitter_world_trends = partial(twitter_trends, twitter_api, WORLD_WOE_ID)

print(pp(twitter_world_trends()))

authenticated_twitter_search = partial(twitter_search, twitter_api)
results = authenticated_twitter_search("iPhone")
print(pp(results))

authenticated_iphone_twitter_search = partial(authenticated_twitter_search, "iPhone")
results = authenticated_iphone_twitter_search()
print(pp(results))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#GF15",
#     "url": "http://twitter.com/search?q=%23GF15",
#     "promoted_content": null,
#     "query": "%23GF15",
#     "tweet_volume": 199997
#    },
#    {
#     "name": "#VisAVisEnFOX",
#     "url": "http://twitter.com/search?q=%23VisAVisEnFOX",
#     "promoted_content": null,
#     "query": "%23VisAVisEnFOX",
#     "tweet_volume": 13530
#    },
#    {
#     "name": "#BackToYou",
#     "url": "http://twitter.com/search?q=%23BackToYou",
#     "promoted_content": null,
#     "query": "%23BackToYou",
#     "tweet_volume": 38167
#    },
#    {
#     "name": "#NationalAdoptAShelterPetDay",
#     "url": "http://twitter.com/search?q=%23NationalAdoptAShelterPetDay",
#     "promoted_content": null,
#     "query": "%23NationalAdoptAShelterPetDay",
#     "tweet_volume": 30915
#    },
#    {
#     "name": "#\u0645\u0627\u0630\u0627_\u0642\u062f\u0645_\u0627\u0644\u0639\u064a\u0633\u064a_\u0644\u0644\u062a\u0639\u0644\u064a\u0645",
#     "url": "http://twitter.com/search?q=%23%D9%85%D8%A7%D8%B0%D8%A7_%D9%82%D8%AF%D9%85_%D8%A7%D9%84%D8%B9%D9%8A%D8%B3%D9%8A_%D9%84%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85",
#     "promoted_content": null,
#     "query": "%23%D9%85%D8%A7%D8%B0%D8%A7_%D9%82%D8%AF%D9%85_%D8%A7%D9%84%D8%B9%D9%8A%D8%B3%D9%8A_%D9%84%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85",
#     "tweet_volume": 76806
#    },
#    {
#     "name": "Betis",
#     "url": "http://twitter.com/search?q=Betis",
#     "promoted_content": null,
#     "query": "Betis",
#     "tweet_volume": 22405
#    },
#    {
#     "name": "John Kelly",
#     "url": "http://twitter.com/search?q=%22John+Kelly%22",
#     "promoted_content": null,
#     "query": "%22John+Kelly%22",
#     "tweet_volume": 20665
#    },
#    {
#     "name": "Iran",
#     "url": "http://twitter.com/search?q=Iran",
#     "promoted_content": null,
#     "query": "Iran",
#     "tweet_volume": 367052
#    },
#    {
#     "name": "Almagro",
#     "url": "http://twitter.com/search?q=Almagro",
#     "promoted_content": null,
#     "query": "Almagro",
#     "tweet_volume": 13987
#    },
#    {
#     "name": "B Nacional",
#     "url": "http://twitter.com/search?q=%22B+Nacional%22",
#     "promoted_content": null,
#     "query": "%22B+Nacional%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "All Boys",
#     "url": "http://twitter.com/search?q=%22All+Boys%22",
#     "promoted_content": null,
#     "query": "%22All+Boys%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Blac Chyna",
#     "url": "http://twitter.com/search?q=%22Blac+Chyna%22",
#     "promoted_content": null,
#     "query": "%22Blac+Chyna%22",
#     "tweet_volume": 24375
#    },
#    {
#     "name": "Sabrina Sato",
#     "url": "http://twitter.com/search?q=%22Sabrina+Sato%22",
#     "promoted_content": null,
#     "query": "%22Sabrina+Sato%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Netanyahu",
#     "url": "http://twitter.com/search?q=Netanyahu",
#     "promoted_content": null,
#     "query": "Netanyahu",
#     "tweet_volume": 208549
#    },
#    {
#     "name": "#Birlikte1May\u0131sa",
#     "url": "http://twitter.com/search?q=%23Birlikte1May%C4%B1sa",
#     "promoted_content": null,
#     "query": "%23Birlikte1May%C4%B1sa",
#     "tweet_volume": 13862
#    },
#    {
#     "name": "#\u0648\u0634_\u0646\u0627\u0648\u064a_\u062a\u062a\u0633\u062d\u0631_\u0628\u0631\u0645\u0636\u0627\u0646",
#     "url": "http://twitter.com/search?q=%23%D9%88%D8%B4_%D9%86%D8%A7%D9%88%D9%8A_%D8%AA%D8%AA%D8%B3%D8%AD%D8%B1_%D8%A8%D8%B1%D9%85%D8%B6%D8%A7%D9%86",
#     "promoted_content": null,
#     "query": "%23%D9%88%D8%B4_%D9%86%D8%A7%D9%88%D9%8A_%D8%AA%D8%AA%D8%B3%D8%AD%D8%B1_%D8%A8%D8%B1%D9%85%D8%B6%D8%A7%D9%86",
#     "tweet_volume": 17030
#    },
#    {
#     "name": "#FelizD\u00edaDelNi\u00f1o",
#     "url": "http://twitter.com/search?q=%23FelizD%C3%ADaDelNi%C3%B1o",
#     "promoted_content": null,
#     "query": "%23FelizD%C3%ADaDelNi%C3%B1o",
#     "tweet_volume": 63927
#    },
#    {
#     "name": "#\u062a\u0631\u0643\u064a_\u0627\u0644_\u0627\u0644\u0634\u064a\u062e_\u064a\u0642\u0641_\u0636\u062f_\u0627\u0644\u0646\u0635\u06312",
#     "url": "http://twitter.com/search?q=%23%D8%AA%D8%B1%D9%83%D9%8A_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE_%D9%8A%D9%82%D9%81_%D8%B6%D8%AF_%D8%A7%D9%84%D9%86%D8%B5%D8%B12",
#     "promoted_content": null,
#     "query": "%23%D8%AA%D8%B1%D9%83%D9%8A_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE_%D9%8A%D9%82%D9%81_%D8%B6%D8%AF_%D8%A7%D9%84%D9%86%D8%B5%D8%B12",
#     "tweet_volume": 30689
#    },
#    {
#     "name": "#TOTWAT",
#     "url": "http://twitter.com/search?q=%23TOTWAT",
#     "promoted_content": null,
#     "query": "%23TOTWAT",
#     "tweet_volume": 10313
#    },
#    {
#     "name": "#OnlarKonu\u015furAkPartiYapar",
#     "url": "http://twitter.com/search?q=%23OnlarKonu%C5%9FurAkPartiYapar",
#     "promoted_content": null,
#     "query": "%23OnlarKonu%C5%9FurAkPartiYapar",
#     "tweet_volume": 33468
#    },
#    {
#     "name": "#\u0627\u0644\u0631\u062c\u0644_\u0627\u0644\u0634\u0631\u0642\u064a_\u0628\u0643\u0644\u0645\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B1%D8%AC%D9%84_%D8%A7%D9%84%D8%B4%D8%B1%D9%82%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%B1%D8%AC%D9%84_%D8%A7%D9%84%D8%B4%D8%B1%D9%82%D9%8A_%D8%A8%D9%83%D9%84%D9%85%D9%87",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ContigoAitana",
#     "url": "http://twitter.com/search?q=%23ContigoAitana",
#     "promoted_content": null,
#     "query": "%23ContigoAitana",
#     "tweet_volume": 13338
#    },
#    {
#     "name": "#FirstDates627",
#     "url": "http://twitter.com/search?q=%23FirstDates627",
#     "promoted_content": null,
#     "query": "%23FirstDates627",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NSYNC",
#     "url": "http://twitter.com/search?q=%23NSYNC",
#     "promoted_content": null,
#     "query": "%23NSYNC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ARMYSelcaDay",
#     "url": "http://twitter.com/search?q=%23ARMYSelcaDay",
#     "promoted_content": null,
#     "query": "%23ARMYSelcaDay",
#     "tweet_volume": 384793
#    },
#    {
#     "name": "#PuntoDedazoSanidad",
#     "url": "http://twitter.com/search?q=%23PuntoDedazoSanidad",
#     "promoted_content": null,
#     "query": "%23PuntoDedazoSanidad",
#     "tweet_volume": null
#    },
#    {
#     "name": "#30Abr",
#     "url": "http://twitter.com/search?q=%2330Abr",
#     "promoted_content": null,
#     "query": "%2330Abr",
#     "tweet_volume": 66980
#    },
#    {
#     "name": "#\u0627\u0646\u0641\u0635\u0627\u0644_\u0633\u0627\u0631\u0647_\u0627\u0644\u0648\u062f\u0639\u0627\u0646\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%86%D9%81%D8%B5%D8%A7%D9%84_%D8%B3%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D9%88%D8%AF%D8%B9%D8%A7%D9%86%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%86%D9%81%D8%B5%D8%A7%D9%84_%D8%B3%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D9%88%D8%AF%D8%B9%D8%A7%D9%86%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#conquis16",
#     "url": "http://twitter.com/search?q=%23conquis16",
#     "promoted_content": null,
#     "query": "%23conquis16",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0644\u0627\u0633\u064a\u0648\u0637\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7%D8%B3%D9%8A%D9%88%D8%B7%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%A7%D8%B3%D9%8A%D9%88%D8%B7%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CSKvDD",
#     "url": "http://twitter.com/search?q=%23CSKvDD",
#     "promoted_content": null,
#     "query": "%23CSKvDD",
#     "tweet_volume": 64519
#    },
#    {
#     "name": "#Sky90",
#     "url": "http://twitter.com/search?q=%23Sky90",
#     "promoted_content": null,
#     "query": "%23Sky90",
#     "tweet_volume": null
#    },
#    {
#     "name": "#holocaustoamarillo",
#     "url": "http://twitter.com/search?q=%23holocaustoamarillo",
#     "promoted_content": null,
#     "query": "%23holocaustoamarillo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SmallBusinessWeek",
#     "url": "http://twitter.com/search?q=%23SmallBusinessWeek",
#     "promoted_content": null,
#     "query": "%23SmallBusinessWeek",
#     "tweet_volume": 12332
#    },
#    {
#     "name": "#ArianaIsTop3Party",
#     "url": "http://twitter.com/search?q=%23ArianaIsTop3Party",
#     "promoted_content": null,
#     "query": "%23ArianaIsTop3Party",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OjosQueNoVen",
#     "url": "http://twitter.com/search?q=%23OjosQueNoVen",
#     "promoted_content": null,
#     "query": "%23OjosQueNoVen",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0643\u0644\u0645\u0647_\u062c\u0645\u064a\u0644\u0647_\u062a\u0637\u064a\u0628_\u0627\u0644\u062e\u0627\u0637\u0631",
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84%D9%85%D9%87_%D8%AC%D9%85%D9%8A%D9%84%D9%87_%D8%AA%D8%B7%D9%8A%D8%A8_%D8%A7%D9%84%D8%AE%D8%A7%D8%B7%D8%B1",
#     "promoted_content": null,
#     "query": "%23%D9%83%D9%84%D9%85%D9%87_%D8%AC%D9%85%D9%8A%D9%84%D9%87_%D8%AA%D8%B7%D9%8A%D8%A8_%D8%A7%D9%84%D8%AE%D8%A7%D8%B7%D8%B1",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AntmanAndTheWasp",
#     "url": "http://twitter.com/search?q=%23AntmanAndTheWasp",
#     "promoted_content": null,
#     "query": "%23AntmanAndTheWasp",
#     "tweet_volume": 23286
#    },
#    {
#     "name": "#Malha\u00e7\u00e3o",
#     "url": "http://twitter.com/search?q=%23Malha%C3%A7%C3%A3o",
#     "promoted_content": null,
#     "query": "%23Malha%C3%A7%C3%A3o",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u00e7ukurdahesapzaman\u0131",
#     "url": "http://twitter.com/search?q=%23%C3%A7ukurdahesapzaman%C4%B1",
#     "promoted_content": null,
#     "query": "%23%C3%A7ukurdahesapzaman%C4%B1",
#     "tweet_volume": 17051
#    },
#    {
#     "name": "#Ratatouille",
#     "url": "http://twitter.com/search?q=%23Ratatouille",
#     "promoted_content": null,
#     "query": "%23Ratatouille",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KYKdaKandilBa\u015fkad\u0131r",
#     "url": "http://twitter.com/search?q=%23KYKdaKandilBa%C5%9Fkad%C4%B1r",
#     "promoted_content": null,
#     "query": "%23KYKdaKandilBa%C5%9Fkad%C4%B1r",
#     "tweet_volume": null
#    },
#    {
#     "name": "#2018GEO",
#     "url": "http://twitter.com/search?q=%232018GEO",
#     "promoted_content": null,
#     "query": "%232018GEO",
#     "tweet_volume": null
#    },
#    {
#     "name": "#InArtePattyPravo",
#     "url": "http://twitter.com/search?q=%23InArtePattyPravo",
#     "promoted_content": null,
#     "query": "%23InArtePattyPravo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HBDThalaAJITH",
#     "url": "http://twitter.com/search?q=%23HBDThalaAJITH",
#     "promoted_content": null,
#     "query": "%23HBDThalaAJITH",
#     "tweet_volume": 737816
#    },
#    {
#     "name": "#\u0648\u0641\u0627\u0647_\u062d\u0644\u0627_\u0627\u0644\u062a\u0631\u0643",
#     "url": "http://twitter.com/search?q=%23%D9%88%D9%81%D8%A7%D9%87_%D8%AD%D9%84%D8%A7_%D8%A7%D9%84%D8%AA%D8%B1%D9%83",
#     "promoted_content": null,
#     "query": "%23%D9%88%D9%81%D8%A7%D9%87_%D8%AD%D9%84%D8%A7_%D8%A7%D9%84%D8%AA%D8%B1%D9%83",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RCLPFC",
#     "url": "http://twitter.com/search?q=%23RCLPFC",
#     "promoted_content": null,
#     "query": "%23RCLPFC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ConPjanicEspulso",
#     "url": "http://twitter.com/search?q=%23ConPjanicEspulso",
#     "promoted_content": null,
#     "query": "%23ConPjanicEspulso",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheIsland",
#     "url": "http://twitter.com/search?q=%23TheIsland",
#     "promoted_content": null,
#     "query": "%23TheIsland",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FCNEBS",
#     "url": "http://twitter.com/search?q=%23FCNEBS",
#     "promoted_content": null,
#     "query": "%23FCNEBS",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-04-30T21:35:23Z",
#   "created_at": "2018-04-30T21:31:06Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "created_at": "Mon Apr 30 21:35:07 +0000 2018",
#   "id": 991068456454840320,
#   "id_str": "991068456454840320",
#   "text": "\u30e2\u30a4\uff01iPhone\u304b\u3089\u30ad\u30e3\u30b9\u914d\u4fe1\u4e2d - https://t.co/o7dhM5g7dN",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/o7dhM5g7dN",
#      "expanded_url": "http://cas.st/1b79ba5b",
#      "display_url": "cas.st/1b79ba5b",
#      "indices": [
#       20,
#       43
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "ja",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitcasting.tv/\" rel=\"nofollow\">TwitCasting</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 780442266817011714,
#    "id_str": "780442266817011714",
#    "name": "\u307f\u3063\u3061\u30fc",
#    "screen_name": "michi19981207",
#    "location": "\u65e5\u672c",
#    "description": "\u4e5d\u5dde\u56fd\u969b\u5927\u5b66 2\u5e74 \u8da3\u5473\u306f\u97f3\u697d\u3092\u8074\u304f\u3053\u3068\uff01UVERworld\u3001Da\u2212iCE\u3001MY FIRST STORY\u3001Nissy\u3068\u3053\u3093\u306a\u611f\u3058\u3067\u308f\u308a\u3068\u5e45\u5e83\u304f\u8074\u3044\u3066\u307e\u3059\uff01\u4ed6\u306b\u3082\u8074\u3044\u3066\u308b\u66f2\u306f\u304b\u306a\u308a\u3042\u308a\u307e\u3059\uff01\u30d5\u30a9\u30ed\u30fc\u3057\u305f\u3089DM\u306f\u304a\u9858\u3044\u3057\u305f\u3044 \u30c8\u30d7\u53f3",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 173,
#    "friends_count": 183,
#    "listed_count": 0,
#    "created_at": "Mon Sep 26 16:21:51 +0000 2016",
#    "favourites_count": 1688,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 5062,
#    "lang": "ja",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/979781624387616768/se_VmkjL_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/979781624387616768/se_VmkjL_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/780442266817011714/1502634636",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "ja"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:07 +0000 2018",
#   "id": 991068454928207873,
#   "id_str": "991068454928207873",
#   "text": "Want to learn how to take better pictures on your iPhone. Read my blog post to learn how. https://ww https://t.co/0Y5nkwoX4X",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/0Y5nkwoX4X",
#      "expanded_url": "https://www.pinterest.com/pin/290974825920447793/",
#      "display_url": "pinterest.com/pin/2909748259\u2026",
#      "indices": [
#       101,
#       124
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://pinterest.com\" rel=\"nofollow\">Pinterest</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 1398232920,
#    "id_str": "1398232920",
#    "name": "Kelly Dixon",
#    "screen_name": "KELLY_LUVS_BLOG",
#    "location": "Arizona, USA",
#    "description": "Lifestyle and Travel Blogger  Love my life as a Mom, a Wife & Adventure Seeker | \ud83d\udccdAZ based | Raised in MT | Grew up in CA \u2708\ufe0f | Follow along #kellyluvsblog |",
#    "url": "https://t.co/AMqgaNk1oi",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/AMqgaNk1oi",
#        "expanded_url": "http://www.kellyluvs.com",
#        "display_url": "kellyluvs.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 105,
#    "friends_count": 260,
#    "listed_count": 1,
#    "created_at": "Thu May 02 21:35:40 +0000 2013",
#    "favourites_count": 96,
#    "utc_offset": -25200,
#    "time_zone": "Pacific Time (US & Canada)",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 259,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/905129393357414400/_kehhWwa_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/905129393357414400/_kehhWwa_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1398232920/1524669672",
#    "profile_link_color": "F2D0DC",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:07 +0000 2018",
#   "id": 991068452977893377,
#   "id_str": "991068452977893377",
#   "text": "iPhone X \u2014 Kicks \u2014 Apple https://t.co/TbFpAY5g7d via @manliomannozzi",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "manliomannozzi",
#      "name": "Manlio Mannozzi#MGWV",
#      "id": 192135286,
#      "id_str": "192135286",
#      "indices": [
#       53,
#       68
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/TbFpAY5g7d",
#      "expanded_url": "https://manliomannozzi.wordpress.com/2018/04/04/iphone-x-kicks-apple/",
#      "display_url": "manliomannozzi.wordpress.com/2018/04/04/iph\u2026",
#      "indices": [
#       25,
#       48
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 376326898,
#    "id_str": "376326898",
#    "name": "Top Feeds News",
#    "screen_name": "TopFeedsNewss",
#    "location": "USA",
#    "description": "Top News from around the world.",
#    "url": "http://t.co/NN0F9cVszB",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/NN0F9cVszB",
#        "expanded_url": "http://www.wilhelmart.com",
#        "display_url": "wilhelmart.com",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 18712,
#    "friends_count": 18727,
#    "listed_count": 249,
#    "created_at": "Mon Sep 19 17:59:00 +0000 2011",
#    "favourites_count": 8473,
#    "utc_offset": 10800,
#    "time_zone": "Riga",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 33422,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1550425120/world-globe_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1550425120/world-globe_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/376326898/1441752024",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:06 +0000 2018",
#   "id": 991068450368831488,
#   "id_str": "991068450368831488",
#   "text": "\u0e09\u0e31\u0e19\u0e01\u0e33\u0e25\u0e31\u0e07\u0e1f\u0e31\u0e07 \"20-SEVENTEEN\" \u0e23\u0e31\u0e1a\u0e1f\u0e31\u0e07\u0e40\u0e1e\u0e25\u0e07\u0e17\u0e32\u0e07 JOOX \u0e44\u0e14\u0e49\u0e41\u0e25\u0e49\u0e27! https://t.co/AQs2meYRzc https://t.co/X4Z6xN6UMI",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/AQs2meYRzc",
#      "expanded_url": "http://www.joox.com/common_redirect.html?page=playsong&songid=A9AnYhHa5PmHj1AEiisNMA==&appshare=iphone&backend_country=th&lang=th",
#      "display_url": "joox.com/common_redirec\u2026",
#      "indices": [
#       55,
#       78
#      ]
#     }
#    ],
#    "media": [
#     {
#      "id": 991068448984743936,
#      "id_str": "991068448984743936",
#      "indices": [
#       79,
#       102
#      ],
#      "media_url": "http://pbs.twimg.com/media/DcD7gOHVQAAdMHy.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DcD7gOHVQAAdMHy.jpg",
#      "url": "https://t.co/X4Z6xN6UMI",
#      "display_url": "pic.twitter.com/X4Z6xN6UMI",
#      "expanded_url": "https://twitter.com/seongwupoem/status/991068450368831488/photo/1",
#      "type": "photo",
#      "sizes": {
#       "small": {
#        "w": 300,
#        "h": 300,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "large": {
#        "w": 300,
#        "h": 300,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 300,
#        "h": 300,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 991068448984743936,
#      "id_str": "991068448984743936",
#      "indices": [
#       79,
#       102
#      ],
#      "media_url": "http://pbs.twimg.com/media/DcD7gOHVQAAdMHy.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DcD7gOHVQAAdMHy.jpg",
#      "url": "https://t.co/X4Z6xN6UMI",
#      "display_url": "pic.twitter.com/X4Z6xN6UMI",
#      "expanded_url": "https://twitter.com/seongwupoem/status/991068450368831488/photo/1",
#      "type": "photo",
#      "sizes": {
#       "small": {
#        "w": 300,
#        "h": 300,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "large": {
#        "w": 300,
#        "h": 300,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 300,
#        "h": 300,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "th",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 937581594679820288,
#    "id_str": "937581594679820288",
#    "name": "\u0e1a\u0e17\u0e01\u0e25\u0e2d\u0e19",
#    "screen_name": "seongwupoem",
#    "location": "#\ub164\uc639\ubbfc\u13a2\u13ac\u13aa\u13b7 #HYUNGLINEX4 #TEAM\uc639\ub12c",
#    "description": "\u0e17\u0e32\u0e2a\u0e41\u0e21\u0e27 | \u0e04\u0e23\u0e2d\u0e1a\u0e04\u0e23\u0e31\u0e27\u0e02\u0e2d\u0e07\u0e1c\u0e21 #\u0e1e\u0e38\u0e48\u0e07\u0e2b\u0e25\u0e32\u0e27\u0e43\u0e2b\u0e49\u0e2a\u0e32\u0e27\u0e01\u0e23\u0e35\u0e49\u0e14 | \ud83c\udf3f\ud83c\udf75 @pwoojinxoranx @Minhyunriverx",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 262,
#    "friends_count": 308,
#    "listed_count": 0,
#    "created_at": "Mon Dec 04 07:17:26 +0000 2017",
#    "favourites_count": 2016,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 19223,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/989731106264989696/Zb2YNb_R_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/989731106264989696/Zb2YNb_R_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/937581594679820288/1522397014",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "th"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:06 +0000 2018",
#   "id": 991068448766726144,
#   "id_str": "991068448766726144",
#   "text": "RT @BoringEnormous: Someone stole my iPhone and didn't realise that videos upload automatically to my iCloud library. Please retweet to hel\u2026",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "BoringEnormous",
#      "name": "Paul Bronks",
#      "id": 20538843,
#      "id_str": "20538843",
#      "indices": [
#       3,
#       18
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 747473253212393472,
#    "id_str": "747473253212393472",
#    "name": "J.F. Riordan",
#    "screen_name": "AudacityofGoats",
#    "location": "",
#    "description": "Author of \u201cRobert\u2019s Rules\u201d, Book Three in the award-winning North of the Tension Line series northofthetensionline@gmail.com",
#    "url": "https://t.co/0hRQubVGjy",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/0hRQubVGjy",
#        "expanded_url": "http://jfriordan.com",
#        "display_url": "jfriordan.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 774,
#    "friends_count": 3056,
#    "listed_count": 5,
#    "created_at": "Mon Jun 27 16:54:45 +0000 2016",
#    "favourites_count": 4825,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 2899,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/972523402987794433/wM-28iqm_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/972523402987794433/wM-28iqm_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/747473253212393472/1467046850",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Sat Apr 28 20:06:50 +0000 2018",
#    "id": 990321463218589697,
#    "id_str": "990321463218589697",
#    "text": "Someone stole my iPhone and didn't realise that videos upload automatically to my iCloud library. Please retweet to\u2026 https://t.co/MjSWRcKaf1",
#    "truncated": true,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/MjSWRcKaf1",
#       "expanded_url": "https://twitter.com/i/web/status/990321463218589697",
#       "display_url": "twitter.com/i/web/status/9\u2026",
#       "indices": [
#        117,
#        140
#       ]
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 20538843,
#     "id_str": "20538843",
#     "name": "Paul Bronks",
#     "screen_name": "BoringEnormous",
#     "location": "Sheffield, England",
#     "description": "A mistake on the part of nature. Not really Jewish, more Jew-ish. I never want to die.",
#     "url": null,
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "protected": false,
#     "followers_count": 49644,
#     "friends_count": 3411,
#     "listed_count": 612,
#     "created_at": "Tue Feb 10 19:45:06 +0000 2009",
#     "favourites_count": 20401,
#     "utc_offset": 3600,
#     "time_zone": "London",
#     "geo_enabled": true,
#     "verified": false,
#     "statuses_count": 19485,
#     "lang": "en",
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "11AA11",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000158092839/AzGbUAxp.jpeg",
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000158092839/AzGbUAxp.jpeg",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/984143028637061122/-JwgvuaO_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/984143028637061122/-JwgvuaO_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/20538843/1524435540",
#     "profile_link_color": "111111",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "EFEFEF",
#     "profile_text_color": "333333",
#     "profile_use_background_image": false,
#     "has_extended_profile": true,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": {
#     "id": "232105a70cb80f00",
#     "url": "https://api.twitter.com/1.1/geo/id/232105a70cb80f00.json",
#     "place_type": "city",
#     "name": "Chapeltown",
#     "full_name": "Chapeltown, England",
#     "country_code": "GB",
#     "country": "United Kingdom",
#     "contained_within": [],
#     "bounding_box": {
#      "type": "Polygon",
#      "coordinates": [
#       [
#        [
#         -1.505303,
#         53.451389
#        ],
#        [
#         -1.4540017,
#         53.451389
#        ],
#        [
#         -1.4540017,
#         53.478938
#        ],
#        [
#         -1.505303,
#         53.478938
#        ]
#       ]
#      ]
#     },
#     "attributes": {}
#    },
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 354,
#    "favorite_count": 802,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "en"
#   },
#   "is_quote_status": false,
#   "retweet_count": 354,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:05 +0000 2018",
#   "id": 991068448531795968,
#   "id_str": "991068448531795968",
#   "text": "\u3010iPhone\u30a2\u30d7\u30ea\u6ce8\u76ee\u60c5\u5831\u3011\u4eca\u71b1\u3044\uff01\uff1f\u30b2\u30fc\u30e0: \u30b9\u30c8\u30e9\u30c6\u30b8\u30fc\u30a2\u30d7\u30ea\u300c\u30d5\u30a1\u30f3\u30c8\u30e0 \u30aa\u30d6 \u30ad\u30eb\u300d\u304c\u4eba\u6c17\u6025\u4e0a\u6607\u4e2d\uff01 https://t.co/zoJnEe5q2k",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/zoJnEe5q2k",
#      "expanded_url": "http://iphone.308413110.com/ranking/detail/882680657/",
#      "display_url": "iphone.308413110.com/ranking/detail\u2026",
#      "indices": [
#       56,
#       79
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "ja",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://iphone.308413110.com/ranking/\" rel=\"nofollow\">$$308413110 Bot</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 242602868,
#    "id_str": "242602868",
#    "name": "$$308413110",
#    "screen_name": "308413110",
#    "location": "",
#    "description": "\u30b5\u30a4\u30c8\u300ciPhone & iPad \u30a2\u30d7\u30ea\u30e9\u30f3\u30ad\u30f3\u30b0\u300d\u306e\u30a2\u30ab\u30a6\u30f3\u30c8\u3067\u3059\u3002\u30b5\u30a4\u30c8\u3067\u306f\u30ea\u30a2\u30eb\u30bf\u30a4\u30e0\u96c6\u8a08\u3057\u305f\u30e9\u30f3\u30ad\u30f3\u30b0\u60c5\u5831\u3092\u63b2\u8f09\u3001Twitter\u3067\u306f\u4e3b\u306bBot\u304c\u4eba\u6c17\u6025\u4e0a\u6607\u3057\u305f\u30a2\u30d7\u30ea\u3092\u3054\u7d39\u4ecb\u3057\u3066\u3044\u307e\u3059\u3002\u3000\u30b5\u30a4\u30c8\u306f\u3053\u3061\u3089 - http://t.co/OSxwKIHqtm",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": [
#       {
#        "url": "http://t.co/OSxwKIHqtm",
#        "expanded_url": "http://iphone.308413110.com/",
#        "display_url": "iphone.308413110.com",
#        "indices": [
#         108,
#         130
#        ]
#       }
#      ]
#     }
#    },
#    "protected": false,
#    "followers_count": 933,
#    "friends_count": 707,
#    "listed_count": 46,
#    "created_at": "Tue Jan 25 04:36:59 +0000 2011",
#    "favourites_count": 0,
#    "utc_offset": 32400,
#    "time_zone": "Tokyo",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 170783,
#    "lang": "ja",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "0099B9",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1266880011/appranking_normal.png",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1266880011/appranking_normal.png",
#    "profile_link_color": "0099B9",
#    "profile_sidebar_border_color": "5ED4DC",
#    "profile_sidebar_fill_color": "95E8EC",
#    "profile_text_color": "3C3940",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "ja"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:03 +0000 2018",
#   "id": 991068438473789440,
#   "id_str": "991068438473789440",
#   "text": "\u3010iPhone\u30a2\u30d7\u30ea\u6ce8\u76ee\u60c5\u5831\u3011\u8981\u30c1\u30a7\u30c3\u30af\uff1f\u4eca\u3068\u3063\u3066\u3082\u30b2\u30fc\u30e0: \u30b7\u30df\u30e5\u30ec\u30fc\u30b7\u30e7\u30f3\u30a2\u30d7\u30ea\u300cCR\u7259\u72fc\u91d1\u8272\u306b\u306a\u308cXX\u300d\u306e\u4eba\u6c17\u304c\u4e0a\u304c\u3063\u3066\u3044\u307e\u3059 https://t.co/d2oU9zki0v",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/d2oU9zki0v",
#      "expanded_url": "http://iphone.308413110.com/ranking/detail/1265791685/",
#      "display_url": "iphone.308413110.com/ranking/detail\u2026",
#      "indices": [
#       67,
#       90
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "ja",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://iphone.308413110.com/ranking/\" rel=\"nofollow\">$$308413110 Bot</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 242602868,
#    "id_str": "242602868",
#    "name": "$$308413110",
#    "screen_name": "308413110",
#    "location": "",
#    "description": "\u30b5\u30a4\u30c8\u300ciPhone & iPad \u30a2\u30d7\u30ea\u30e9\u30f3\u30ad\u30f3\u30b0\u300d\u306e\u30a2\u30ab\u30a6\u30f3\u30c8\u3067\u3059\u3002\u30b5\u30a4\u30c8\u3067\u306f\u30ea\u30a2\u30eb\u30bf\u30a4\u30e0\u96c6\u8a08\u3057\u305f\u30e9\u30f3\u30ad\u30f3\u30b0\u60c5\u5831\u3092\u63b2\u8f09\u3001Twitter\u3067\u306f\u4e3b\u306bBot\u304c\u4eba\u6c17\u6025\u4e0a\u6607\u3057\u305f\u30a2\u30d7\u30ea\u3092\u3054\u7d39\u4ecb\u3057\u3066\u3044\u307e\u3059\u3002\u3000\u30b5\u30a4\u30c8\u306f\u3053\u3061\u3089 - http://t.co/OSxwKIHqtm",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": [
#       {
#        "url": "http://t.co/OSxwKIHqtm",
#        "expanded_url": "http://iphone.308413110.com/",
#        "display_url": "iphone.308413110.com",
#        "indices": [
#         108,
#         130
#        ]
#       }
#      ]
#     }
#    },
#    "protected": false,
#    "followers_count": 933,
#    "friends_count": 707,
#    "listed_count": 46,
#    "created_at": "Tue Jan 25 04:36:59 +0000 2011",
#    "favourites_count": 0,
#    "utc_offset": 32400,
#    "time_zone": "Tokyo",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 170783,
#    "lang": "ja",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "0099B9",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1266880011/appranking_normal.png",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1266880011/appranking_normal.png",
#    "profile_link_color": "0099B9",
#    "profile_sidebar_border_color": "5ED4DC",
#    "profile_sidebar_fill_color": "95E8EC",
#    "profile_text_color": "3C3940",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "ja"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:03 +0000 2018",
#   "id": 991068438129864704,
#   "id_str": "991068438129864704",
#   "text": "@Sungyung5winner \u4eca\u5e74\u66ff\u3048\u305f\u3070\u304b\u308a\u306a\u3093\u3067\u3059\u304b\ud83d\ude25\ud83d\udca6\n\n\u79c1\u3001iPhone\u306b\u66ff\u3048\u30663\u5e74\u8fd1\u304f\u7d4c\u3064\u306e\u3067\u5145\u96fb\u6e1b\u308a\u304c\u65e9\u3044\u306e\u306f\u3082\u3046\u3057\u3087\u3046\u304c\u306a\u3044\u3067\u3059\u3088\u306d\ud83d\ude02",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "Sungyung5winner",
#      "name": "\ubbfc",
#      "id": 907418408580300800,
#      "id_str": "907418408580300800",
#      "indices": [
#       0,
#       16
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "ja",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": 991055442229977088,
#   "in_reply_to_status_id_str": "991055442229977088",
#   "in_reply_to_user_id": 907418408580300800,
#   "in_reply_to_user_id_str": "907418408580300800",
#   "in_reply_to_screen_name": "Sungyung5winner",
#   "user": {
#    "id": 706889932258680832,
#    "id_str": "706889932258680832",
#    "name": "K.yuka*.\uff61\u2741",
#    "screen_name": "xxxykxx17",
#    "location": "",
#    "description": "91(90) BIGBANG  WINNER \u672c\u57a2\u5225\u306b\u6709\u308a\u307e\u3059 \u3046\u3043\u306a\u5bc4\u308a\u30a2\u30ab\u30a6\u30f3\u30c8\u2190 \uff8c\uff6b\uff9b\uff70\uff98\uff91\uff90\uff6d\uff70\uff84\u3054\u81ea\u7531\u306b(\u00b4\u2200`)",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 23,
#    "friends_count": 22,
#    "listed_count": 0,
#    "created_at": "Mon Mar 07 17:11:08 +0000 2016",
#    "favourites_count": 192,
#    "utc_offset": 32400,
#    "time_zone": "JST",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 520,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/974492271088353280/Xs78aVLK_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/974492271088353280/Xs78aVLK_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/706889932258680832/1521171433",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "ja"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:03 +0000 2018",
#   "id": 991068436242599936,
#   "id_str": "991068436242599936",
#   "text": "M\u00fasica do momento? \u2014 Anota no meu iPhone https://t.co/FfDGlYLE4U",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/FfDGlYLE4U",
#      "expanded_url": "https://curiouscat.me/lemosni/post/440331943?1525124102",
#      "display_url": "curiouscat.me/lemosni/post/4\u2026",
#      "indices": [
#       41,
#       64
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "pt",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://curiouscat.me\" rel=\"nofollow\">Curious Cat</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 902167240501493760,
#    "id_str": "902167240501493760",
#    "name": "n\u00edcolas",
#    "screen_name": "lemos_ni",
#    "location": "Ai dentro",
#    "description": "\u25aa ECPELOTAS \u25aa \ud83c\uddfa\ud83c\udde6",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 249,
#    "friends_count": 211,
#    "listed_count": 0,
#    "created_at": "Mon Aug 28 13:53:26 +0000 2017",
#    "favourites_count": 929,
#    "utc_offset": -25200,
#    "time_zone": "Pacific Time (US & Canada)",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 1267,
#    "lang": "pt",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/975850439915769856/X3PTfKmX_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/975850439915769856/X3PTfKmX_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/902167240501493760/1524273090",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "pt"
#  },
#  {
#   "created_at": "Mon Apr 30 21:35:02 +0000 2018",
#   "id": 991068434099245059,
#   "id_str": "991068434099245059",
#   "text": "#AmazonGiveaway #AmazonGiveaways https://t.co/OkXff3QDwp",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "AmazonGiveaway",
#      "indices": [
#       0,
#       15
#      ]
#     },
#     {
#      "text": "AmazonGiveaways",
#      "indices": [
#       16,
#       32
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/OkXff3QDwp",
#      "expanded_url": "http://zpr.io/nKURL",
#      "display_url": "zpr.io/nKURL",
#      "indices": [
#       33,
#       56
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "und",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://zapier.com/\" rel=\"nofollow\">Zapier.com</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 814848469399642117,
#    "id_str": "814848469399642117",
#    "name": "Freebie Mom",
#    "screen_name": "Freebie_Mom_",
#    "location": "",
#    "description": "",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
# ...
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "has_extended_profile": true,
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 2,
#    "favorite_count": 6,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "ru"
#   },
#   "is_quote_status": false,
#   "retweet_count": 2,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "ru"
#  },
#  {
#   "created_at": "Mon Apr 30 21:31:17 +0000 2018",
#   "id": 991067490024329216,
#   "id_str": "991067490024329216",
#   "text": "Apple no est\u00e1 contenta con las ventas del iPhone X https://t.co/p1keb2Mtue v\u00eda @taringa https://t.co/wEj0aHtSjR",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "taringa",
#      "name": "Taringa!",
#      "id": 26830077,
#      "id_str": "26830077",
#      "indices": [
#       79,
#       87
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/p1keb2Mtue",
#      "expanded_url": "https://beta.taringa.net/+celulares/apple-no-esta-contenta-con-las-ventas-del-iphone-x_14eqy1",
#      "display_url": "beta.taringa.net/+celulares/app\u2026",
#      "indices": [
#       51,
#       74
#      ]
#     }
#    ],
#    "media": [
#     {
#      "id": 991067487797051392,
#      "id_str": "991067487797051392",
#      "indices": [
#       88,
#       111
#      ],
#      "media_url": "http://pbs.twimg.com/media/DcD6oRaVAAAZkH3.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DcD6oRaVAAAZkH3.jpg",
#      "url": "https://t.co/wEj0aHtSjR",
#      "display_url": "pic.twitter.com/wEj0aHtSjR",
#      "expanded_url": "https://twitter.com/t_celulares/status/991067490024329216/photo/1",
#      "type": "photo",
#      "sizes": {
#       "large": {
#        "w": 400,
#        "h": 300,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 400,
#        "h": 300,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 400,
#        "h": 300,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 991067487797051392,
#      "id_str": "991067487797051392",
#      "indices": [
#       88,
#       111
#      ],
#      "media_url": "http://pbs.twimg.com/media/DcD6oRaVAAAZkH3.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DcD6oRaVAAAZkH3.jpg",
#      "url": "https://t.co/wEj0aHtSjR",
#      "display_url": "pic.twitter.com/wEj0aHtSjR",
#      "expanded_url": "https://twitter.com/t_celulares/status/991067490024329216/photo/1",
#      "type": "photo",
#      "sizes": {
#       "large": {
#        "w": 400,
#        "h": 300,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 400,
#        "h": 300,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 400,
#        "h": 300,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "es",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://www.taringa.com/\" rel=\"nofollow\">RSS Crawler</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 106436886,
#    "id_str": "106436886",
#    "name": "Taringa! Celulares",
#    "screen_name": "t_celulares",
#    "location": "",
#    "description": "Posts de Taringa! Celulares.",
#    "url": "https://t.co/WKIisBTzO9",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/WKIisBTzO9",
#        "expanded_url": "https://beta.taringa.net/+celulares",
#        "display_url": "beta.taringa.net/+celulares",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 2648,
#    "friends_count": 30,
#    "listed_count": 29,
#    "created_at": "Tue Jan 19 15:17:01 +0000 2010",
#    "favourites_count": 0,
#    "utc_offset": -7200,
#    "time_zone": "Greenland",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 845,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "2968A6",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/935239566075850758/EFPye2v6_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/935239566075850758/EFPye2v6_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/106436886/1511813497",
#    "profile_link_color": "0084B4",
#    "profile_sidebar_border_color": "BDBDBD",
#    "profile_sidebar_fill_color": "EDEDED",
#    "profile_text_color": "333333",
#    "profile_use_background_image": false,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "es"
#  },
#  {
#   "created_at": "Mon Apr 30 21:31:16 +0000 2018",
#   "id": 991067485620273152,
#   "id_str": "991067485620273152",
#   "text": "RT @MenorBom7: Quer iPhone??? Ent\u00e3o toma \ud83d\ude0f\ud83d\ude0e https://t.co/uYlUVwcIQ9",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "MenorBom7",
#      "name": "MENOR BOM \ud83d\ude0e \ud83c\udde9\ud83c\uddea #EHQVVSP",
#      "id": 339382568,
#      "id_str": "339382568",
#      "indices": [
#       3,
#       13
#      ]
#     }
#    ],
#    "urls": [],
#    "media": [
#     {
#      "id": 990373814386249728,
#      "id_str": "990373814386249728",
#      "indices": [
#       44,
#       67
#      ],
#      "media_url": "http://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#      "url": "https://t.co/uYlUVwcIQ9",
#      "display_url": "pic.twitter.com/uYlUVwcIQ9",
#      "expanded_url": "https://twitter.com/MenorBom7/status/990373848523640832/photo/1",
#      "type": "photo",
#      "sizes": {
#       "medium": {
#        "w": 768,
#        "h": 1024,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 768,
#        "h": 1024,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 510,
#        "h": 680,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 990373848523640832,
#      "source_status_id_str": "990373848523640832",
#      "source_user_id": 339382568,
#      "source_user_id_str": "339382568"
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 990373814386249728,
#      "id_str": "990373814386249728",
#      "indices": [
#       44,
#       67
#      ],
#      "media_url": "http://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#      "url": "https://t.co/uYlUVwcIQ9",
#      "display_url": "pic.twitter.com/uYlUVwcIQ9",
#      "expanded_url": "https://twitter.com/MenorBom7/status/990373848523640832/photo/1",
#      "type": "photo",
#      "sizes": {
#       "medium": {
#        "w": 768,
#        "h": 1024,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 768,
#        "h": 1024,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 510,
#        "h": 680,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 990373848523640832,
#      "source_status_id_str": "990373848523640832",
#      "source_user_id": 339382568,
#      "source_user_id_str": "339382568"
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "pt",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 975078757806505985,
#    "id_str": "975078757806505985",
#    "name": "Beaa\u2764",
#    "screen_name": "abusada_01",
#    "location": "aonde mandando n\u00e3o acha\ud83d\ude1a",
#    "description": "@flamengo\u2764//Bernardo\ud83d\udc99",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 216,
#    "friends_count": 278,
#    "listed_count": 0,
#    "created_at": "Sat Mar 17 18:37:46 +0000 2018",
#    "favourites_count": 538,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 1431,
#    "lang": "pt",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/991028813030191104/BKAlEshp_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/991028813030191104/BKAlEshp_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/975078757806505985/1525123857",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Sat Apr 28 23:35:00 +0000 2018",
#    "id": 990373848523640832,
#    "id_str": "990373848523640832",
#    "text": "Quer iPhone??? Ent\u00e3o toma \ud83d\ude0f\ud83d\ude0e https://t.co/uYlUVwcIQ9",
#    "truncated": false,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [],
#     "media": [
#      {
#       "id": 990373814386249728,
#       "id_str": "990373814386249728",
#       "indices": [
#        29,
#        52
#       ],
#       "media_url": "http://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#       "media_url_https": "https://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#       "url": "https://t.co/uYlUVwcIQ9",
#       "display_url": "pic.twitter.com/uYlUVwcIQ9",
#       "expanded_url": "https://twitter.com/MenorBom7/status/990373848523640832/photo/1",
#       "type": "photo",
#       "sizes": {
#        "medium": {
#         "w": 768,
#         "h": 1024,
#         "resize": "fit"
#        },
#        "large": {
#         "w": 768,
#         "h": 1024,
#         "resize": "fit"
#        },
#        "thumb": {
#         "w": 150,
#         "h": 150,
#         "resize": "crop"
#        },
#        "small": {
#         "w": 510,
#         "h": 680,
#         "resize": "fit"
#        }
#       }
#      }
#     ]
#    },
#    "extended_entities": {
#     "media": [
#      {
#       "id": 990373814386249728,
#       "id_str": "990373814386249728",
#       "indices": [
#        29,
#        52
#       ],
#       "media_url": "http://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#       "media_url_https": "https://pbs.twimg.com/media/Db6DvKlXUAAVNDI.jpg",
#       "url": "https://t.co/uYlUVwcIQ9",
#       "display_url": "pic.twitter.com/uYlUVwcIQ9",
#       "expanded_url": "https://twitter.com/MenorBom7/status/990373848523640832/photo/1",
#       "type": "photo",
#       "sizes": {
#        "medium": {
#         "w": 768,
#         "h": 1024,
#         "resize": "fit"
#        },
#        "large": {
#         "w": 768,
#         "h": 1024,
#         "resize": "fit"
#        },
#        "thumb": {
#         "w": 150,
#         "h": 150,
#         "resize": "crop"
#        },
#        "small": {
#         "w": 510,
#         "h": 680,
#         "resize": "fit"
#        }
#       }
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "pt",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 339382568,
#     "id_str": "339382568",
#     "name": "MENOR BOM \ud83d\ude0e \ud83c\udde9\ud83c\uddea #EHQVVSP",
#     "screen_name": "MenorBom7",
#     "location": "Terra De Deus ",
#     "description": "Flameguista Doente \ud83d\udd34\u26ab\ufe0f Agrade\u00e7o a Deus por ter nascido favelado, onde eu aprendi o certo praticando o errado #SddsDoDan\u00e7a \ud83d\ude07 #SddsDoTeuz\u00e3o\ud83d\ude07     @Crf_my \u2764\ufe0f",
#     "url": "https://t.co/lqW1BvelKs",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/lqW1BvelKs",
#         "expanded_url": "https://www.youtube.com/user/carlostevesful",
#         "display_url": "youtube.com/user/carlostev\u2026",
#         "indices": [
#          0,
#          23
#         ]
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "protected": false,
#     "followers_count": 2931,
#     "friends_count": 5000,
#     "listed_count": 6,
#     "created_at": "Thu Jul 21 01:06:46 +0000 2011",
#     "favourites_count": 21749,
#     "utc_offset": -10800,
#     "time_zone": "Brasilia",
#     "geo_enabled": true,
#     "verified": false,
#     "statuses_count": 39919,
#     "lang": "pt",
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "94D487",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/691721500764680192/5LgX5VX1.jpg",
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/691721500764680192/5LgX5VX1.jpg",
#     "profile_background_tile": true,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/989714424045842435/E4Lmhu7b_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/989714424045842435/E4Lmhu7b_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/339382568/1524718049",
#     "profile_link_color": "ABB8C2",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "has_extended_profile": true,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 11,
#    "favorite_count": 51,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "pt"
#   },
#   "is_quote_status": false,
#   "retweet_count": 11,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "pt"
#  }
# ]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## Example 6. Saving and restoring JSON data with flat-text files

# %%
import io, json

def save_json(filename, data):
    with io.open('resources/ch09-twittercookbook/{0}.json'.format(filename), 
                 'w', encoding='utf-8') as f:
        f.write(str(json.dumps(data, ensure_ascii=False)))

def load_json(filename):
    with io.open('resources/ch09-twittercookbook/{0}.json'.format(filename), 
                 encoding='utf-8') as f:
        return f.read()

# Sample usage

q = 'CrossFit'

twitter_api = oauth_login()
results = twitter_search(twitter_api, q, max_results=10)

save_json(q, results)
results = load_json(q)

print(json.dumps(results, indent=1))
# Out:
# "[{\"created_at\": \"Mon Apr 30 21:34:12 +0000 2018\", \"id\": 991068223281029121, \"id_str\": \"991068223281029121\", \"text\": \"#mondaymotivation #strength #training #crossfit https://t.co/uMqCXSfV1h\", \"truncated\": false, \"entities\": {\"hashtags\": [{\"text\": \"mondaymotivation\", \"indices\": [0, 17]}, {\"text\": \"strength\", \"indices\": [18, 27]}, {\"text\": \"training\", \"indices\": [28, 37]}, {\"text\": \"crossfit\", \"indices\": [38, 47]}], \"symbols\": [], \"user_mentions\": [], \"urls\": [{\"url\": \"https://t.co/uMqCXSfV1h\", \"expanded_url\": \"https://www.instagram.com/p/BiNbgMCntCk/?utm_source=twitter\", \"display_url\": \"instagram.com/p/BiNbgMCntCk/\u2026\", \"indices\": [48, 71]}]}, \"metadata\": {\"iso_language_code\": \"und\", \"result_type\": \"recent\"}, \"source\": \"<a href=\\\"http://instagram.com\\\" rel=\\\"nofollow\\\">Instagram</a>\", \"in_reply_to_status_id\": null, \"in_reply_to_status_id_str\": null, \"in_reply_to_user_id\": null, \"in_reply_to_user_id_str\": null, \"in_reply_to_screen_name\": null, \"user\": {\"id\": 814105939989164033, \"id_str\": \"814105939989164033\", \"name\": \"CrossFit Ridgeway\", \"screen_name\": \"CFRidgeway\", \"location\": \"Rochester, NY\", \"description\": \"Improve Health. Lose Weight. Look Better. CrossFit Ridgeway wants to provide every person that walks through the door the best one hour of their day.\", \"url\": \"https://t.co/cwLHjPQUbk\", \"entities\": {\"url\": {\"urls\": [{\"url\": \"https://t.co/cwLHjPQUbk\", \"expanded_url\": \"https://crossfitridgeway.com\", \"display_url\": \"crossfitridgeway.com\", \"indices\": [0, 23]}]}, \"description\": {\"urls\": []}}, \"protected\": false, \"followers_count\": 44, \"friends_count\": 109, \"listed_count\": 2, \"created_at\": \"Wed Dec 28 13:49:16 +0000 2016\", \"favourites_count\": 260, \"utc_offset\": -25200, \"time_zone\": \"Pacific Time (US & Canada)\", \"geo_enabled\": false, \"verified\": false, \"statuses_count\": 371, \"lang\": \"en\", \"contributors_enabled\": false, \"is_translator\": false, \"is_translation_enabled\": false, \"profile_background_color\": \"000000\", \"profile_background_image_url\": \"http://abs.twimg.com/images/themes/theme1/bg.png\", \"profile_background_image_url_https\": \"https://abs.twimg.com/images/themes/theme1/bg.png\", \"profile_background_tile\": false, \"profile_image_url\": \"http://pbs.twimg.com/profile_images/892499333836226560/fb0-5z2H_normal.jpg\", \"profile_image_url_https\": \"https://pbs.twimg.com/profile_images/892499333836226560/fb0-5z2H_normal.jpg\", \"profile_banner_url\": \"https://pbs.twimg.com/profile_banners/814105939989164033/1501623408\", \"profile_link_color\": \"B62127\", \"profile_sidebar_border_color\": \"000000\", \"profile_sidebar_fill_color\": \"000000\", \"profile_text_color\": \"000000\", \"profile_use_background_image\": false, \"has_extended_profile\": false, \"default_profile\": false, \"default_profile_image\": false, \"following\": false, \"follow_request_sent\": false, \"notifications\": false, \"translator_type\": \"none\"}, \"geo\": null, \"coordinates\": null, \"place\": null, \"contributors\": null, \"is_quote_status\": false, \"retweet_count\": 0, \"favorite_count\": 0, \"favorited\": false, \"retweeted\": false, \"possibly_sensitive\": false, \"lang\": \"und\"}, {\"created_at\": \"Mon Apr 30 21:33:59 +0000 2018\", \"id\": 991068167924576259, \"id_str\": \"991068167924576259\", \"text\": \"A\u00ed voc\u00ea chega para o seu primeiro dia no Crossfit e o instrutor \u00e9 naval \ud83d\udcaa\ud83c\udffd\ud83d\udc4c\ud83c\udffd\ud83d\udc80\", \"truncated\": false, \"entities\": {\"hashtags\": [], \"symbols\": [], \"user_mentions\": [], \"urls\": []}, \"metadata\": {\"iso_language_code\": \"pt\", \"result_type\": \"recent\"}, \"source\": \"<a href=\\\"http://twitter.com/download/iphone\\\" rel=\\\"nofollow\\\">Twitter for iPhone</a>\", \"in_reply_to_status_id\": null, \"in_reply_to_status_id_str\": null, \"in_reply_to_user_id\": null, \ ...

# %% [markdown]
# ## Example 7. Saving and accessing JSON data with MongoDB

# %%
import json
import pymongo # pip install pymongo

def save_to_mongo(data, mongo_db, mongo_db_coll, **mongo_conn_kw):
    
    # Connects to the MongoDB server running on 
    # localhost:27017 by default
    
    client = pymongo.MongoClient(**mongo_conn_kw)
    
    # Get a reference to a particular database
    
    db = client[mongo_db]
    
    # Reference a particular collection in the database
    
    coll = db[mongo_db_coll]
    
    # Perform a bulk insert and  return the IDs
    
    return coll.insert(data)

def load_from_mongo(mongo_db, mongo_db_coll, return_cursor=False,
                    criteria=None, projection=None, **mongo_conn_kw):
    
    # Optionally, use criteria and projection to limit the data that is 
    # returned as documented in 
    # http://docs.mongodb.org/manual/reference/method/db.collection.find/
    
    # Consider leveraging MongoDB's aggregations framework for more 
    # sophisticated queries.
    
    client = pymongo.MongoClient(**mongo_conn_kw)
    db = client[mongo_db]
    coll = db[mongo_db_coll]
    
    if criteria is None:
        criteria = {}
    
    if projection is None:
        cursor = coll.find(criteria)
    else:
        cursor = coll.find(criteria, projection)

    # Returning a cursor is recommended for large amounts of data
    
    if return_cursor:
        return cursor
    else:
        return [ item for item in cursor ]

# Sample usage

q = 'CrossFit'

twitter_api = oauth_login()
results = twitter_search(twitter_api, q, max_results=10)

save_to_mongo(results, 'search_results', q)

load_from_mongo('search_results', q)
# Out:
# /Users/temp/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:21: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-13-d0c810182fc8> in <module>()
#      57 results = twitter_search(twitter_api, q, max_results=10)
#      58
# ---> 59 save_to_mongo(results, 'search_results', q)
#      60
#      61 load_from_mongo('search_results', q)
#
# <ipython-input-13-d0c810182fc8> in save_to_mongo(data, mongo_db, mongo_db_coll, **mongo_conn_kw)
#      19     # Perform a bulk insert and  return the IDs
#      20
# ---> 21     return coll.insert(data)
#      22
#      23 def load_from_mongo(mongo_db, mongo_db_coll, return_cursor=False,
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    2497         if kwargs:
#    2498             write_concern = WriteConcern(**kwargs)
# -> 2499         with self._socket_for_writes() as sock_info:
#    2500             return self._insert(sock_info, doc_or_docs, not continue_on_error,
#    2501                                 check_keys, manipulate, write_concern)
#
# /Users/temp/anaconda/lib/python3.6/contextlib.py in __enter__(self)
#      80     def __enter__(self):
#      81         try:
# ---> 82             return next(self.gen)
#      83         except StopIteration:
#      84             raise RuntimeError("generator didn't yield") from None
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, selector)
#     866     @contextlib.contextmanager
#     867     def _get_socket(self, selector):
# --> 868         server = self._get_topology().select_server(selector)
#     869         try:
#     870             with server.get_socket(self.__all_credentials) as sock_info:
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/topology.py in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/topology.py in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %% [markdown]
# ## Example 8. Sampling the Twitter firehose with the Streaming API

# %%
# Finding topics of interest by using the filtering capablities it offers.

import sys
import twitter

# Query terms

q = 'CrossFit' # Comma-separated list of terms

#Python 2.x:
# print >> sys.stderr, 'Filtering the public timeline for track="%s"' % (q,)

#Python 3:
print('Filtering the public timeline for track="%s"' % (q,) , file = sys.stderr) 

sys.stderr.flush()

# Returns an instance of twitter.Twitter
twitter_api = oauth_login()

# Reference the self.auth parameter
twitter_stream = twitter.TwitterStream(auth=twitter_api.auth)

# See https://dev.twitter.com/docs/streaming-apis
stream = twitter_stream.statuses.filter(track=q)

# For illustrative purposes, when all else fails, search for Justin Bieber
# and something is sure to turn up (at least, on Twitter)

for tweet in stream:
    print(tweet['text'])
    sys.stdout.flush()

    # Save to a database in a particular collection
# Out:
# Filtering the public timeline for track="CrossFit"
# Um vegan, um praticante de crossfit e um ateu entram num bar.
#
# Antes de um deles abrir a boca, já um benfiquista di… https://t.co/o5ZyTnLmzS
# SONUNDAAAA BITCHEEEEZ. ZATEN YARIN CROSSFIT. https://t.co/bwbMJUNVOk
# singles 🏆 https://t.co/N6UJ7tpEGm
#  a dating flirtingwith girls in 1 2 3 chatham kentfinding boys in 4 5 coventryre… https://t.co/MhRJMpcCOu
# I'm at Deltha Crossfit in Pachuca, Hidalgo w/ @aquiles478 @alain93_ @libelula0412 @gonzlezaarn @aaronmagc… https://t.co/JzBUckDGBC
# Mosaic Gradient – Emerald and Sapphire Leggings https://t.co/mTFXuc2Mqg All shades of green in these awesome yoga p… https://t.co/xnpoUePKOo
# Jack be nimble but Jack ain’t Quick. #getafterit #disciplineequalsfreedom #crossfit #0445club https://t.co/MOtrUPsNR4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-76cf8a71839c> in <module>()
#      23 # and something is sure to turn up (at least, on Twitter)
#      24
# ---> 25 for tweet in stream:
#      26     print(tweet['text'])
#      27     sys.stdout.flush()
#
# /Users/temp/anaconda/lib/python3.6/site-packages/twitter/stream.py in __iter__(self)
#     175             # Decode all the things:
#     176             try:
# --> 177                 data = sock_reader.read()
#     178             except SSLError:
#     179                 yield Hangup
#
# /Users/temp/anaconda/lib/python3.6/site-packages/twitter/stream.py in read(self)
#     131     def read(self):
#     132         try:
# --> 133             ready_to_read = select.select([self.sock], [], [], self.sock_timeout)[0]
#     134             if ready_to_read:
#     135                 return self.sock.read()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Example 9. Collecting time-series data

# %%
import sys
import datetime
import time
import twitter

def get_time_series_data(api_func, mongo_db_name, mongo_db_coll, 
                         secs_per_interval=60, max_intervals=15, **mongo_conn_kw):
    
    # Default settings of 15 intervals and 1 API call per interval ensure that 
    # you will not exceed the Twitter rate limit.
    
    interval = 0
    
    while True:
    
        # A timestamp of the form "2013-06-14 12:52:07"
        now = str(datetime.datetime.now()).split(".")[0]
    
        ids = save_to_mongo(api_func(), mongo_db_name, mongo_db_coll + "-" + now)
#Python 2.x:    
#         print >> sys.stderr, "Write {0} trends".format(len(ids))
#         print >> sys.stderr, "Zzz..."
#         print >> sys.stderr.flush()
        
#Python 3.x:
        print("Write {0} trends".format(len(ids)), file = sys.stderr)
        print( "Zzz...", file = sys.stderr)
        sys.stderr.flush()
        
        time.sleep(secs_per_interval) # seconds
        interval += 1
        
        if interval >= 15:
            break
        
# Sample usage

get_time_series_data(twitter_world_trends, 'time-series', 'twitter_world_trends')
# Out:
# /Users/temp/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:21: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-16-cae5e411b30d> in <module>()
#      31 # Sample usage
#      32
# ---> 33 get_time_series_data(twitter_world_trends, 'time-series', 'twitter_world_trends')
#
# <ipython-input-16-cae5e411b30d> in get_time_series_data(api_func, mongo_db_name, mongo_db_coll, secs_per_interval, max_intervals, **mongo_conn_kw)
#      17         now = str(datetime.datetime.now()).split(".")[0]
#      18
# ---> 19         ids = save_to_mongo(api_func(), mongo_db_name, mongo_db_coll + "-" + now)
#      20
#      21         print >> sys.stderr, "Write {0} trends".format(len(ids))
#
# <ipython-input-13-d0c810182fc8> in save_to_mongo(data, mongo_db, mongo_db_coll, **mongo_conn_kw)
#      19     # Perform a bulk insert and  return the IDs
#      20
# ---> 21     return coll.insert(data)
#      22
#      23 def load_from_mongo(mongo_db, mongo_db_coll, return_cursor=False,
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    2497         if kwargs:
#    2498             write_concern = WriteConcern(**kwargs)
# -> 2499         with self._socket_for_writes() as sock_info:
#    2500             return self._insert(sock_info, doc_or_docs, not continue_on_error,
#    2501                                 check_keys, manipulate, write_concern)
#
# /Users/temp/anaconda/lib/python3.6/contextlib.py in __enter__(self)
#      80     def __enter__(self):
#      81         try:
# ---> 82             return next(self.gen)
#      83         except StopIteration:
#      84             raise RuntimeError("generator didn't yield") from None
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, selector)
#     866     @contextlib.contextmanager
#     867     def _get_socket(self, selector):
# --> 868         server = self._get_topology().select_server(selector)
#     869         try:
#     870             with server.get_socket(self.__all_credentials) as sock_info:
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/topology.py in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# /Users/temp/anaconda/lib/python3.6/site-packages/pymongo/topology.py in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %% [markdown]
# ## Example 10. Extracting tweet entities

# %%
def extract_tweet_entities(statuses):
    
    # See https://dev.twitter.com/docs/tweet-entities for more details on tweet
    # entities

    if len(statuses) == 0:
        return [], [], [], [], []
    
    screen_names = [ user_mention['screen_name'] 
                         for status in statuses
                            for user_mention in status['entities']['user_mentions'] ]
    
    hashtags = [ hashtag['text'] 
                     for status in statuses 
                        for hashtag in status['entities']['hashtags'] ]

    urls = [ url['expanded_url'] 
                     for status in statuses 
                        for url in status['entities']['urls'] ]
    
    symbols = [ symbol['text']
                   for status in statuses
                       for symbol in status['entities']['symbols'] ]
               
    # In some circumstances (such as search results), the media entity
    # may not appear
    if status['entities'].has_key('media'): 
        media = [ media['url'] 
                         for status in statuses  
                            for media in status['entities']['media'] ]
    else:
        media = []

    return screen_names, hashtags, urls, media, symbols

# Sample usage

q = 'CrossFit'

statuses = twitter_search(twitter_api, q)

screen_names, hashtags, urls, media, symbols = extract_tweet_entities(statuses)
    
# Explore the first five items for each...

print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(urls[0:5], indent=1))
print(json.dumps(media[0:5], indent=1))
print(json.dumps(symbols[0:5], indent=1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6a8d1926d10a> in <module>()
#      40 statuses = twitter_search(twitter_api, q)
#      41
# ---> 42 screen_names, hashtags, urls, media, symbols = extract_tweet_entities(statuses)
#      43
#      44 # Explore the first five items for each...
#
# <ipython-input-19-6a8d1926d10a> in extract_tweet_entities(statuses)
#      25     # In some circumstances (such as search results), the media entity
#      26     # may not appear
# ---> 27     if status['entities'].has_key('media'):
#      28         media = [ media['url']
#      29                          for status in statuses
#
# NameError: name 'status' is not defined

# %% [markdown]
# ## Example 11. Finding the most popular tweets in a collection of tweets

# %%
import twitter

def find_popular_tweets(twitter_api, statuses, retweet_threshold=3):

    # You could also consider using the favorite_count parameter as part of 
    # this  heuristic, possibly using it to provide an additional boost to 
    # popular tweets in a ranked formulation
        
    return [ status
                for status in statuses 
                    if status['retweet_count'] > retweet_threshold ] 
    
# Sample usage

q = "CrossFit"

twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q, max_results=200)

popular_tweets = find_popular_tweets(twitter_api, search_results)

for tweet in popular_tweets:
    print(tweet['text'], tweet['retweet_count'])
# Out:
# RT @getfiscal: they turned a protestant church in my city into a combination coworking space and crossfit gym... too on the nose 5
# RT @figureandfit: #Fitness #Resistance Bands Elastic Stretch #Bands #Exercise Training Band Best for Pilates Yoga , Home #Gym #Crossfit #Wo… 9
# RT @figureandfit: #Exercise Strength #Resistance Bands Loop Band Weight #Training #Fitness Crossfit pull up #bands
# https://t.co/PcwUU28ybm… 5
# RT @figureandfit: Resistance #Bands Exercise #Loop #Crossfit Strength Weight #Training #Fitness 4pcs loop bands
# https://t.co/ONwbTEfrQ9 htt… 13
# RT @jollyrobber: "Wow. The first rule of crossfit club is VERY different from the last club I was in."
#
# Tyler Durden 49
# RT @FogoCharcoal: Hanger Steaks on @finexcookware Cast Iron grill skillet. Amazing crust, super tasty 🔥🔥#FOGOcharcoal #TheFirstIngredient #… 5
# RT @getfiscal: they turned a protestant church in my city into a combination coworking space and crossfit gym... too on the nose 5
# RT @warrlly: isso q acontece com quem faz crossfit https://t.co/I43KkeILWH 7840
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @MonsterJam: .@CynthiaGauthier: Living in the Fast Lane. A special segment with @CrossFit. 👀 Watch it now 👉 https://t.co/BQMR0O1x6O
#
# #Mo… 5
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# RT @muscle_fitness: Can you achieve this fitness milestone? https://t.co/0DCqSzYqrw 8
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# RT @MichaelBensonn: 😂 Arguably the greatest press conference WAR speech you will ever see from David Haye's representative Adam Morallee to… 487
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# RT @Tips_Fitness1: Crossfit :D https://t.co/lEqYkkHq9i 10
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# RT @CrossFit: "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqn… 10
# "Everyone is practicing taking the stairs and I’m over here mastering the elevator." 😎
#
# —@CassidyDuffield https://t.co/uJIZqnfLjR 10
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @BlackandBrave: Our Crossfit Jesus line has expanded! Grab your Homeboy and Last Supper tees at https://t.co/9AS4H8qPKC now! https://t.c… 32
# RT @LisaFrame: Went to Crossfit today but left early because I forgot something.
#
# I forgot that I'm not in shape and can't do that shit. 615
# RT @daddancechamp: Shoot I got Nutella on my CrossFit diary again 8
# RT @daddancechamp: Shoot I got Nutella on my CrossFit diary again 8
# RT @getfiscal: they turned a protestant church in my city into a combination coworking space and crossfit gym... too on the nose 5
# RT @getfiscal: they turned a protestant church in my city into a combination coworking space and crossfit gym... too on the nose 5
# they turned a protestant church in my city into a combination coworking space and crossfit gym... too on the nose 5
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @SportsCenter: Oladipo really texted his trainer less than 20 minutes after Game 7 ended. https://t.co/0YUDfB1Ecm 17325
# RT @ClichedOut: me: i was doing crossfit on the night of the 16th
#
# cop: you're not even a suspect tho
#
# me: i just wanted u to know 277
# RT @DevInTheLab: Terry Rozier, after you watch this you won’t forget his name. https://t.co/NggLGBkJhg 7688
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @skwpearce: I love crossfit, journeying to great health,building business, my friends, family and church! 4
# RT @Dr_Fleibur: Me voy al gimnasio a las nueve después de un curso de inglés, voy bien en mi camino a padre divorciado de cuarenta años que… 12
# RT @CrossFit: Today Dona tackled FRAN. You are never too old to become fit.
# #CrossFit @CrossfitEnoch https://t.co/hYyGOix8Aa 76
# RT @garyvee: So much energy out there in the judgement of others. If some people used half the energy they use in judging others on looking… 1137
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @RahmaHashimloe: @CrossFit Mpoki 4
# RT @JohnMcGrathMB: Only Hang with those who see
# the Greatness in You!
#
# #MondayMotivation #Crossfit #Strength
# #Inspiration #Motivation htt… 47
# RT @TheSharkDaymond: Happy #SmallBusinessWeek entrepreneurs. RT if you're a business owner! https://t.co/OJSW5ql6oI 77
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @therizo_thieles: Γκουγκλάρω να δω τι είναι το crossfit που μου προτείνει η άλλη να κάνω και τώρα τη ρωτάω με βλέμμα αγελάδας σοβαρά μιλ… 38
# RT @_Zeets: @ayyy_west @micahpeters_ Bane left his weekly crossfit session and had Batman calling for the guard 5
# RT @KarenDanczuk: Been focusing on “repairing myself” both mentally &amp; physically after what’s been difficult year following childhood trial… 17
# RT @Dr_Fleibur: Me voy al gimnasio a las nueve después de un curso de inglés, voy bien en mi camino a padre divorciado de cuarenta años que… 12
# RT @BlackandBrave: CROSSFIT JESUS HAS RETURNED!
# https://t.co/9AS4H8qPKC https://t.co/HcqnozJVfy 35
# RT @claudiamarz_: Help #CrossFit coach and #olympicweightlifter @Josephg103 as he embarks on this honorable journey to represent @TeamUSA a… 11

# %% [markdown]
# ## Example 12. Finding the most popular tweet entities in a collection of tweets

# %%
import twitter
from collections import Counter

def get_common_tweet_entities(statuses, entity_threshold=3):

    # Create a flat list of all tweet entities
    tweet_entities = [  e
                        for status in statuses
                            for entity_type in extract_tweet_entities([status]) 
                                for e in entity_type 
                     ]

    c = Counter(tweet_entities).most_common()

    # Compute frequencies
    return [ (k,v) 
             for (k,v) in c
                 if v >= entity_threshold
           ]

# Sample usage

q = 'CrossFit'

twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q, max_results=100)
common_entities = get_common_tweet_entities(search_results)

print("Most common tweet entities")
print(common_entities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4a372e4ee7e7> in <module>()
#      25 twitter_api = oauth_login()
#      26 search_results = twitter_search(twitter_api, q, max_results=100)
# ---> 27 common_entities = get_common_tweet_entities(search_results)
#      28
#      29 print("Most common tweet entities")
#
# <ipython-input-20-4a372e4ee7e7> in get_common_tweet_entities(statuses, entity_threshold)
#       6     # Create a flat list of all tweet entities
#       7     tweet_entities = [  e
# ----> 8                         for status in statuses
#       9                             for entity_type in extract_tweet_entities([status])
#      10                                 for e in entity_type
#
# <ipython-input-20-4a372e4ee7e7> in <listcomp>(.0)
#       7     tweet_entities = [  e
#       8                         for status in statuses
# ----> 9                             for entity_type in extract_tweet_entities([status])
#      10                                 for e in entity_type
#      11                      ]
#
# <ipython-input-19-6a8d1926d10a> in extract_tweet_entities(statuses)
#      25     # In some circumstances (such as search results), the media entity
#      26     # may not appear
# ---> 27     if status['entities'].has_key('media'):
#      28         media = [ media['url']
#      29                          for status in statuses
#
# NameError: name 'status' is not defined

# %% [markdown]
# ## Example 13. Tabulating frequency analysis

# %%
from prettytable import PrettyTable

# Get some frequency data

twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q, max_results=100)
common_entities = get_common_tweet_entities(search_results)

# Use PrettyTable to create a nice tabular display

pt = PrettyTable(field_names=['Entity', 'Count']) 
[ pt.add_row(kv) for kv in common_entities ]
pt.align['Entity'], pt.align['Count'] = 'l', 'r' # Set column alignment
print pt

# %% [markdown]
# ## Example 14. Finding users who have retweeted a status

# %%
import twitter

twitter_api = oauth_login()

print("""User IDs for retweeters of a tweet by @fperez_org
that was retweeted by @SocialWebMining and that @jyeee then retweeted
from @SocialWebMining's timeline\n""")
print(twitter_api.statuses.retweeters.ids(_id=334188056905129984)['ids'])
print(json.dumps(twitter_api.statuses.show(_id=334188056905129984), indent=1))
print('\n')

print("@SocialWeb's retweet of @fperez_org's tweet\n")
print(twitter_api.statuses.retweeters.ids(_id=345723917798866944)['ids'])
print(json.dumps(twitter_api.statuses.show(_id=345723917798866944), indent=1))
print('\n')

print("@jyeee's retweet of @fperez_org's tweet\n")
print(twitter_api.statuses.retweeters.ids(_id=338835939172417537)['ids'])
print(json.dumps(twitter_api.statuses.show(_id=338835939172417537), indent=1))
# Out:
# User IDs for retweeters of a tweet by @fperez_org
# that was retweeted by @SocialWebMining and that @jyeee then retweeted
# from @SocialWebMining's timeline
#
# [17930287, 132373965, 13085242, 66592853, 25696968]
# {
#  "created_at": "Tue May 14 06:06:56 +0000 2013",
#  "id": 334188056905129984,
#  "id_str": "334188056905129984",
#  "text": "Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://t.co/56giCSjcqw",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "SocialWebMining",
#     "name": "MiningTheSocialWeb",
#     "id": 132373965,
#     "id_str": "132373965",
#     "indices": [
#      82,
#      98
#     ]
#    },
#    {
#     "screen_name": "ptwobrussell",
#     "name": "Matthew Russell",
#     "id": 13085242,
#     "id_str": "13085242",
#     "indices": [
#      102,
#      115
#     ]
#    }
#   ],
#   "urls": [
#    {
#     "url": "http://t.co/56giCSjcqw",
#     "expanded_url": "http://on.fb.me/11WCD9E",
#     "display_url": "on.fb.me/11WCD9E",
#     "indices": [
#      116,
#      138
#     ]
#    }
#   ]
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 244991150,
#   "id_str": "244991150",
#   "name": "Fernando Perez",
#   "screen_name": "fperez_org",
#   "location": "Berkeley, CA",
#   "description": "Physicist, data scientist, @IPythonDev creator (evolved into @ProjectJupyter). UC Berkeley Stats Asst. Prof, @BerkeleyLab scientist, adv. @plotlygraphs, climber",
#   "url": "http://t.co/J7UDLpykqU",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/J7UDLpykqU",
#       "expanded_url": "http://fperez.org",
#       "display_url": "fperez.org",
#       "indices": [
#        0,
#        22
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 16463,
#   "friends_count": 532,
#   "listed_count": 746,
#   "created_at": "Sun Jan 30 16:28:09 +0000 2011",
#   "favourites_count": 6611,
#   "utc_offset": -25200,
#   "time_zone": "Pacific Time (US & Canada)",
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 7062,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/244991150/1404790002",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 5,
#  "favorite_count": 9,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "possibly_sensitive_appealable": false,
#  "lang": "en"
# }
#
#
# @SocialWeb's retweet of @fperez_org's tweet
#
# []
# {
#  "created_at": "Sat Jun 15 02:06:19 +0000 2013",
#  "id": 345723917798866944,
#  "id_str": "345723917798866944",
#  "text": "RT @fperez_org: Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "fperez_org",
#     "name": "Fernando Perez",
#     "id": 244991150,
#     "id_str": "244991150",
#     "indices": [
#      3,
#      14
#     ]
#    },
#    {
#     "screen_name": "SocialWebMining",
#     "name": "MiningTheSocialWeb",
#     "id": 132373965,
#     "id_str": "132373965",
#     "indices": [
#      98,
#      114
#     ]
#    },
#    {
#     "screen_name": "ptwobrussell",
#     "name": "Matthew Russell",
#     "id": 13085242,
#     "id_str": "13085242",
#     "indices": [
#      118,
#      131
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 13085242,
#   "id_str": "13085242",
#   "name": "Matthew Russell",
#   "screen_name": "ptwobrussell",
#   "location": "Franklin, TN",
#   "description": "Computer Scientist. Technologist. CrossFitter. Triathlete. Author.",
#   "url": "http://t.co/AzFoM9TBPO",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/AzFoM9TBPO",
#       "expanded_url": "http://MiningTheSocialWeb.com",
#       "display_url": "MiningTheSocialWeb.com",
#       "indices": [
#        0,
#        22
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 2033,
#   "friends_count": 162,
#   "listed_count": 180,
#   "created_at": "Tue Feb 05 08:16:12 +0000 2008",
#   "favourites_count": 900,
#   "utc_offset": -18000,
#   "time_zone": "Central Time (US & Canada)",
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 1507,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "888888",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/112353046/twitter-1.4.2.gif",
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/112353046/twitter-1.4.2.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000365424290/cbdedf17eb021ce95ddce059a90c1787_normal.jpeg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000365424290/cbdedf17eb021ce95ddce059a90c1787_normal.jpeg",
#   "profile_link_color": "EE8336",
#   "profile_sidebar_border_color": "888888",
#   "profile_sidebar_fill_color": "F7F7F7",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "regular"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue May 14 06:06:56 +0000 2013",
#   "id": 334188056905129984,
#   "id_str": "334188056905129984",
#   "text": "Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://t.co/56giCSjcqw",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "SocialWebMining",
#      "name": "MiningTheSocialWeb",
#      "id": 132373965,
#      "id_str": "132373965",
#      "indices": [
#       82,
#       98
#      ]
#     },
#     {
#      "screen_name": "ptwobrussell",
#      "name": "Matthew Russell",
#      "id": 13085242,
#      "id_str": "13085242",
#      "indices": [
#       102,
#       115
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/56giCSjcqw",
#      "expanded_url": "http://on.fb.me/11WCD9E",
#      "display_url": "on.fb.me/11WCD9E",
#      "indices": [
#       116,
#       138
#      ]
#     }
#    ]
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 244991150,
#    "id_str": "244991150",
#    "name": "Fernando Perez",
#    "screen_name": "fperez_org",
#    "location": "Berkeley, CA",
#    "description": "Physicist, data scientist, @IPythonDev creator (evolved into @ProjectJupyter). UC Berkeley Stats Asst. Prof, @BerkeleyLab scientist, adv. @plotlygraphs, climber",
#    "url": "http://t.co/J7UDLpykqU",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/J7UDLpykqU",
#        "expanded_url": "http://fperez.org",
#        "display_url": "fperez.org",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 16463,
#    "friends_count": 532,
#    "listed_count": 746,
#    "created_at": "Sun Jan 30 16:28:09 +0000 2011",
#    "favourites_count": 6611,
#    "utc_offset": -25200,
#    "time_zone": "Pacific Time (US & Canada)",
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 7062,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/244991150/1404790002",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 5,
#   "favorite_count": 9,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "possibly_sensitive_appealable": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 5,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }
#
#
# @jyeee's retweet of @fperez_org's tweet
# []
# {
#  "created_at": "Mon May 27 01:55:57 +0000 2013",
#  "id": 338835939172417537,
#  "id_str": "338835939172417537",
#  "text": "RT @fperez_org: Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "fperez_org",
#     "name": "Fernando Perez",
#     "id": 244991150,
#     "id_str": "244991150",
#     "indices": [
#      3,
#      14
#     ]
#    },
#    {
#     "screen_name": "SocialWebMining",
#     "name": "MiningTheSocialWeb",
#     "id": 132373965,
#     "id_str": "132373965",
#     "indices": [
#      98,
#      114
#     ]
#    },
#    {
#     "screen_name": "ptwobrussell",
#     "name": "Matthew Russell",
#     "id": 13085242,
#     "id_str": "13085242",
#     "indices": [
#      118,
#      131
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 17930287,
#   "id_str": "17930287",
#   "name": "jyeee",
#   "screen_name": "jyeee",
#   "location": "Washington, DC",
#   "description": "",
#   "url": "https://t.co/6oebaBkYVa",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/6oebaBkYVa",
#       "expanded_url": "http://www.linkedin.com/in/jyeee",
#       "display_url": "linkedin.com/in/jyeee",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 189,
#   "friends_count": 393,
#   "listed_count": 30,
#   "created_at": "Sat Dec 06 22:27:09 +0000 2008",
#   "favourites_count": 885,
#   "utc_offset": -14400,
#   "time_zone": "Eastern Time (US & Canada)",
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 1169,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "131516",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "profile_background_tile": true,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/904172995060617220/5R83Sh9u_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/904172995060617220/5R83Sh9u_normal.jpg",
#   "profile_link_color": "009999",
#   "profile_sidebar_border_color": "EEEEEE",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue May 14 06:06:56 +0000 2013",
#   "id": 334188056905129984,
#   "id_str": "334188056905129984",
#   "text": "Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://t.co/56giCSjcqw",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "SocialWebMining",
#      "name": "MiningTheSocialWeb",
#      "id": 132373965,
#      "id_str": "132373965",
#      "indices": [
#       82,
#       98
#      ]
#     },
#     {
#      "screen_name": "ptwobrussell",
#      "name": "Matthew Russell",
#      "id": 13085242,
#      "id_str": "13085242",
#      "indices": [
#       102,
#       115
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/56giCSjcqw",
#      "expanded_url": "http://on.fb.me/11WCD9E",
#      "display_url": "on.fb.me/11WCD9E",
#      "indices": [
#       116,
#       138
#      ]
#     }
#    ]
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 244991150,
#    "id_str": "244991150",
#    "name": "Fernando Perez",
#    "screen_name": "fperez_org",
#    "location": "Berkeley, CA",
#    "description": "Physicist, data scientist, @IPythonDev creator (evolved into @ProjectJupyter). UC Berkeley Stats Asst. Prof, @BerkeleyLab scientist, adv. @plotlygraphs, climber",
#    "url": "http://t.co/J7UDLpykqU",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/J7UDLpykqU",
#        "expanded_url": "http://fperez.org",
#        "display_url": "fperez.org",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 16463,
#    "friends_count": 532,
#    "listed_count": 746,
#    "created_at": "Sun Jan 30 16:28:09 +0000 2011",
#    "favourites_count": 6611,
#    "utc_offset": -25200,
#    "time_zone": "Pacific Time (US & Canada)",
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 7062,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/244991150/1404790002",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 5,
#   "favorite_count": 9,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "possibly_sensitive_appealable": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 5,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %% [markdown]
# ## Example 15. Extracting a retweet's attribution

# %%
import re

def get_rt_attributions(tweet):

    # Regex adapted from Stack Overflow (http://bit.ly/1821y0J)

    rt_patterns = re.compile(r"(RT|via)((?:\b\W*@\w+)+)", re.IGNORECASE)
    rt_attributions = []

    # Inspect the tweet to see if it was produced with /statuses/retweet/:id.
    # See https://dev.twitter.com/docs/api/1.1/get/statuses/retweets/%3Aid.
    
    if 'retweeted_status' in tweet:
        attribution = tweet['retweeted_status']['user']['screen_name'].lower()
        rt_attributions.append(attribution)

    # Also, inspect the tweet for the presence of "legacy" retweet patterns
    # such as "RT" and "via", which are still widely used for various reasons
    # and potentially very useful. See https://dev.twitter.com/discussions/2847 
    # and https://dev.twitter.com/discussions/1748 for some details on how/why.

    try:
        rt_attributions += [ 
                        mention.strip() 
                        for mention in rt_patterns.findall(tweet['text'])[0][1].split() 
                      ]
    except IndexError:
        pass

    # Filter out any duplicates

    return list(set([rta.strip("@").lower() for rta in rt_attributions]))

# Sample usage
twitter_api = oauth_login()

tweet = twitter_api.statuses.show(_id=214746575765913602)
print(get_rt_attributions(tweet))
print('\n')
tweet = twitter_api.statuses.show(_id=345723917798866944)
print(get_rt_attributions(tweet))
# Out:
# ['jyeee']
#
#
# ['fperez_org']

# %% [markdown]
# ## Example 16. Making robust Twitter requests

# %%
import sys
import time
import urllib.error
from http.client import BadStatusLine
import json
import twitter

def make_twitter_request(twitter_api_func, max_errors=10, *args, **kw): 
    
    # A nested helper function that handles common HTTPErrors. Return an updated
    # value for wait_period if the problem is a 500 level error. Block until the
    # rate limit is reset if it's a rate limiting issue (429 error). Returns None
    # for 401 and 404 errors, which requires special handling by the caller.
    def handle_twitter_http_error(e, wait_period=2, sleep_when_rate_limited=True):
    
        if wait_period > 3600: # Seconds
#             print >> sys.stderr, 'Too many retries. Quitting.'

            print('Too many retries. Quitting.', file = sys.stderr)
            raise e
    
        # See https://dev.twitter.com/docs/error-codes-responses for common codes
    
        if e.e.code == 401:
#             print >> sys.stderr, 'Encountered 401 Error (Not Authorized)'

            print('Encountered 401 Error (Not Authorized)', file = sys.stderr)
            return None
        elif e.e.code == 404:
#             print >> sys.stderr, 'Encountered 404 Error (Not Found)'

            print('Encountered 404 Error (Not Found)', file = sys.stderr)
            return None
        elif e.e.code == 429: 
#             print >> sys.stderr, 'Encountered 429 Error (Rate Limit Exceeded)'

            print('Encountered 429 Error (Rate Limit Exceeded)', file = sys.stderr)
            if sleep_when_rate_limited:
            
#                 print >> sys.stderr, "Retrying in 15 minutes...ZzZ..."
                print("Retrying in 15 minutes...ZzZ...", file = sys.stderr)
                sys.stderr.flush()
                time.sleep(60*15 + 5)
            
#                 print >> sys.stderr, '...ZzZ...Awake now and trying again.'
                print('...ZzZ...Awake now and trying again.', file = sys.stderr)
                return 2
            else:
                raise e # Caller must handle the rate limiting issue
        elif e.e.code in (500, 502, 503, 504):
            
#             print >> sys.stderr, 'Encountered %i Error. Retrying in %i seconds' % \
#                 (e.e.code, wait_period)
            print('Encountered %i Error. Retrying in %i seconds' % \
                (e.e.code, wait_period), file = sys.stderr)
            time.sleep(wait_period)
            wait_period *= 1.5
            return wait_period
        else:
            raise e

    # End of nested helper function
    
    wait_period = 2 
    error_count = 0 

    while True:
        try:
            return twitter_api_func(*args, **kw)
        except twitter.api.TwitterHTTPError:
            error_count = 0 
            wait_period = handle_twitter_http_error(e, wait_period)
            if wait_period is None:
                return
        except URLError:
            error_count += 1
            time.sleep(wait_period)
            wait_period *= 1.5
#             print >> sys.stderr, "URLError encountered. Continuing."
            print("URLError encountered. Continuing.", file = sys.stderr)
            if error_count > max_errors:
                  
#                 print >> sys.stderr, "Too many consecutive errors...bailing out."
                print("Too many consecutive errors...bailing out.", file = sys.stderr)
                raise
        except BadStatusLine:
            error_count += 1
            time.sleep(wait_period)
            wait_period *= 1.5
                  
#             print >> sys.stderr, "BadStatusLine encountered. Continuing."
            print("BadStatusLine encountered. Continuing.", file = sys.stderr)
            if error_count > max_errors:
                  
#                 print >> sys.stderr, "Too many consecutive errors...bailing out."
                print("Too many consecutive errors...bailing out.", file = sys.stderr)
                raise

# Sample usage

twitter_api = oauth_login()

# See https://dev.twitter.com/docs/api/1.1/get/users/lookup for 
# twitter_api.users.lookup

response = make_twitter_request(twitter_api.users.lookup, 
                                screen_name="SocialWebMining")

print(json.dumps(response, indent=1))
# Out:
# [
#  {
#   "id": 132373965,
#   "id_str": "132373965",
#   "name": "MiningTheSocialWeb",
#   "screen_name": "SocialWebMining",
#   "location": "",
#   "description": "Get the source code at GitHub: http://t.co/U0VmWrXpB9",
#   "url": "http://t.co/CJfJDyM6ki",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/CJfJDyM6ki",
#       "expanded_url": "http://miningthesocialweb.com",
#       "display_url": "miningthesocialweb.com",
#       "indices": [
#        0,
#        22
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": [
#      {
#       "url": "http://t.co/U0VmWrXpB9",
#       "expanded_url": "http://bit.ly/MiningTheSocialWeb2E",
#       "display_url": "bit.ly/MiningTheSocia\u2026",
#       "indices": [
#        31,
#        53
#       ]
#      }
#     ]
#    }
#   },
#   "protected": false,
#   "followers_count": 4416,
#   "friends_count": 0,
#   "listed_count": 225,
#   "created_at": "Tue Apr 13 02:10:40 +0000 2010",
#   "favourites_count": 37,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 770,
#   "lang": "en",
#   "status": {
#    "created_at": "Mon Aug 17 14:39:50 +0000 2015",
#    "id": 633287122284228612,
#    "id_str": "633287122284228612",
#    "text": "Would you like to see a revised/expanded 3rd Ed. of Mining the Social Web? https://t.co/Bpd5UHMFw6 (If so, please RT, fav, or comment!)",
#    "truncated": false,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/Bpd5UHMFw6",
#       "expanded_url": "https://www.facebook.com/MiningTheSocialWeb/posts/874302272625003",
#       "display_url": "facebook.com/MiningTheSocia\u2026",
#       "indices": [
#        75,
#        98
#       ]
#      }
#     ]
#    },
#    "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 42,
#    "favorite_count": 132,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "en"
#   },
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "352726",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme5/bg.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1154493071/Picture_7_normal.png",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1154493071/Picture_7_normal.png",
#   "profile_link_color": "D02B55",
#   "profile_sidebar_border_color": "829D5E",
#   "profile_sidebar_fill_color": "99CC33",
#   "profile_text_color": "3E4415",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  }
# ]

# %% [markdown]
# ## Example 17. Resolving user profile information

# %%
def get_user_profile(twitter_api, screen_names=None, user_ids=None):
   
    # Must have either screen_name or user_id (logical xor)
    assert (screen_names != None) != (user_ids != None), \
    "Must have screen_names or user_ids, but not both"
    
    items_to_info = {}

    items = screen_names or user_ids
    
    while len(items) > 0:

        # Process 100 items at a time per the API specifications for /users/lookup.
        # See https://dev.twitter.com/docs/api/1.1/get/users/lookup for details.
        
        items_str = ','.join([str(item) for item in items[:100]])
        items = items[100:]

        if screen_names:
            response = make_twitter_request(twitter_api.users.lookup, 
                                            screen_name=items_str)
        else: # user_ids
            response = make_twitter_request(twitter_api.users.lookup, 
                                            user_id=items_str)
    
        for user_info in response:
            if screen_names:
                items_to_info[user_info['screen_name']] = user_info
            else: # user_ids
                items_to_info[user_info['id']] = user_info

    return items_to_info

# Sample usage

twitter_api = oauth_login()

print(get_user_profile(twitter_api, screen_names=["SocialWebMining", "ptwobrussell"]))
#print get_user_profile(twitter_api, user_ids=[132373965])
# Out:
# {'SocialWebMining': {'id': 132373965, 'id_str': '132373965', 'name': 'MiningTheSocialWeb', 'screen_name': 'SocialWebMining', 'location': '', 'description': 'Get the source code at GitHub: http://t.co/U0VmWrXpB9', 'url': 'http://t.co/CJfJDyM6ki', 'entities': {'url': {'urls': [{'url': 'http://t.co/CJfJDyM6ki', 'expanded_url': 'http://miningthesocialweb.com', 'display_url': 'miningthesocialweb.com', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'http://t.co/U0VmWrXpB9', 'expanded_url': 'http://bit.ly/MiningTheSocialWeb2E', 'display_url': 'bit.ly/MiningTheSocia…', 'indices': [31, 53]}]}}, 'protected': False, 'followers_count': 4416, 'friends_count': 0, 'listed_count': 225, 'created_at': 'Tue Apr 13 02:10:40 +0000 2010', 'favourites_count': 37, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 770, 'lang': 'en', 'status': {'created_at': 'Mon Aug 17 14:39:50 +0000 2015', 'id': 633287122284228612, 'id_str': '633287122284228612', 'text': 'Would you like to see a revised/expanded 3rd Ed. of Mining the Social Web? https://t.co/Bpd5UHMFw6 (If so, please RT, fav, or comment!)', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Bpd5UHMFw6', 'expanded_url': 'https://www.facebook.com/MiningTheSocialWeb/posts/874302272625003', 'display_url': 'facebook.com/MiningTheSocia…', 'indices': [75, 98]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 42, 'favorite_count': 132, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '352726', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1154493071/Picture_7_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154493071/Picture_7_normal.png', 'profile_link_color': 'D02B55', 'profile_sidebar_border_color': '829D5E', 'profile_sidebar_fill_color': '99CC33', 'profile_text_color': '3E4415', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'ptwobrussell': {'id': 13085242, 'id_str': '13085242', 'name': 'Matthew Russell', 'screen_name': 'ptwobrussell', 'location': 'Franklin, TN', 'description': 'Computer Scientist. Technologist. CrossFitter. Triathlete. Author.', 'url': 'http://t.co/AzFoM9TBPO', 'entities': {'url': {'urls': [{'url': 'http://t.co/AzFoM9TBPO', 'expanded_url': 'http://MiningTheSocialWeb.com', 'display_url': 'MiningTheSocialWeb.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2033, 'friends_count': 162, 'listed_count': 180, 'created_at': 'Tue Feb 05 08:16:12 +0000 2008', 'favourites_count': 900, 'utc_offset': -18000, 'time_zone': 'Central Time (US & Canada)', 'geo_enabled': False, 'verified': False, 'statuses_count': 1507, 'lang': 'en', 'status': {'created_at': 'Sat Jan 28 00:15:22 +0000 2017', 'id': 825135141525811200, 'id_str': '825135141525811200', 'text': 'RT @dreasoning: #CTO of the Year @ptwobrussell, and #DataScientist of the Year @guard0g, join our CEO @twestes to accept their #NTCAwards f…', 'truncated': False, 'entities': {'hashtags': [{'text': 'CTO', 'indices': [16, 20]}, {'text': 'DataScientist', 'indices': [52, 66]}], 'symbols': [], 'u ...

# %% [markdown]
# ## Example 18. Extracting tweet entities from arbitrary text

# %%
import twitter_text

# Sample usage

txt = "RT @SocialWebMining Mining 1M+ Tweets About #Syria http://wp.me/p3QiJd-1I"

ex = twitter_text.Extractor(txt)

print("Screen Names:", ex.extract_mentioned_screen_names_with_indices())
print("URLs:", ex.extract_urls_with_indices())
print("Hashtags:", ex.extract_hashtags_with_indices())
# Out:
# Screen Names: [{'screen_name': 'SocialWebMining', 'indices': [3, 19]}]
# URLs: [{'url': 'http://wp.me/p3QiJd-1I', 'indices': [51, 73]}]
# Hashtags: [{'hashtag': 'Syria', 'indices': [44, 50]}]

# %% [markdown]
# ## Example 19. Getting all friends or followers for a user

# %%
from functools import partial
import sys

def get_friends_followers_ids(twitter_api, screen_name=None, user_id=None,
                              friends_limit=sys.maxsize, followers_limit=sys.maxsize):
    
    # Must have either screen_name or user_id (logical xor)
    assert (screen_name != None) != (user_id != None), \
    "Must have screen_name or user_id, but not both"
    
    # See https://dev.twitter.com/docs/api/1.1/get/friends/ids and
    # https://dev.twitter.com/docs/api/1.1/get/followers/ids for details
    # on API parameters
    
    get_friends_ids = partial(make_twitter_request, twitter_api.friends.ids, 
                              count=5000)
    get_followers_ids = partial(make_twitter_request, twitter_api.followers.ids, 
                                count=5000)

    friends_ids, followers_ids = [], []
    
    for twitter_api_func, limit, ids, label in [
                    [get_friends_ids, friends_limit, friends_ids, "friends"], 
                    [get_followers_ids, followers_limit, followers_ids, "followers"]
                ]:
        
        if limit == 0: continue
        
        cursor = -1
        while cursor != 0:
        
            # Use make_twitter_request via the partially bound callable...
            if screen_name: 
                response = twitter_api_func(screen_name=screen_name, cursor=cursor)
            else: # user_id
                response = twitter_api_func(user_id=user_id, cursor=cursor)

            if response is not None:
                ids += response['ids']
                cursor = response['next_cursor']
        
#             print >> sys.stderr, 'Fetched {0} total {1} ids for {2}'.format(len(ids), 
#                                                     label, (user_id or screen_name))
            print('Fetched {0} total {1} ids for {2}'.format(len(ids), 
                                                    label, (user_id or screen_name)), file = sys.stderr)
        
            # XXX: You may want to store data during each iteration to provide an 
            # an additional layer of protection from exceptional circumstances
        
            if len(ids) >= limit or response is None:
                break

    # Do something useful with the IDs, like store them to disk...
    return friends_ids[:friends_limit], followers_ids[:followers_limit]

# Sample usage

twitter_api = oauth_login()

friends_ids, followers_ids = get_friends_followers_ids(twitter_api, 
                                                       screen_name="SocialWebMining", 
                                                       friends_limit=10, 
                                                       followers_limit=10)

print(friends_ids)
print(followers_ids)
# Out:
# Fetched 0 total friends ids for SocialWebMining
# []
# [122038352, 984307835113803781, 494133183, 65461579, 1098331556, 985326284644368384, 75995552, 39810811, 712533602102284288, 979144244]
# Fetched 4416 total followers ids for SocialWebMining

# %% [markdown]
# ## Example 20. Analyzing a user's friends and followers

# %%
def setwise_friends_followers_analysis(screen_name, friends_ids, followers_ids):
    
    friends_ids, followers_ids = set(friends_ids), set(followers_ids)
    
    print('{0} is following {1}'.format(screen_name, len(friends_ids)))

    print('{0} is being followed by {1}'.format(screen_name, len(followers_ids)))
    
    print('{0} of {1} are not following {2} back'.format(
            len(friends_ids.difference(followers_ids)), 
            len(friends_ids), screen_name))
    
    print('{0} of {1} are not being followed back by {2}'.format(
            len(followers_ids.difference(friends_ids)), 
            len(followers_ids), screen_name))
    
    print('{0} has {1} mutual friends'.format(
            screen_name, len(friends_ids.intersection(followers_ids))))

# Sample usage

screen_name = "ptwobrussell"

twitter_api = oauth_login()

friends_ids, followers_ids = get_friends_followers_ids(twitter_api, 
                                                       screen_name=screen_name)
setwise_friends_followers_analysis(screen_name, friends_ids, followers_ids)
# Out:
# Fetched 162 total friends ids for ptwobrussell
# ptwobrussell is following 162
# ptwobrussell is being followed by 2033
# 112 of 162 are not following ptwobrussell back
# 1983 of 2033 are not being followed back by ptwobrussell
# ptwobrussell has 50 mutual friends
# Fetched 2033 total followers ids for ptwobrussell

# %% [markdown]
# ## Example 21. Harvesting a user's tweets

# %%
def harvest_user_timeline(twitter_api, screen_name=None, user_id=None, max_results=1000):
     
    assert (screen_name != None) != (user_id != None), \
    "Must have screen_name or user_id, but not both"    
    
    kw = {  # Keyword args for the Twitter API call
        'count': 200,
        'trim_user': 'true',
        'include_rts' : 'true',
        'since_id' : 1
        }
    
    if screen_name:
        kw['screen_name'] = screen_name
    else:
        kw['user_id'] = user_id
        
    max_pages = 16
    results = []
    
    tweets = make_twitter_request(twitter_api.statuses.user_timeline, **kw)
    
    if tweets is None: # 401 (Not Authorized) - Need to bail out on loop entry
        tweets = []
        
    results += tweets
    
    print >> sys.stderr, 'Fetched %i tweets' % len(tweets)
    
    page_num = 1
    
    # Many Twitter accounts have fewer than 200 tweets so you don't want to enter
    # the loop and waste a precious request if max_results = 200.
    
    # Note: Analogous optimizations could be applied inside the loop to try and 
    # save requests. e.g. Don't make a third request if you have 287 tweets out of 
    # a possible 400 tweets after your second request. Twitter does do some 
    # post-filtering on censored and deleted tweets out of batches of 'count', though,
    # so you can't strictly check for the number of results being 200. You might get
    # back 198, for example, and still have many more tweets to go. If you have the
    # total number of tweets for an account (by GET /users/lookup/), then you could 
    # simply use this value as a guide.
    
    if max_results == kw['count']:
        page_num = max_pages # Prevent loop entry
    
    while page_num < max_pages and len(tweets) > 0 and len(results) < max_results:
    
        # Necessary for traversing the timeline in Twitter's v1.1 API:
        # get the next query's max-id parameter to pass in.
        # See https://dev.twitter.com/docs/working-with-timelines.
        kw['max_id'] = min([ tweet['id'] for tweet in tweets]) - 1 
    
        tweets = make_twitter_request(twitter_api.statuses.user_timeline, **kw)
        results += tweets

        print >> sys.stderr, 'Fetched %i tweets' % (len(tweets),)
    
        page_num += 1
        
    print >> sys.stderr, 'Done fetching tweets'

    return results[:max_results]
    
# Sample usage

twitter_api = oauth_login()
tweets = harvest_user_timeline(twitter_api, screen_name="SocialWebMining", \
                               max_results=200)

# Save to MongoDB with save_to_mongo or a local file with save_json...

# %% [markdown]
# ## Example 22. Crawling a friendship graph

# %%
def crawl_followers(twitter_api, screen_name, limit=1000000, depth=2):
    
    # Resolve the ID for screen_name and start working with IDs for consistency 
    # in storage

    seed_id = str(twitter_api.users.show(screen_name=screen_name)['id'])
    
    _, next_queue = get_friends_followers_ids(twitter_api, user_id=seed_id, 
                                              friends_limit=0, followers_limit=limit)

    # Store a seed_id => _follower_ids mapping in MongoDB
    
    save_to_mongo({'followers' : [ _id for _id in next_queue ]}, 'followers_crawl', 
                  '{0}-follower_ids'.format(seed_id))
    
    d = 1
    while d < depth:
        d += 1
        (queue, next_queue) = (next_queue, [])
        for fid in queue:
            _, follower_ids = get_friends_followers_ids(twitter_api, user_id=fid, 
                                                     friends_limit=0, 
                                                     followers_limit=limit)
            
            # Store a fid => follower_ids mapping in MongoDB
            save_to_mongo({'followers' : [ _id for _id in follower_ids ]}, 
                          'followers_crawl', '{0}-follower_ids'.format(fid))
            
            next_queue += follower_ids

# Sample usage

screen_name = "timoreilly"

twitter_api = oauth_login()

crawl_followers(twitter_api, screen_name, depth=1, limit=10)

# %% [markdown]
# ## Example 23. Analyzing tweet content

# %%
def analyze_tweet_content(statuses):
    
    if len(statuses) == 0:
        print "No statuses to analyze"
        return
    
    # A nested helper function for computing lexical diversity
    def lexical_diversity(tokens):
        return 1.0*len(set(tokens))/len(tokens) 
    
    # A nested helper function for computing the average number of words per tweet
    def average_words(statuses):
        total_words = sum([ len(s.split()) for s in statuses ]) 
        return 1.0*total_words/len(statuses)

    status_texts = [ status['text'] for status in statuses ]
    screen_names, hashtags, urls, media, _ = extract_tweet_entities(statuses)
    
    # Compute a collection of all words from all tweets
    words = [ w 
          for t in status_texts 
              for w in t.split() ]
    
    print "Lexical diversity (words):", lexical_diversity(words)
    print "Lexical diversity (screen names):", lexical_diversity(screen_names)
    print "Lexical diversity (hashtags):", lexical_diversity(hashtags)
    print "Averge words per tweet:", average_words(status_texts)

    
# Sample usage

q = 'CrossFit'
twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q)

analyze_tweet_content(search_results)

# %% [markdown]
# ## Example 24. Summarizing link targets

# %%
import sys
import json
import nltk
import numpy
import requests
from boilerpipe.extract import Extractor

def summarize(url=None, html=None, n=100, cluster_threshold=5, top_sentences=5):

    # Adapted from "The Automatic Creation of Literature Abstracts" by H.P. Luhn
    #
    # Parameters:
    # * n  - Number of words to consider
    # * cluster_threshold - Distance between words to consider
    # * top_sentences - Number of sentences to return for a "top n" summary
            
    # Begin - nested helper function
    def score_sentences(sentences, important_words):
        scores = []
        sentence_idx = -1
    
        for s in [nltk.tokenize.word_tokenize(s) for s in sentences]:
    
            sentence_idx += 1
            word_idx = []
    
            # For each word in the word list...
            for w in important_words:
                try:
                    # Compute an index for important words in each sentence
    
                    word_idx.append(s.index(w))
                except ValueError, e: # w not in this particular sentence
                    pass
    
            word_idx.sort()
    
            # It is possible that some sentences may not contain any important words
            if len(word_idx)== 0: continue
    
            # Using the word index, compute clusters with a max distance threshold
            # for any two consecutive words
    
            clusters = []
            cluster = [word_idx[0]]
            i = 1
            while i < len(word_idx):
                if word_idx[i] - word_idx[i - 1] < cluster_threshold:
                    cluster.append(word_idx[i])
                else:
                    clusters.append(cluster[:])
                    cluster = [word_idx[i]]
                i += 1
            clusters.append(cluster)
    
            # Score each cluster. The max score for any given cluster is the score 
            # for the sentence.
    
            max_cluster_score = 0
            for c in clusters:
                significant_words_in_cluster = len(c)
                total_words_in_cluster = c[-1] - c[0] + 1
                score = 1.0 * significant_words_in_cluster \
                    * significant_words_in_cluster / total_words_in_cluster
    
                if score > max_cluster_score:
                    max_cluster_score = score
    
            scores.append((sentence_idx, score))
    
        return scores    
    
    # End - nested helper function
    
    extractor = Extractor(extractor='ArticleExtractor', url=url, html=html)

    # It's entirely possible that this "clean page" will be a big mess. YMMV.
    # The good news is that the summarize algorithm inherently accounts for handling
    # a lot of this noise.

    txt = extractor.getText()
    
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    normalized_sentences = [s.lower() for s in sentences]

    words = [w.lower() for sentence in normalized_sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    top_n_words = [w[0] for w in fdist.items() 
            if w[0] not in nltk.corpus.stopwords.words('english')][:n]

    scored_sentences = score_sentences(normalized_sentences, top_n_words)

    # Summarization Approach 1:
    # Filter out nonsignificant sentences by using the average score plus a
    # fraction of the std dev as a filter

    avg = numpy.mean([s[1] for s in scored_sentences])
    std = numpy.std([s[1] for s in scored_sentences])
    mean_scored = [(sent_idx, score) for (sent_idx, score) in scored_sentences
                   if score > avg + 0.5 * std]

    # Summarization Approach 2:
    # Another approach would be to return only the top N ranked sentences

    top_n_scored = sorted(scored_sentences, key=lambda s: s[1])[-top_sentences:]
    top_n_scored = sorted(top_n_scored, key=lambda s: s[0])

    # Decorate the post object with summaries

    return dict(top_n_summary=[sentences[idx] for (idx, score) in top_n_scored],
                mean_scored_summary=[sentences[idx] for (idx, score) in mean_scored])

# Sample usage

sample_url = 'http://radar.oreilly.com/2013/06/phishing-in-facebooks-pond.html'
summary = summarize(url=sample_url)

# Alternatively, you can pass in HTML if you have it. Sometimes this approach may be
# necessary if you encounter mysterious urllib2.BadStatusLine errors. Here's how
# that would work:

# sample_html = requests.get(sample_url).text
# summary = summarize(html=sample_html)

print "-------------------------------------------------"
print "                'Top N Summary'"
print "-------------------------------------------------"
print " ".join(summary['top_n_summary'])
print
print
print "-------------------------------------------------"
print "             'Mean Scored' Summary"
print "-------------------------------------------------"
print " ".join(summary['mean_scored_summary'])

# %% [markdown]
# ## Example 25. Analyzing a user's favorite tweets

# %%
def analyze_favorites(twitter_api, screen_name, entity_threshold=2):
    
    # Could fetch more than 200 by walking the cursor as shown in other
    # recipes, but 200 is a good sample to work with.
    favs = twitter_api.favorites.list(screen_name=screen_name, count=200)
    print "Number of favorites:", len(favs)
    
    # Figure out what some of the common entities are, if any, in the content
    
    common_entities = get_common_tweet_entities(favs, 
                                                entity_threshold=entity_threshold)
    
    # Use PrettyTable to create a nice tabular display
    
    pt = PrettyTable(field_names=['Entity', 'Count']) 
    [ pt.add_row(kv) for kv in common_entities ]
    pt.align['Entity'], pt.align['Count'] = 'l', 'r' # Set column alignment
    
    print
    print "Common entities in favorites..."
    print pt
    
    
    # Print out some other stats
    print
    print "Some statistics about the content of the favorities..."
    print
    analyze_tweet_content(favs)
    
    # Could also start analyzing link content or summarized link content, and more.

# Sample usage

twitter_api = oauth_login()
analyze_favorites(twitter_api, "ptwobrussell")
